# %%
import numpy as np
import scipy.linalg as sl
import scipy.special as ss
import libstempo as lt, libstempo.plot as ltp, libstempo.toasim as ltt
import matplotlib.pyplot as plt
import os, sys, glob
import simple_mcmc as smcmc
import triangle
# %matplotlib inline
# Out:
# Warning: cannot find astropy, units support will not be available.

# %% [markdown]
# # Day 2: do a simple noise analysis #
#
# We are going to do a simple noise analysis today. For a whole bunch of pulsars, you will find datafiles in the directory 'signals'. We will analyze one pulsar (say, J0030) today for noise. In order to do that, we have provided some auxiliary functions

# %% [markdown]
# ## Some constants ##
#
# These constants will come in handy

# %%
day = 86400.0                   # Seconds per day
year =  31557600.0              # Seconds per year (yr = 365.25 days, so Julian years)
EulerGamma = 0.5772156649015329 # Euler gamma constant
mjdT0 = 54000.0                 # MJD to which all toas are referenced (for precision)

# %% [markdown]
# ## Design matrix ##
# In case we do not use the tempo2 design matrix, we can generate one ourselves for quadratic spindown

# %%
def designqsd(t, order=2):
    """
    Calculate the design matrix for quadratic spindown

    :param t:
        array of toas
    """
    M = np.ones([len(t), order+1])
    for ii in range(1, order+1):
        M[:,ii] = t ** ii
    
    return M.copy()

# %% [markdown]
# ## Fourier basis ##
# Like the design matrix, we need a basis for the Fourier amplitudes as well.

# %%
def fourierdesignmatrix(t, nmodes, Ttot=None):
    """
    Calculate the matrix of Fourier modes A, given a set of timestamps

    These are sine/cosine basis vectors at evenly separated frequency bins

    Mode 0: sin(f_0)
    Mode 1: cos(f_0)
    Mode 2: sin(f_1)
    ... etc

    :param nmodes:
        The number of modes that will be included (= 2*nfreq)
    :param Ttot:
        Total duration experiment (in case not given by t)

    :return:
        (A, freqs), with A the 'fourier design matrix', and f the associa

    """
    N = t.size
    A = np.zeros([N, nmodes])
    T = t.max() - t.min()

    if(nmodes % 2 != 0):
      print "WARNING: Number of modes should be even!"

    if Ttot is None:
        deltaf = 1.0 / T
    else:
        deltaf = 1.0 / Ttot

    freqs1 = np.linspace(deltaf, (nmodes/2)*deltaf, nmodes/2)
    freqs = np.array([freqs1, freqs1]).T.flatten()

    # The cosine modes
    for i in range(0, nmodes, 2):
        omega = 2.0 * np.pi * freqs[i]
        A[:,i] = np.cos(omega * t)

    # The sine modes
    for i in range(1, nmodes, 2):
        omega = 2.0 * np.pi * freqs[i]
        A[:,i] = np.sin(omega * t)

    return (A, freqs)

# %% [markdown]
# ## Functions for power-law spectral analysis ##
# In order to do spectral analysis, we need the PSD, the covariance function (PSD cosine transform), and the covariance matrix.

# %%
def PL_psd(f, amp, alpha, sig_fL):
    """
    PSD for a power-law signal.

    :param f:
        Array of frequencies for which to return the PSD (1/sec)

    :param amp:
        Unitless amplitude of the power-law signal

    :param alpha:
        Spectral index

    :param sig_fL:
        Signal low-frequency cut-off. A physical bound
    
    Note that this function returns the power per
    frequency bin of (1/Tmax) size, so the units are in sec^2 / (1/Tmax)
    """
    Si = 3.0 - 2.0*alpha

    Tmax = 1.0 / np.min(f)

    freqpy = f * year

    mask = (freqpy >= sig_fL)

    psd = np.zeros(len(freqpy))
    psd[mask] = (amp**2 * year**3 / (12*np.pi*np.pi * Tmax)) * freqpy[mask] ** (-Si)
    
    return psd


# Calculate the covariance matrix for a red signal
# (for a GWB with unitless amplitude h_c(1yr^{-1}) = 1)
def PL_covfunc(tau, amp, alpha=-2.0/3.0, fL=1.0/(year*20)):
    """
    Compute the covariance function for a powerlaw
    Result is in units of (sec)^2.

    :param tau:
        the time lag

    :param amp:
        amplitude

    :param alpha:
        the GWB spectral index

    :param fL:
        the low-frequency cut-off
    """
    fL = fL * year
    x = 2 * np.pi * fL * np.abs(tau) / year
    cf = ss.gamma(-2+2*alpha) * np.cos(np.pi*alpha)
    power = cf * x**(2-2*alpha)
    ksum = ss.hyp1f2(alpha-1,0.5,alpha,-0.25*x**2)[0]/(2*alpha-2)
    corr = -(year**2 * fL**(-2+2*alpha)) / (12 * np.pi**2) * (power + ksum)
    
    return amp**2*corr


def PL_covmat(toas, amp, alpha=-2.0/3.0, fL=1.0/(year*20)):
    """
    Use the covariance function PL_covfunc to create the covariance matrix for
    'toas'. Result is in units of (sec)^2

    :param tau:
        the time lag

    :param amp:
        amplitude

    :param alpha:
        the GWB spectral index

    :param fL:
        the low-frequency cut-off
    """
    t1, t2 = np.meshgrid(toas, toas)
    tau = np.abs(t1-t2)

    return PL_covfunc(tau, amp, alpha, fL)

# %% [markdown]
# ## A simple pulsar class ##
#
# This class does not do much. It neatly stores data for you, and conveniently creates the Fourier basis for spectral analysis

# %%
class Pulsar(object):
    def __init__(self, toas, residuals, toaerrs, desmat=None, nfreqs=20,
            qsdorder=2, Tlow=None):
        """
        Initialise the pulsar from data

        :param toas:
            The barycentric times of arrival [MJD]

        :param residuals:
            The timing residuals [sec]

        :param toaerrs:
            The TOA uncertainties [sec]

        :param desmat:
            The design matrix (default None)

        :param nfreqs:
            The number of frequencies we'll use in the Fourier expansion

        :param qsdorder:
            If desmat=None, make a design matrix from scratch, with this order

        :param Tlow:
            1/lowest frequency used in expansion (default length of dataset)(
        """
        self.toas = (toas - mjdT0) * day       # MJD to seconds
        self.residuals = residuals
        self.toaerrs = toaerrs
        self.Mmat = desmat
        self.nobs = len(toas)
        self.nfreqs = nfreqs

        self.T = (np.max(self.toas) - np.min(self.toas))

        if self.Mmat is None:
            self.Mmat = designqsd(self.toas, order=qsdorder)

        # Create the basis of Fourier components
        if Tlow is None:
            Tlow = (np.max(self.toas) - np.min(self.toas))
        (self.Fmat, self.freqs) = fourierdesignmatrix(self.toas, 2*nfreqs, Ttot=Tlow)

# %% [markdown]
# # Exercise 1 #
# In this exercise, we test the provided functions above. We'll read in data, and construct the PSD-derived functions

# %% [markdown]
# # Exercise 1a #
# Read in a pulsar of your choice, and initialize the pulsar class

# %%
psrnum = 1 # J0030
psrlist = glob.glob('signals/J?????????.txt')
psrname = os.path.splitext(psrlist[psrnum])[0]
sigfile = psrname + '.txt'
desfile = psrname + '-des.txt'

# %%
dat = np.loadtxt(sigfile)
toas = dat[:,0]
residuals = dat[:,1]
toaerrs = dat[:,2]
desmat = np.loadtxt(desfile)
psr = Pulsar(toas, residuals, toaerrs, desmat=desmat)

# %% [markdown]
# # Exercise 1b #
# Plot the timing residuals, including the measurement uncertainties

# %%
plt.errorbar(toas, residuals, yerr=toaerrs, fmt='x', c='blue')
# Out:
# <Container object of 3 artists>

# %% [markdown]
# # Exercise 1c #
# For a red noise signal with $\alpha=-\frac{2}{3}$, and $A=10^{-14}$, plot the power spectral density and the covariance function.
#
# What is the effect of the low-frequency cut-off on either of these?

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)

# Power-law parameters
amp = 1.0e-14
alpha = -2.0/3.0
fL = 1.0 / (np.max(psr.toas) - np.min(psr.toas))

# Create the PSD
psd = PL_psd(psr.freqs, amp=1.0e-14, alpha=-2.0/3.0, sig_fL=fL)
ax[0].loglog(psr.freqs, psd)

# Create the covariance function
tau = psr.toas-np.min(psr.toas)
covf = PL_covfunc(tau, amp, alpha, fL=fL/4.0)
ax[1].plot(tau, covf)

# %% [markdown]
# ## Exercise 1d ##
# How could you use the psd of the previous exercise to generate mock timing residuals?

# %%
mockres = np.dot(psr.Fmat, np.sqrt(psd) * np.random.randn(len(psd)))
plt.plot(psr.toas, mockres)

# %% [markdown]
# # Exercise 2 #
# We will be writing log-likelihood functions here. First we will give two log-likelihood functions that can be used for _simple_ analyses, but they are not fast. You will be challenged to write a faster version. If you don't manage, use one of these slower versions for the MCMC exercise in exercise 3.

# %%
def mark1loglikelihood(psr, Aw, Ar, Si):
    """
    Log-likelihood for our pulsar. This one does not marginalize
    over the timing model, so it cannot be used if the data has been
    'fit'. Use when creating data with 'dofit=False':
    psr = Pulsar(dofit=False)
    
    Calculate covariance matrix in the time-domain with:
    
    ll = -0.5 * res^{T} C^{-1} res - 0.5 * log(det(C))
    
    :param psr:
        pulsar object, containing the data and stuff

    :param Aw:
        White noise amplitude, model parameter

    :param Ar:
        Red noise amplitude, model parameter

    :param Si:
        Spectral index of red noise, model parameter
    """
    
    # The function that builds the non-diagonal covariance matrix is Cred_sec
    #Cov = Aw**2 * np.eye(len(psr.toas)) + \
    #      Ar**2 * Cred_sec(psr.toas, alpha=0.5*(3-Si))
    Cov = Aw**2 * np.eye(len(psr.toas)) + \
        PL_covmat(psr.toas, Ar, alpha=0.5*(3-Si), fL=1.0/(year*20))
    
    cfC = sl.cho_factor(Cov)
    ldetC = 2 * np.sum(np.log(np.diag(cfC[0])))
    rCr = np.dot(psr.residuals, sl.cho_solve(cfC, psr.residuals))
    
    return -0.5 * rCr - 0.5 * ldetC - 0.5*len(psr.residuals)*np.log(2*np.pi)

def mark2loglikelihood(psr, Aw, Ar, Si):
    """
    Log-likelihood for our pulsar
    
    This likelihood does marginalize over the timing model. Calculate
    covariance matrix in the time-domain with:
    
    ll = 0.5 * res^{t} (C^{-1} - C^{-1} M (M^{T} C^{-1} M)^{-1} M^{T} C^{-1} ) res - \
         0.5 * log(det(C)) - 0.5 * log(det(M^{T} C^{-1} M))
         
    In relation to 'mark1loglikelihood', this likelihood has but a simple addition:
    res' = res - M xi
    where M is a (n x m) matrix, with m < n, and xi is a vector of length m. The xi
    are analytically marginalised over, yielding the above equation (up to constants)
    
    :param psr:
        pulsar object, containing the data and stuff

    :param Aw:
        White noise amplitude, model parameter

    :param Ar:
        Red noise amplitude, model parameter

    :param Si:
        Spectral index of red noise, model parameter
    """
    Mmat = psr.Mmat
    
    Cov = Aw**2 * np.eye(len(psr.toas)) + \
        PL_covmat(psr.toas, Ar, alpha=0.5*(3-Si), fL=1.0/(year*20))
    
    cfC = sl.cho_factor(Cov)
    Cinv = sl.cho_solve(cfC, np.eye(len(psr.toas)))
    ldetC = 2 * np.sum(np.log(np.diag(cfC[0])))

    MCM = np.dot(Mmat.T, np.dot(Cinv, Mmat))
    cfM = sl.cho_factor(MCM)
    ldetM = 2 * np.sum(np.log(np.diag(cfM[0])))
    
    wr = np.dot(Cinv, psr.residuals)
    rCr = np.dot(psr.residuals, wr)
    MCr = np.dot(Mmat.T, wr)
    
    return -0.5 * rCr + 0.5 * np.dot(MCr, sl.cho_solve(cfM, MCr)) - \
            0.5 * ldetC - 0.5 * ldetM -0.5*len(psr.residuals)*np.log(2*np.pi)

# %% [markdown]
# ## Exercise 2a ##
# Write the log-likelihood function using the hierachical model (with the Woodbury matrix identity) as shown in the presentation. How much faster is it?

# %%
def mark3loglikelihood(psr, Nvec, psd):
    """
    Log-likelihood for our pulsar (hierarchical/Woodbury)

    :param psr:
        pulsar object, containing the data and stuff

    :param Nvec:
        Vector of squared white noise amplitude (diagonal of covariance matrix)

    :param psd:
        Power-spectral density per frequency bin (of size 1/T)
    """
    Mmat, Fmat = psr.Mmat, psr.Fmat
    Tmat = np.append(Mmat, Fmat, axis=1)
    n, m, l = len(psr.toas), Mmat.shape[1], Fmat.shape[1]

    # Sigma matrix (inverse)
    TNT = np.dot(Tmat.T / Nvec, Tmat)
    phi_inv = np.zeros(m+l)
    phi_inv[m:] = 1.0/psd
    Sigma_inv = TNT + np.diag(phi_inv)

    # Invert Sigma_inv for use in the Woodbury identity
    #Sigma = sl.inv(Sigma_inv)       # Does not use Cholesky
    cf = sl.cho_factor(Sigma_inv)
    STNr = sl.cho_solve(cf, np.dot(Tmat.T / Nvec, psr.residuals))
    rNTSTNr = np.dot(psr.residuals, np.dot((Tmat.T / Nvec).T, STNr))
    rNr = np.sum(psr.residuals**2/Nvec)

    # The full Woodbury expansion
    rCr = rNr - rNTSTNr

    # Determinants
    logNdet = np.sum(np.log(Nvec))
    logPhidet = np.sum(np.log(psd))
    logSigmadet = 2.0*np.sum(np.log(np.diag(cf[0])))

    # Sylvester Matrix identity
    logCdet = logNdet + logPhidet + logSigmadet

    return -0.5*rCr-0.5*logCdet-0.5*n*np.log(2*np.pi)

def pl_loglikelihood(psr, Aw, Ar, Si):
    """
    Log-likelihood for our pulsar (hierarchical/Woodbury)

    :param psr:
        pulsar object, containing the data and stuff

    :param Aw:
        White noise amplitude [sec]
        
    :param Ar:
        Power-law red noise amplitude []

    :param Si:
        Power-law red noise spectral index []
    """
    Nvec = np.ones(len(psr.toas)) * Aw**2
    psd = PL_psd(psr.freqs, Ar, 0.5*(3-Si), sig_fL=1.0/(20.0*year))
    return mark3loglikelihood(psr, Nvec, psd)

def sp_loglikelihood(psr, Aw, psd):
    """
    Log-likelihood for our pulsar (hierarchical/Woodbury)

    :param psr:
        pulsar object, containing the data and stuff

    :param Aw:
        White noise amplitude [sec]
        
    :param psd:
        Vector PSD amplitudes [sec]
    """    
    if len(psd)*2 != psr.Fmat.shape[1]:
        raise ValueError("PSD vector not of appropriate length!")

    Nvec = np.ones(len(psr.toas)) * Aw**2
    return mark3loglikelihood(psr, Nvec, psd.repeat(2))

# %%
# %timeit mark1loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
# %timeit mark2loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
# %timeit pl_loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
# Out:
# 100 loops, best of 3: 4.42 ms per loop
# 100 loops, best of 3: 6.42 ms per loop
# 1000 loops, best of 3: 397 µs per loop

# %% [markdown]
# # Exercise 2b #
# Plot the log-likelihood as a function of power-law amplitude for the range 10**(-16, -13), with $\gamma=13/3$

# %%
# The log-likelihood for a particular value of A
print mark1loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
print mark2loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
print pl_loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
# Out:
# 2842.91946275
# 2613.81315359
# 2613.8339915

# %%
Ar = np.linspace(-16.0, -13.0, 100)
ll1 = np.zeros_like(Ar)
ll2 = np.zeros_like(Ar)
ll3 = np.zeros_like(Ar)

for ii, A in enumerate(Ar):
    amp = 10**(A)
    ll1[ii] = mark1loglikelihood(psr, 1.0e-7, amp, 4.33)
    ll2[ii] = mark2loglikelihood(psr, 1.0e-7, amp, 4.33)
    ll3[ii] = pl_loglikelihood(psr, 1.0e-7, amp, 4.33)

plt.plot(Ar, np.exp(ll1-np.max(ll1)), 'b')
plt.plot(Ar, np.exp(ll2-np.max(ll2)), 'g')
plt.plot(Ar, np.exp(ll3-np.max(ll3)), 'r--')

# %% [markdown]
# ## Exercise 2c ##
# Run a simple MCMC, using the sampler you wrote yesterday, to discover the injected value of:
#  * white noise
#  * power-law red noise amplitude
#  * power-law red noise spectral index

# %%
# Run a simple MCMC on the power-law
def loglik(x):
    return pl_loglikelihood(psr, 10**x[0], 10**x[1], x[2])

def logprior(x):
    rv = 0.0
    xmin = np.array([-10.0, -18.0, 0.0])
    xmax = np.array([-4.0, -12.0, 9.0])
    
    if np.any(x < xmin) or np.any(x > xmax):
        rv = -np.inf
        
    return rv

p0 = np.array([-7.0, -14.0, 4.33])
sigmas = np.array([0.1, 0.1, 0.1])
sampler = smcmc.SimpleMCMC(loglik, logprior, sigmas)

# %%
sampler.sample(p0, 50000)
# Out:
# Finished 0.2 percent. Acceptance Rate: 24
# Finished 0.4 percent. Acceptance Rate: 23.5
# Finished 0.6 percent. Acceptance Rate: 23.6667
# Finished 0.8 percent. Acceptance Rate: 24.25
# Finished 1 percent. Acceptance Rate: 24.2
# Finished 1.2 percent. Acceptance Rate: 23.8333
# Finished 1.4 percent. Acceptance Rate: 23.5714
# Finished 1.6 percent. Acceptance Rate: 23.625
# Finished 1.8 percent. Acceptance Rate: 23.6667
# Finished 2 percent. Acceptance Rate: 22.8
# Finished 2.2 percent. Acceptance Rate: 22.8182
# Finished 2.4 percent. Acceptance Rate: 23.6667
# Finished 2.6 percent. Acceptance Rate: 23.5385
# Finished 2.8 percent. Acceptance Rate: 23.9286
# Finished 3 percent. Acceptance Rate: 23.6
# Finished 3.2 percent. Acceptance Rate: 23.5
# Finished 3.4 percent. Acceptance Rate: 23.3529
# Finished 3.6 percent. Acceptance Rate: 23.2778
# Finished 3.8 percent. Acceptance Rate: 23.4737
# Finished 4 percent. Acceptance Rate: 23.55
# Finished 4.2 percent. Acceptance Rate: 23.4762
# Finished 4.4 percent. Acceptance Rate: 23.4091
# Finished 4.6 percent. Acceptance Rate: 23.3913
# Finished 4.8 percent. Acceptance Rate: 23.25
# Finished 5 percent. Acceptance Rate: 23.12
# Finished 5.2 percent. Acceptance Rate: 23.0769
# Finished 5.4 percent. Acceptance Rate: 22.7778
# Finished 5.6 percent. Acceptance Rate: 22.7857
# Finished 5.8 percent. Acceptance Rate: 22.7931
# Finished 6 percent. Acceptance Rate: 22.5
# Finished 6.2 percent. Acceptance Rate: 22.6129
# Finished 6.4 percent. Acceptance Rate: 22.4688
# Finished 6.6 percent. Acceptance Rate: 22.6667
# Finished 6.8 percent. Acceptance Rate: 22.6176
# Finished 7 percent. Acceptance Rate: 22.6857
# Finished 7.2 percent. Acceptance Rate: 22.5556
# Finished 7.4 percent. Acceptance Rate: 22.8649
# Finished 7.6 percent. Acceptance Rate: 22.7895
# Finished 7.8 percent. Acceptance Rate: 22.6667
# Finished 8 percent. Acceptance Rate: 22.7
# Finished 8.2 percent. Acceptance Rate: 22.6341
# Finished 8.4 percent. Acceptance Rate: 22.5952
# Finished 8.6 percent. Acceptance Rate: 22.4651
# Finished 8.8 percent. Acceptance Rate: 22.5227
# Finished 9 percent. Acceptance Rate: 22.4222
# Finished 9.2 percent. Acceptance Rate: 22.5
# Finished 9.4 percent. Acceptance Rate: 22.4043
# Finished 9.6 percent. Acceptance Rate: 22.4167
# Finished 9.8 percent. Acceptance Rate: 22.5102
# Finished 10 percent. Acceptance Rate: 22.58
# Finished 10.2 percent. Acceptance Rate: 22.7255
# Finished 10.4 percent. Acceptance Rate: 22.6346
# Finished 10.6 percent. Acceptance Rate: 22.5849
# Finished 10.8 percent. Acceptance Rate: 22.7407
# Finished 11 percent. Acceptance Rate: 22.7636
# Finished 11.2 percent. Acceptance Rate: 22.8036
# Finished 11.4 percent. Acceptance Rate: 22.7895
# Finished 11.6 percent. Acceptance Rate: 22.8621
# Finished 11.8 percent. Acceptance Rate: 22.8136
# Finished 12 percent. Acceptance Rate: 22.7333
# Finished 12.2 percent. Acceptance Rate: 22.8361
# Finished 12.4 percent. Acceptance Rate: 22.7742
# Finished 12.6 percent. Acceptance Rate: 22.8413
# Finished 12.8 percent. Acceptance Rate: 22.8438
# Finished 13 percent. Acceptance Rate: 22.6923
# Finished 13.2 percent. Acceptance Rate: 22.7727
# Finished 13.4 percent. Acceptance Rate: 22.7612
# Finished 13.6 percent. Acceptance Rate: 22.8088
# Finished 13.8 percent. Acceptance Rate: 22.8406
# Finished 14 percent. Acceptance Rate: 22.8286
# Finished 14.2 percent. Acceptance Rate: 22.831
# Finished 14.4 percent. Acceptance Rate: 22.8056
# Finished 14.6 percent. Acceptance Rate: 22.7945
# Finished 14.8 percent. Acceptance Rate: 22.7297
# Finished 15 percent. Acceptance Rate: 22.7733
# Finished 15.2 percent. Acceptance Rate: 22.8158
# Finished 15.4 percent. Acceptance Rate: 22.8182
# Finished 15.6 percent. Acceptance Rate: 22.7692
# Finished 15.8 percent. Acceptance Rate: 22.8354
# Finished 16 percent. Acceptance Rate: 22.8125
# Finished 16.2 percent. Acceptance Rate: 22.7778
# Finished 16.4 percent. Acceptance Rate: 22.7439
# Finished 16.6 percent. Acceptance Rate: 22.7952
# Finished 16.8 percent. Acceptance Rate: 22.7738
# Finished 17 percent. Acceptance Rate: 22.7647
# Finished 17.2 percent. Acceptance Rate: 22.814
# Finished 17.4 percent. Acceptance Rate: 22.8276
# Finished 17.6 percent. Acceptance Rate: 22.8182
# Finished 17.8 percent. Acceptance Rate: 22.809
# Finished 18 percent. Acceptance Rate: 22.8556
# Finished 18.2 percent. Acceptance Rate: 22.8462
# Finished 18.4 percent. Acceptance Rate: 22.8478
# Finished 18.6 percent. Acceptance Rate: 22.828
# Finished 18.8 percent. Acceptance Rate: 22.8511
# Finished 19 percent. Acceptance Rate: 22.7684
# Finished 19.2 percent. Acceptance Rate: 22.7604
# Finished 19.4 percent. Acceptance Rate: 22.7629
# Finished 19.6 percent. Acceptance Rate: 22.7551
# Finished 19.8 percent. Acceptance Rate: 22.697
# Finished 20 percent. Acceptance Rate: 22.67
# Finished 20.2 percent. Acceptance Rate: 22.6337
# Finished 20.4 percent. Acceptance Rate: 22.6569
# Finished 20.6 percent. Acceptance Rate: 22.6602
# Finished 20.8 percent. Acceptance Rate: 22.6731
# Finished 21 percent. Acceptance Rate: 22.7143
# Finished 21.2 percent. Acceptance Rate: 22.7547
# Finished 21.4 percent. Acceptance Rate: 22.8318
# Finished 21.6 percent. Acceptance Rate: 22.8981
# Finished 21.8 percent. Acceptance Rate: 22.8073
# Finished 22 percent. Acceptance Rate: 22.7818
# Finished 22.2 percent. Acceptance Rate: 22.7297
# Finished 22.4 percent. Acceptance Rate: 22.7589
# Finished 22.6 percent. Acceptance Rate: 22.7788
# Finished 22.8 percent. Acceptance Rate: 22.7895
# Finished 23 percent. Acceptance Rate: 22.8261
# Finished 23.2 percent. Acceptance Rate: 22.8707
# Finished 23.4 percent. Acceptance Rate: 22.8376
# Finished 23.6 percent. Acceptance Rate: 22.822
# Finished 23.8 percent. Acceptance Rate: 22.8824
# Finished 24 percent. Acceptance Rate: 22.9167
# Finished 24.2 percent. Acceptance Rate: 22.9174
# Finished 24.4 percent. Acceptance Rate: 22.9426
# Finished 24.6 percent. Acceptance Rate: 22.935
# Finished 24.8 percent. Acceptance Rate: 22.871
# Finished 25 percent. Acceptance Rate: 22.896
# Finished 25.2 percent. Acceptance Rate: 22.8968
# Finished 25.4 percent. Acceptance Rate: 22.8819
# Finished 25.6 percent. Acceptance Rate: 22.9141
# Finished 25.8 percent. Acceptance Rate: 22.938
# Finished 26 percent. Acceptance Rate: 23.0385
# Finished 26.2 percent. Acceptance Rate: 23.0534
# Finished 26.4 percent. Acceptance Rate: 23.0303
# Finished 26.6 percent. Acceptance Rate: 23.0677
# Finished 26.8 percent. Acceptance Rate: 23.0522
# Finished 27 percent. Acceptance Rate: 23.0444
# Finished 27.2 percent. Acceptance Rate: 23.0221
# Finished 27.4 percent. Acceptance Rate: 23.0292
# Finished 27.6 percent. Acceptance Rate: 23.0072
# Finished 27.8 percent. Acceptance Rate: 23.0576
# Finished 28 percent. Acceptance Rate: 23.0214
# Finished 28.2 percent. Acceptance Rate: 23
# Finished 28.4 percent. Acceptance Rate: 23.0211
# Finished 28.6 percent. Acceptance Rate: 23
# Finished 28.8 percent. Acceptance Rate: 23.0208
# Finished 29 percent. Acceptance Rate: 23.0345
# Finished 29.2 percent. Acceptance Rate: 23.0068
# Finished 29.4 percent. Acceptance Rate: 22.9864
# Finished 29.6 percent. Acceptance Rate: 22.9595
# Finished 29.8 percent. Acceptance Rate: 22.9463
# Finished 30 percent. Acceptance Rate: 22.98
# Finished 30.2 percent. Acceptance Rate: 22.9934
# Finished 30.4 percent. Acceptance Rate: 23.0263
# Finished 30.6 percent. Acceptance Rate: 23
# Finished 30.8 percent. Acceptance Rate: 23.026
# Finished 31 percent. Acceptance Rate: 23.0065
# Finished 31.2 percent. Acceptance Rate: 22.9936
# Finished 31.4 percent. Acceptance Rate: 22.9809
# Finished 31.6 percent. Acceptance Rate: 23.0127
# Finished 31.8 percent. Acceptance Rate: 23.044
# Finished 32 percent. Acceptance Rate: 23.0187
# Finished 32.2 percent. Acceptance Rate: 23.0435
# Finished 32.4 percent. Acceptance Rate: 23.0864
# Finished 32.6 percent. Acceptance Rate: 23.0982
# Finished 32.8 percent. Acceptance Rate: 23.1524
# Finished 33 percent. Acceptance Rate: 23.1697
# Finished 33.2 percent. Acceptance Rate: 23.1446
# Finished 33.4 percent. Acceptance Rate: 23.1437
# Finished 33.6 percent. Acceptance Rate: 23.1131
# Finished 33.8 percent. Acceptance Rate: 23.1893
# Finished 34 percent. Acceptance Rate: 23.1882
# Finished 34.2 percent. Acceptance Rate: 23.1579
# Finished 34.4 percent. Acceptance Rate: 23.1221
# Finished 34.6 percent. Acceptance Rate: 23.0809
# Finished 34.8 percent. Acceptance Rate: 23.0805
# Finished 35 percent. Acceptance Rate: 23.0743
# Finished 35.2 percent. Acceptance Rate: 23.0398
# Finished 35.4 percent. Acceptance Rate: 23.0169
# Finished 35.6 percent. Acceptance Rate: 22.9831
# Finished 35.8 percent. Acceptance Rate: 22.9944
# Finished 36 percent. Acceptance Rate: 23.0111
# Finished 36.2 percent. Acceptance Rate: 23.0387
# Finished 36.4 percent. Acceptance Rate: 23.0275
# Finished 36.6 percent. Acceptance Rate: 23.0437
# Finished 36.8 percent. Acceptance Rate: 23.0109
# Finished 37 percent. Acceptance Rate: 22.9676
# Finished 37.2 percent. Acceptance Rate: 22.9247
# Finished 37.4 percent. Acceptance Rate: 22.9198
# Finished 37.6 percent. Acceptance Rate: 22.8936
# Finished 37.8 percent. Acceptance Rate: 22.8519
# Finished 38 percent. Acceptance Rate: 22.8211
# Finished 38.2 percent. Acceptance Rate: 22.8168
# Finished 38.4 percent. Acceptance Rate: 22.8177
# Finished 38.6 percent. Acceptance Rate: 22.8187
# Finished 38.8 percent. Acceptance Rate: 22.8041
# Finished 39 percent. Acceptance Rate: 22.7949
# Finished 39.2 percent. Acceptance Rate: 22.8571
# Finished 39.4 percent. Acceptance Rate: 22.8782
# Finished 39.6 percent. Acceptance Rate: 22.899
# Finished 39.8 percent. Acceptance Rate: 22.9146
# Finished 40 percent. Acceptance Rate: 22.89
# Finished 40.2 percent. Acceptance Rate: 22.8756
# Finished 40.4 percent. Acceptance Rate: 22.8861
# Finished 40.6 percent. Acceptance Rate: 22.9113
# Finished 40.8 percent. Acceptance Rate: 22.9461
# Finished 41 percent. Acceptance Rate: 22.9512
# Finished 41.2 percent. Acceptance Rate: 22.9272
# Finished 41.4 percent. Acceptance Rate: 22.9372
# Finished 41.6 percent. Acceptance Rate: 22.9279
# Finished 41.8 percent. Acceptance Rate: 22.9474
# Finished 42 percent. Acceptance Rate: 22.9476
# Finished 42.2 percent. Acceptance Rate: 22.9479
# Finished 42.4 percent. Acceptance Rate: 22.9575
# Finished 42.6 percent. Acceptance Rate: 22.9718
# Finished 42.8 percent. Acceptance Rate: 22.9626
# Finished 43 percent. Acceptance Rate: 22.9395
# Finished 43.2 percent. Acceptance Rate: 22.9722
# Finished 43.4 percent. Acceptance Rate: 23
# Finished 43.6 percent. Acceptance Rate: 23.0092
# Finished 43.8 percent. Acceptance Rate: 23.0228
# Finished 44 percent. Acceptance Rate: 23.0591
# Finished 44.2 percent. Acceptance Rate: 23.0362
# Finished 44.4 percent. Acceptance Rate: 23.0135
# Finished 44.6 percent. Acceptance Rate: 23.0359
# Finished 44.8 percent. Acceptance Rate: 23.0357
# Finished 45 percent. Acceptance Rate: 23.0622
# Finished 45.2 percent. Acceptance Rate: 23.0752
# Finished 45.4 percent. Acceptance Rate: 23.0705
# Finished 45.6 percent. Acceptance Rate: 23.0702
# Finished 45.8 percent. Acceptance Rate: 23.0742
# Finished 46 percent. Acceptance Rate: 23.1
# Finished 46.2 percent. Acceptance Rate: 23.0909
# Finished 46.4 percent. Acceptance Rate: 23.0733
# Finished 46.6 percent. Acceptance Rate: 23.0773
# Finished 46.8 percent. Acceptance Rate: 23.0556
# Finished 47 percent. Acceptance Rate: 23.0851
# Finished 47.2 percent. Acceptance Rate: 23.072
# Finished 47.4 percent. Acceptance Rate: 23.0549
# Finished 47.6 percent. Acceptance Rate: 23.0378
# Finished 47.8 percent. Acceptance Rate: 23.0042
# Finished 48 percent. Acceptance Rate: 22.9958
# Finished 48.2 percent. Acceptance Rate: 23
# Finished 48.4 percent. Acceptance Rate: 22.9835
# Finished 48.6 percent. Acceptance Rate: 22.9712
# Finished 48.8 percent. Acceptance Rate: 22.9713
# Finished 49 percent. Acceptance Rate: 22.9551
# Finished 49.2 percent. Acceptance Rate: 22.9593
# Finished 49.4 percent. Acceptance Rate: 23
# Finished 49.6 percent. Acceptance Rate: 22.996
# Finished 49.8 percent. Acceptance Rate: 22.996
# Finished 50 percent. Acceptance Rate: 23.004
# Finished 50.2 percent. Acceptance Rate: 22.9681
# Finished 50.4 percent. Acceptance Rate: 22.996
# Finished 50.6 percent. Acceptance Rate: 23.0277
# Finished 50.8 percent. Acceptance Rate: 23.0118
# Finished 51 percent. Acceptance Rate: 23
# Finished 51.2 percent. Acceptance Rate: 22.9805
# Finished 51.4 percent. Acceptance Rate: 22.9922
# Finished 51.6 percent. Acceptance Rate: 22.9922
# Finished 51.8 percent. Acceptance Rate: 23.0116
# Finished 52 percent. Acceptance Rate: 22.9808
# Finished 52.2 percent. Acceptance Rate: 22.9502
# Finished 52.4 percent. Acceptance Rate: 22.9427
# Finished 52.6 percent. Acceptance Rate: 22.9392
# Finished 52.8 percent. Acceptance Rate: 22.947
# Finished 53 percent. Acceptance Rate: 22.9283
# Finished 53.2 percent. Acceptance Rate: 22.9361
# Finished 53.4 percent. Acceptance Rate: 22.9251
# Finished 53.6 percent. Acceptance Rate: 22.9254
# Finished 53.8 percent. Acceptance Rate: 22.9331
# Finished 54 percent. Acceptance Rate: 22.9259
# Finished 54.2 percent. Acceptance Rate: 22.9151
# Finished 54.4 percent. Acceptance Rate: 22.9265
# Finished 54.6 percent. Acceptance Rate: 22.9011
# Finished 54.8 percent. Acceptance Rate: 22.9124
# Finished 55 percent. Acceptance Rate: 22.92
# Finished 55.2 percent. Acceptance Rate: 22.9239
# Finished 55.4 percent. Acceptance Rate: 22.8953
# Finished 55.6 percent. Acceptance Rate: 22.9137
# Finished 55.8 percent. Acceptance Rate: 22.9319
# Finished 56 percent. Acceptance Rate: 22.9286
# Finished 56.2 percent. Acceptance Rate: 22.9431
# Finished 56.4 percent. Acceptance Rate: 22.9326
# Finished 56.6 percent. Acceptance Rate: 22.9258
# Finished 56.8 percent. Acceptance Rate: 22.8979
# Finished 57 percent. Acceptance Rate: 22.9123
# Finished 57.2 percent. Acceptance Rate: 22.9021
# Finished 57.4 percent. Acceptance Rate: 22.8746
# Finished 57.6 percent. Acceptance Rate: 22.8889
# Finished 57.8 percent. Acceptance Rate: 22.9135
# Finished 58 percent. Acceptance Rate: 22.9345
# Finished 58.2 percent. Acceptance Rate: 22.9863
# Finished 58.4 percent. Acceptance Rate: 22.9932
# Finished 58.6 percent. Acceptance Rate: 23.041
# Finished 58.8 percent. Acceptance Rate: 23.0476
# Finished 59 percent. Acceptance Rate: 23.0712
# Finished 59.2 percent. Acceptance Rate: 23.0541
# Finished 59.4 percent. Acceptance Rate: 23.0471
# Finished 59.6 percent. Acceptance Rate: 23.0336
# Finished 59.8 percent. Acceptance Rate: 23.0334
# Finished 60 percent. Acceptance Rate: 23.0433
# Finished 60.2 percent. Acceptance Rate: 23.0498
# Finished 60.4 percent. Acceptance Rate: 23.0298
# Finished 60.6 percent. Acceptance Rate: 23.0165
# Finished 60.8 percent. Acceptance Rate: 23
# Finished 61 percent. Acceptance Rate: 22.9902
# Finished 61.2 percent. Acceptance Rate: 22.9608
# Finished 61.4 percent. Acceptance Rate: 22.9544
# Finished 61.6 percent. Acceptance Rate: 22.9416
# Finished 61.8 percent. Acceptance Rate: 22.945
# Finished 62 percent. Acceptance Rate: 22.9355
# Finished 62.2 percent. Acceptance Rate: 22.9293
# Finished 62.4 percent. Acceptance Rate: 22.9103
# Finished 62.6 percent. Acceptance Rate: 22.9137
# Finished 62.8 percent. Acceptance Rate: 22.9299
# Finished 63 percent. Acceptance Rate: 22.9556
# Finished 63.2 percent. Acceptance Rate: 22.981
# Finished 63.4 percent. Acceptance Rate: 22.9937
# Finished 63.6 percent. Acceptance Rate: 23
# Finished 63.8 percent. Acceptance Rate: 22.9937
# Finished 64 percent. Acceptance Rate: 22.9844
# Finished 64.2 percent. Acceptance Rate: 22.9844
# Finished 64.4 percent. Acceptance Rate: 22.9845
# Finished 64.6 percent. Acceptance Rate: 22.9969
# Finished 64.8 percent. Acceptance Rate: 22.9691
# Finished 65 percent. Acceptance Rate: 22.9754
# Finished 65.2 percent. Acceptance Rate: 22.9755
# Finished 65.4 percent. Acceptance Rate: 22.9786
# Finished 65.6 percent. Acceptance Rate: 23.0122
# Finished 65.8 percent. Acceptance Rate: 23.0061
# Finished 66 percent. Acceptance Rate: 23.0061
# Finished 66.2 percent. Acceptance Rate: 23.0121
# Finished 66.4 percent. Acceptance Rate: 23.009
# Finished 66.6 percent. Acceptance Rate: 22.997
# Finished 66.8 percent. Acceptance Rate: 23.003
# Finished 67 percent. Acceptance Rate: 23.0119
# Finished 67.2 percent. Acceptance Rate: 23.0387
# Finished 67.4 percent. Acceptance Rate: 23.0564
# Finished 67.6 percent. Acceptance Rate: 23.0562
# Finished 67.8 percent. Acceptance Rate: 23.0413
# Finished 68 percent. Acceptance Rate: 23.0265
# Finished 68.2 percent. Acceptance Rate: 23.0293
# Finished 68.4 percent. Acceptance Rate: 23.0351
# Finished 68.6 percent. Acceptance Rate: 23.0262
# Finished 68.8 percent. Acceptance Rate: 23.0349
# Finished 69 percent. Acceptance Rate: 23.058
# Finished 69.2 percent. Acceptance Rate: 23.0549
# Finished 69.4 percent. Acceptance Rate: 23.0288
# Finished 69.6 percent. Acceptance Rate: 23.0029
# Finished 69.8 percent. Acceptance Rate: 22.9971
# Finished 70 percent. Acceptance Rate: 22.9771
# Finished 70.2 percent. Acceptance Rate: 22.9858
# Finished 70.4 percent. Acceptance Rate: 22.9915
# Finished 70.6 percent. Acceptance Rate: 23.0085
# Finished 70.8 percent. Acceptance Rate: 23.0141
# Finished 71 percent. Acceptance Rate: 23.0197
# Finished 71.2 percent. Acceptance Rate: 23.0169
# Finished 71.4 percent. Acceptance Rate: 23.0252
# Finished 71.6 percent. Acceptance Rate: 23.0363
# Finished 71.8 percent. Acceptance Rate: 23.0195
# Finished 72 percent. Acceptance Rate: 23.0306
# Finished 72.2 percent. Acceptance Rate: 23.0471
# Finished 72.4 percent. Acceptance Rate: 23.0663
# Finished 72.6 percent. Acceptance Rate: 23.0441
# Finished 72.8 percent. Acceptance Rate: 23.0495
# Finished 73 percent. Acceptance Rate: 23.0301
# Finished 73.2 percent. Acceptance Rate: 23.0219
# Finished 73.4 percent. Acceptance Rate: 23
# Finished 73.6 percent. Acceptance Rate: 22.9946
# Finished 73.8 percent. Acceptance Rate: 23
# Finished 74 percent. Acceptance Rate: 23.0027
# Finished 74.2 percent. Acceptance Rate: 22.9919
# Finished 74.4 percent. Acceptance Rate: 22.9812
# Finished 74.6 percent. Acceptance Rate: 22.9678
# Finished 74.8 percent. Acceptance Rate: 22.9759
# Finished 75 percent. Acceptance Rate: 22.9733
# Finished 75.2 percent. Acceptance Rate: 22.984
# Finished 75.4 percent. Acceptance Rate: 23
# Finished 75.6 percent. Acceptance Rate: 23.0132
# Finished 75.8 percent. Acceptance Rate: 23.0449
# Finished 76 percent. Acceptance Rate: 23.0421
# Finished 76.2 percent. Acceptance Rate: 23.042
# Finished 76.4 percent. Acceptance Rate: 23.034
# Finished 76.6 percent. Acceptance Rate: 23.0313
# Finished 76.8 percent. Acceptance Rate: 23.0312
# Finished 77 percent. Acceptance Rate: 23.0494
# Finished 77.2 percent. Acceptance Rate: 23.0518
# Finished 77.4 percent. Acceptance Rate: 23.0543
# Finished 77.6 percent. Acceptance Rate: 23.0515
# Finished 77.8 percent. Acceptance Rate: 23.0334
# Finished 78 percent. Acceptance Rate: 23.0308
# Finished 78.2 percent. Acceptance Rate: 23.0486
# Finished 78.4 percent. Acceptance Rate: 23.0459
# Finished 78.6 percent. Acceptance Rate: 23.0407
# Finished 78.8 percent. Acceptance Rate: 23.0305
# Finished 79 percent. Acceptance Rate: 23.038
# Finished 79.2 percent. Acceptance Rate: 23.0227
# Finished 79.4 percent. Acceptance Rate: 23.005
# Finished 79.6 percent. Acceptance Rate: 23.0075
# Finished 79.8 percent. Acceptance Rate: 23.01
# Finished 80 percent. Acceptance Rate: 23.0025
# Finished 80.2 percent. Acceptance Rate: 23.0025
# Finished 80.4 percent. Acceptance Rate: 23.0075
# Finished 80.6 percent. Acceptance Rate: 23.005
# Finished 80.8 percent. Acceptance Rate: 23.005
# Finished 81 percent. Acceptance Rate: 23.0074
# Finished 81.2 percent. Acceptance Rate: 23.0049
# Finished 81.4 percent. Acceptance Rate: 23.0074
# Finished 81.6 percent. Acceptance Rate: 23.0074
# Finished 81.8 percent. Acceptance Rate: 22.9951
# Finished 82 percent. Acceptance Rate: 22.9902
# Finished 82.2 percent. Acceptance Rate: 22.9927
# Finished 82.4 percent. Acceptance Rate: 22.9927
# Finished 82.6 percent. Acceptance Rate: 22.9976
# Finished 82.8 percent. Acceptance Rate: 22.9855
# Finished 83 percent. Acceptance Rate: 22.9663
# Finished 83.2 percent. Acceptance Rate: 22.9639
# Finished 83.4 percent. Acceptance Rate: 22.9592
# Finished 83.6 percent. Acceptance Rate: 22.9545
# Finished 83.8 percent. Acceptance Rate: 22.9403
# Finished 84 percent. Acceptance Rate: 22.9524
# Finished 84.2 percent. Acceptance Rate: 22.9572
# Finished 84.4 percent. Acceptance Rate: 22.9431
# Finished 84.6 percent. Acceptance Rate: 22.9433
# Finished 84.8 percent. Acceptance Rate: 22.941
# Finished 85 percent. Acceptance Rate: 22.9482
# Finished 85.2 percent. Acceptance Rate: 22.946
# Finished 85.4 percent. Acceptance Rate: 22.9344
# Finished 85.6 percent. Acceptance Rate: 22.9276
# Finished 85.8 percent. Acceptance Rate: 22.9091
# Finished 86 percent. Acceptance Rate: 22.8907
# Finished 86.2 percent. Acceptance Rate: 22.9095
# Finished 86.4 percent. Acceptance Rate: 22.9167
# Finished 86.6 percent. Acceptance Rate: 22.9215
# Finished 86.8 percent. Acceptance Rate: 22.9124
# Finished 87 percent. Acceptance Rate: 22.908
# Finished 87.2 percent. Acceptance Rate: 22.8899
# Finished 87.4 percent. Acceptance Rate: 22.9039
# Finished 87.6 percent. Acceptance Rate: 22.911
# Finished 87.8 percent. Acceptance Rate: 22.9112
# Finished 88 percent. Acceptance Rate: 22.9091
# Finished 88.2 percent. Acceptance Rate: 22.9025
# Finished 88.4 percent. Acceptance Rate: 22.914
# Finished 88.6 percent. Acceptance Rate: 22.9255
# Finished 88.8 percent. Acceptance Rate: 22.9414
# Finished 89 percent. Acceptance Rate: 22.9596
# Finished 89.2 percent. Acceptance Rate: 22.9686
# Finished 89.4 percent. Acceptance Rate: 22.9597
# Finished 89.6 percent. Acceptance Rate: 22.9487
# Finished 89.8 percent. Acceptance Rate: 22.9198
# Finished 90 percent. Acceptance Rate: 22.92
# Finished 90.2 percent. Acceptance Rate: 22.9246
# Finished 90.4 percent. Acceptance Rate: 22.9381
# Finished 90.6 percent. Acceptance Rate: 22.9448
# Finished 90.8 percent. Acceptance Rate: 22.9559
# Finished 91 percent. Acceptance Rate: 22.9604
# Finished 91.2 percent. Acceptance Rate: 22.9803
# Finished 91.4 percent. Acceptance Rate: 22.9869
# Finished 91.6 percent. Acceptance Rate: 22.9716
# Finished 91.8 percent. Acceptance Rate: 22.9586
# Finished 92 percent. Acceptance Rate: 22.9565
# Finished 92.2 percent. Acceptance Rate: 22.9458
# Finished 92.4 percent. Acceptance Rate: 22.9524
# Finished 92.6 percent. Acceptance Rate: 22.9525
# Finished 92.8 percent. Acceptance Rate: 22.9332
# Finished 93 percent. Acceptance Rate: 22.9097
# Finished 93.2 percent. Acceptance Rate: 22.9013
# Finished 93.4 percent. Acceptance Rate: 22.9058
# Finished 93.6 percent. Acceptance Rate: 22.9081
# Finished 93.8 percent. Acceptance Rate: 22.9211
# Finished 94 percent. Acceptance Rate: 22.9298
# Finished 94.2 percent. Acceptance Rate: 22.913
# Finished 94.4 percent. Acceptance Rate: 22.9153
# Finished 94.6 percent. Acceptance Rate: 22.9027
# Finished 94.8 percent. Acceptance Rate: 22.9219
# Finished 95 percent. Acceptance Rate: 22.9242
# Finished 95.2 percent. Acceptance Rate: 22.9097
# Finished 95.4 percent. Acceptance Rate: 22.914
# Finished 95.6 percent. Acceptance Rate: 22.9184
# Finished 95.8 percent. Acceptance Rate: 22.9269
# Finished 96 percent. Acceptance Rate: 22.9167
# Finished 96.2 percent. Acceptance Rate: 22.9085
# Finished 96.4 percent. Acceptance Rate: 22.9025
# Finished 96.6 percent. Acceptance Rate: 22.9068
# Finished 96.8 percent. Acceptance Rate: 22.8884
# Finished 97 percent. Acceptance Rate: 22.8619
# Finished 97.2 percent. Acceptance Rate: 22.8621
# Finished 97.4 percent. Acceptance Rate: 22.8686
# Finished 97.6 percent. Acceptance Rate: 22.8566
# Finished 97.8 percent. Acceptance Rate: 22.865
# Finished 98 percent. Acceptance Rate: 22.8735
# Finished 98.2 percent. Acceptance Rate: 22.8676
# Finished 98.4 percent. Acceptance Rate: 22.8699
# Finished 98.6 percent. Acceptance Rate: 22.8722
# Finished 98.8 percent. Acceptance Rate: 22.8603
# Finished 99 percent. Acceptance Rate: 22.8525
# Finished 99.2 percent. Acceptance Rate: 22.8508
# Finished 99.4 percent. Acceptance Rate: 22.8612
# Finished 99.6 percent. Acceptance Rate: 22.8635
# Finished 99.8 percent. Acceptance Rate: 22.8617

# %%
triangle.corner(sampler.chain)

# %% [markdown]
# ## Exercise 2d ##
# Run a simple MCMC, using the sampler you wrote yesterday, to discover the injected value of:
#  * white noise
#  * PSD amplitudes
#
# Make a plot of the power spectrum (use np.percentile)

# %%
# Run a simple MCMC on the power-law
def loglik(x):
    return sp_loglikelihood(psr, 10**x[0], 10**x[1:])

def logprior(x):
    rv = 0.0
    xmin, xmax = np.ones_like(x), np.ones_like(x)
    
    xmin[0], xmax[0] = -10.0, -4.0
    xmin[1:] = -18.0
    xmax[1:] = -12.0
    
    if np.any(x < xmin) or np.any(x > xmax):
        rv = -np.inf
        
    return rv

psd0 = np.ones(psr.Fmat.shape[1]/2) * -14.0
p0 = np.append([-7.0], psd0)
sigmas = 0.1 * np.ones_like(p0)
sampler = smcmc.SimpleMCMC(loglik, logprior, sigmas)

# %%
sampler.sample(p0, 50000)
# Out:
# Finished 0.2 percent. Acceptance Rate: 40
# Finished 0.4 percent. Acceptance Rate: 34.5
# Finished 0.6 percent. Acceptance Rate: 31.6667
# Finished 0.8 percent. Acceptance Rate: 31
# Finished 1 percent. Acceptance Rate: 28.6
# Finished 1.2 percent. Acceptance Rate: 29.5
# Finished 1.4 percent. Acceptance Rate: 28.1429
# Finished 1.6 percent. Acceptance Rate: 27.375
# Finished 1.8 percent. Acceptance Rate: 27.8889
# Finished 2 percent. Acceptance Rate: 27.7
# Finished 2.2 percent. Acceptance Rate: 27.2727
# Finished 2.4 percent. Acceptance Rate: 27.0833
# Finished 2.6 percent. Acceptance Rate: 27.3077
# Finished 2.8 percent. Acceptance Rate: 27.2143
# Finished 3 percent. Acceptance Rate: 26.7333
# Finished 3.2 percent. Acceptance Rate: 25.9375
# Finished 3.4 percent. Acceptance Rate: 26.2353
# Finished 3.6 percent. Acceptance Rate: 25.6667
# Finished 3.8 percent. Acceptance Rate: 25.7895
# Finished 4 percent. Acceptance Rate: 25.7
# Finished 4.2 percent. Acceptance Rate: 25.1905
# Finished 4.4 percent. Acceptance Rate: 24.8636
# Finished 4.6 percent. Acceptance Rate: 24.8261
# Finished 4.8 percent. Acceptance Rate: 24.5
# Finished 5 percent. Acceptance Rate: 24.04
# Finished 5.2 percent. Acceptance Rate: 23.6538
# Finished 5.4 percent. Acceptance Rate: 23.8148
# Finished 5.6 percent. Acceptance Rate: 23.6071
# Finished 5.8 percent. Acceptance Rate: 23.4483
# Finished 6 percent. Acceptance Rate: 23.5333
# Finished 6.2 percent. Acceptance Rate: 23.7097
# Finished 6.4 percent. Acceptance Rate: 23.4688
# Finished 6.6 percent. Acceptance Rate: 23.3333
# Finished 6.8 percent. Acceptance Rate: 23.1765
# Finished 7 percent. Acceptance Rate: 23.2571
# Finished 7.2 percent. Acceptance Rate: 23.2222
# Finished 7.4 percent. Acceptance Rate: 23.1351
# Finished 7.6 percent. Acceptance Rate: 22.8421
# Finished 7.8 percent. Acceptance Rate: 22.8718
# Finished 8 percent. Acceptance Rate: 22.925
# Finished 8.2 percent. Acceptance Rate: 22.6829
# Finished 8.4 percent. Acceptance Rate: 22.6667
# Finished 8.6 percent. Acceptance Rate: 23
# Finished 8.8 percent. Acceptance Rate: 22.8636
# Finished 9 percent. Acceptance Rate: 22.4889
# Finished 9.2 percent. Acceptance Rate: 22.5
# Finished 9.4 percent. Acceptance Rate: 22.383
# Finished 9.6 percent. Acceptance Rate: 22.25
# Finished 9.8 percent. Acceptance Rate: 22.1837
# Finished 10 percent. Acceptance Rate: 22.12
# Finished 10.2 percent. Acceptance Rate: 21.8235
# Finished 10.4 percent. Acceptance Rate: 21.7115
# Finished 10.6 percent. Acceptance Rate: 21.5849
# Finished 10.8 percent. Acceptance Rate: 21.6852
# Finished 11 percent. Acceptance Rate: 21.6727
# Finished 11.2 percent. Acceptance Rate: 21.5893
# Finished 11.4 percent. Acceptance Rate: 21.6316
# Finished 11.6 percent. Acceptance Rate: 21.7586
# Finished 11.8 percent. Acceptance Rate: 21.7797
# Finished 12 percent. Acceptance Rate: 21.65
# Finished 12.2 percent. Acceptance Rate: 21.541
# Finished 12.4 percent. Acceptance Rate: 21.5323
# Finished 12.6 percent. Acceptance Rate: 21.4444
# Finished 12.8 percent. Acceptance Rate: 21.3594
# Finished 13 percent. Acceptance Rate: 21.2923
# Finished 13.2 percent. Acceptance Rate: 21.197
# Finished 13.4 percent. Acceptance Rate: 21.1343
# Finished 13.6 percent. Acceptance Rate: 21.1324
# Finished 13.8 percent. Acceptance Rate: 21.1159
# Finished 14 percent. Acceptance Rate: 21.1714
# Finished 14.2 percent. Acceptance Rate: 21.2254
# Finished 14.4 percent. Acceptance Rate: 21.2917
# Finished 14.6 percent. Acceptance Rate: 21.2877
# Finished 14.8 percent. Acceptance Rate: 21.2703
# Finished 15 percent. Acceptance Rate: 21.3067
# Finished 15.2 percent. Acceptance Rate: 21.1974
# Finished 15.4 percent. Acceptance Rate: 21.1948
# Finished 15.6 percent. Acceptance Rate: 21.2821
# Finished 15.8 percent. Acceptance Rate: 21.2658
# Finished 16 percent. Acceptance Rate: 21.2875
# Finished 16.2 percent. Acceptance Rate: 21.1975
# Finished 16.4 percent. Acceptance Rate: 21.0854
# Finished 16.6 percent. Acceptance Rate: 21.0602
# Finished 16.8 percent. Acceptance Rate: 21.1071
# Finished 17 percent. Acceptance Rate: 21.1059
# Finished 17.2 percent. Acceptance Rate: 21.0465
# Finished 17.4 percent. Acceptance Rate: 20.931
# Finished 17.6 percent. Acceptance Rate: 20.8523
# Finished 17.8 percent. Acceptance Rate: 20.8202
# Finished 18 percent. Acceptance Rate: 20.8111
# Finished 18.2 percent. Acceptance Rate: 20.8242
# Finished 18.4 percent. Acceptance Rate: 20.8478
# Finished 18.6 percent. Acceptance Rate: 20.8495
# Finished 18.8 percent. Acceptance Rate: 20.8723
# Finished 19 percent. Acceptance Rate: 20.9263
# Finished 19.2 percent. Acceptance Rate: 20.8542
# Finished 19.4 percent. Acceptance Rate: 20.8041
# Finished 19.6 percent. Acceptance Rate: 20.8469
# Finished 19.8 percent. Acceptance Rate: 20.7677
# Finished 20 percent. Acceptance Rate: 20.86
# Finished 20.2 percent. Acceptance Rate: 20.802
# Finished 20.4 percent. Acceptance Rate: 20.7941
# Finished 20.6 percent. Acceptance Rate: 20.8155
# Finished 20.8 percent. Acceptance Rate: 20.9135
# Finished 21 percent. Acceptance Rate: 20.8857
# Finished 21.2 percent. Acceptance Rate: 20.8962
# Finished 21.4 percent. Acceptance Rate: 20.9065
# Finished 21.6 percent. Acceptance Rate: 20.9352
# Finished 21.8 percent. Acceptance Rate: 20.8991
# Finished 22 percent. Acceptance Rate: 20.9
# Finished 22.2 percent. Acceptance Rate: 20.8649
# Finished 22.4 percent. Acceptance Rate: 20.9554
# Finished 22.6 percent. Acceptance Rate: 20.9558
# Finished 22.8 percent. Acceptance Rate: 20.9825
# Finished 23 percent. Acceptance Rate: 20.9826
# Finished 23.2 percent. Acceptance Rate: 20.9655
# Finished 23.4 percent. Acceptance Rate: 21
# Finished 23.6 percent. Acceptance Rate: 21.0254
# Finished 23.8 percent. Acceptance Rate: 21.0084
# Finished 24 percent. Acceptance Rate: 20.9917
# Finished 24.2 percent. Acceptance Rate: 21.0083
# Finished 24.4 percent. Acceptance Rate: 21.0164
# Finished 24.6 percent. Acceptance Rate: 21.0163
# Finished 24.8 percent. Acceptance Rate: 21.0081
# Finished 25 percent. Acceptance Rate: 21.072
# Finished 25.2 percent. Acceptance Rate: 21.0873
# Finished 25.4 percent. Acceptance Rate: 21.0945
# Finished 25.6 percent. Acceptance Rate: 21.1328
# Finished 25.8 percent. Acceptance Rate: 21.124
# Finished 26 percent. Acceptance Rate: 21.2
# Finished 26.2 percent. Acceptance Rate: 21.2137
# Finished 26.4 percent. Acceptance Rate: 21.197
# Finished 26.6 percent. Acceptance Rate: 21.203
# Finished 26.8 percent. Acceptance Rate: 21.1866
# Finished 27 percent. Acceptance Rate: 21.2667
# Finished 27.2 percent. Acceptance Rate: 21.2721
# Finished 27.4 percent. Acceptance Rate: 21.219
# Finished 27.6 percent. Acceptance Rate: 21.2319
# Finished 27.8 percent. Acceptance Rate: 21.2374
# Finished 28 percent. Acceptance Rate: 21.2214
# Finished 28.2 percent. Acceptance Rate: 21.2199
# Finished 28.4 percent. Acceptance Rate: 21.3028
# Finished 28.6 percent. Acceptance Rate: 21.3427
# Finished 28.8 percent. Acceptance Rate: 21.3056
# Finished 29 percent. Acceptance Rate: 21.3103
# Finished 29.2 percent. Acceptance Rate: 21.274
# Finished 29.4 percent. Acceptance Rate: 21.2517
# Finished 29.6 percent. Acceptance Rate: 21.2095
# Finished 29.8 percent. Acceptance Rate: 21.2349
# Finished 30 percent. Acceptance Rate: 21.24
# Finished 30.2 percent. Acceptance Rate: 21.3046
# Finished 30.4 percent. Acceptance Rate: 21.3224
# Finished 30.6 percent. Acceptance Rate: 21.2876
# Finished 30.8 percent. Acceptance Rate: 21.2922
# Finished 31 percent. Acceptance Rate: 21.3419
# Finished 31.2 percent. Acceptance Rate: 21.3526
# Finished 31.4 percent. Acceptance Rate: 21.3822
# Finished 31.6 percent. Acceptance Rate: 21.3165
# Finished 31.8 percent. Acceptance Rate: 21.3899
# Finished 32 percent. Acceptance Rate: 21.4312
# Finished 32.2 percent. Acceptance Rate: 21.441
# Finished 32.4 percent. Acceptance Rate: 21.3951
# Finished 32.6 percent. Acceptance Rate: 21.411
# Finished 32.8 percent. Acceptance Rate: 21.4085
# Finished 33 percent. Acceptance Rate: 21.3879
# Finished 33.2 percent. Acceptance Rate: 21.4096
# Finished 33.4 percent. Acceptance Rate: 21.3832
# Finished 33.6 percent. Acceptance Rate: 21.3869
# Finished 33.8 percent. Acceptance Rate: 21.4556
# Finished 34 percent. Acceptance Rate: 21.4471
# Finished 34.2 percent. Acceptance Rate: 21.4444
# Finished 34.4 percent. Acceptance Rate: 21.3721
# Finished 34.6 percent. Acceptance Rate: 21.3757
# Finished 34.8 percent. Acceptance Rate: 21.3391
# Finished 35 percent. Acceptance Rate: 21.3771
# Finished 35.2 percent. Acceptance Rate: 21.3807
# Finished 35.4 percent. Acceptance Rate: 21.4068
# Finished 35.6 percent. Acceptance Rate: 21.4045
# Finished 35.8 percent. Acceptance Rate: 21.4134
# Finished 36 percent. Acceptance Rate: 21.4
# Finished 36.2 percent. Acceptance Rate: 21.3812
# Finished 36.4 percent. Acceptance Rate: 21.3791
# Finished 36.6 percent. Acceptance Rate: 21.3224
# Finished 36.8 percent. Acceptance Rate: 21.2772
# Finished 37 percent. Acceptance Rate: 21.2324
# Finished 37.2 percent. Acceptance Rate: 21.2151
# Finished 37.4 percent. Acceptance Rate: 21.1711
# Finished 37.6 percent. Acceptance Rate: 21.133
# Finished 37.8 percent. Acceptance Rate: 21.1005
# Finished 38 percent. Acceptance Rate: 21.1316
# Finished 38.2 percent. Acceptance Rate: 21.1675
# Finished 38.4 percent. Acceptance Rate: 21.125
# Finished 38.6 percent. Acceptance Rate: 21.1451
# Finished 38.8 percent. Acceptance Rate: 21.0979
# Finished 39 percent. Acceptance Rate: 21.0872
# Finished 39.2 percent. Acceptance Rate: 21.0714
# Finished 39.4 percent. Acceptance Rate: 21.1015
# Finished 39.6 percent. Acceptance Rate: 21.0859
# Finished 39.8 percent. Acceptance Rate: 21.1156
# Finished 40 percent. Acceptance Rate: 21.12
# Finished 40.2 percent. Acceptance Rate: 21.1343
# Finished 40.4 percent. Acceptance Rate: 21.1683
# Finished 40.6 percent. Acceptance Rate: 21.1675
# Finished 40.8 percent. Acceptance Rate: 21.152
# Finished 41 percent. Acceptance Rate: 21.0927
# Finished 41.2 percent. Acceptance Rate: 21.0825
# Finished 41.4 percent. Acceptance Rate: 21.0725
# Finished 41.6 percent. Acceptance Rate: 21.0769
# Finished 41.8 percent. Acceptance Rate: 21.0957
# Finished 42 percent. Acceptance Rate: 21.0476
# Finished 42.2 percent. Acceptance Rate: 21.0616
# Finished 42.4 percent. Acceptance Rate: 21.0613
# Finished 42.6 percent. Acceptance Rate: 21.0329
# Finished 42.8 percent. Acceptance Rate: 20.9907
# Finished 43 percent. Acceptance Rate: 21
# Finished 43.2 percent. Acceptance Rate: 20.9815
# Finished 43.4 percent. Acceptance Rate: 21.0046
# Finished 43.6 percent. Acceptance Rate: 20.9908
# Finished 43.8 percent. Acceptance Rate: 20.9954
# Finished 44 percent. Acceptance Rate: 20.9727
# Finished 44.2 percent. Acceptance Rate: 20.9638
# Finished 44.4 percent. Acceptance Rate: 21.0045
# Finished 44.6 percent. Acceptance Rate: 21.0359
# Finished 44.8 percent. Acceptance Rate: 21.0446
# Finished 45 percent. Acceptance Rate: 21.0489
# Finished 45.2 percent. Acceptance Rate: 21.0575
# Finished 45.4 percent. Acceptance Rate: 21.0485
# Finished 45.6 percent. Acceptance Rate: 21.0526
# Finished 45.8 percent. Acceptance Rate: 21.083
# Finished 46 percent. Acceptance Rate: 21.1043
# Finished 46.2 percent. Acceptance Rate: 21.0823
# Finished 46.4 percent. Acceptance Rate: 21.0603
# Finished 46.6 percent. Acceptance Rate: 21.0215
# Finished 46.8 percent. Acceptance Rate: 21.0214
# Finished 47 percent. Acceptance Rate: 21.0255
# Finished 47.2 percent. Acceptance Rate: 21.0508
# Finished 47.4 percent. Acceptance Rate: 21.0253
# Finished 47.6 percent. Acceptance Rate: 21.0336
# Finished 47.8 percent. Acceptance Rate: 21.0126
# Finished 48 percent. Acceptance Rate: 20.9875
# Finished 48.2 percent. Acceptance Rate: 20.9917
# Finished 48.4 percent. Acceptance Rate: 20.9876
# Finished 48.6 percent. Acceptance Rate: 20.9753
# Finished 48.8 percent. Acceptance Rate: 20.959
# Finished 49 percent. Acceptance Rate: 20.9224
# Finished 49.2 percent. Acceptance Rate: 20.8984
# Finished 49.4 percent. Acceptance Rate: 20.9069
# Finished 49.6 percent. Acceptance Rate: 20.9234
# Finished 49.8 percent. Acceptance Rate: 20.9277
# Finished 50 percent. Acceptance Rate: 20.944
# Finished 50.2 percent. Acceptance Rate: 20.9323
# Finished 50.4 percent. Acceptance Rate: 20.9206
# Finished 50.6 percent. Acceptance Rate: 20.8854
# Finished 50.8 percent. Acceptance Rate: 20.8583
# Finished 51 percent. Acceptance Rate: 20.8431
# Finished 51.2 percent. Acceptance Rate: 20.8047
# Finished 51.4 percent. Acceptance Rate: 20.8444
# Finished 51.6 percent. Acceptance Rate: 20.876
# Finished 51.8 percent. Acceptance Rate: 20.8417
# Finished 52 percent. Acceptance Rate: 20.8308
# Finished 52.2 percent. Acceptance Rate: 20.8238
# Finished 52.4 percent. Acceptance Rate: 20.8244
# Finished 52.6 percent. Acceptance Rate: 20.8099
# Finished 52.8 percent. Acceptance Rate: 20.8485
# Finished 53 percent. Acceptance Rate: 20.8642
# Finished 53.2 percent. Acceptance Rate: 20.8647
# Finished 53.4 percent. Acceptance Rate: 20.8315
# Finished 53.6 percent. Acceptance Rate: 20.791
# Finished 53.8 percent. Acceptance Rate: 20.7584
# Finished 54 percent. Acceptance Rate: 20.7481
# Finished 54.2 percent. Acceptance Rate: 20.7749
# Finished 54.4 percent. Acceptance Rate: 20.7721
# Finished 54.6 percent. Acceptance Rate: 20.7802
# Finished 54.8 percent. Acceptance Rate: 20.7883
# Finished 55 percent. Acceptance Rate: 20.7964
# Finished 55.2 percent. Acceptance Rate: 20.8152
# Finished 55.4 percent. Acceptance Rate: 20.7834
# Finished 55.6 percent. Acceptance Rate: 20.8165
# Finished 55.8 percent. Acceptance Rate: 20.8351
# Finished 56 percent. Acceptance Rate: 20.8607
# Finished 56.2 percent. Acceptance Rate: 20.8754
# Finished 56.4 percent. Acceptance Rate: 20.8901
# Finished 56.6 percent. Acceptance Rate: 20.9046
# Finished 56.8 percent. Acceptance Rate: 20.8979
# Finished 57 percent. Acceptance Rate: 20.9298
# Finished 57.2 percent. Acceptance Rate: 20.9406
# Finished 57.4 percent. Acceptance Rate: 20.9721
# Finished 57.6 percent. Acceptance Rate: 20.9722
# Finished 57.8 percent. Acceptance Rate: 20.9931
# Finished 58 percent. Acceptance Rate: 20.9793
# Finished 58.2 percent. Acceptance Rate: 20.9553
# Finished 58.4 percent. Acceptance Rate: 20.9623
# Finished 58.6 percent. Acceptance Rate: 20.9693
# Finished 58.8 percent. Acceptance Rate: 20.983
# Finished 59 percent. Acceptance Rate: 20.9695
# Finished 59.2 percent. Acceptance Rate: 20.9865
# Finished 59.4 percent. Acceptance Rate: 21.0269
# Finished 59.6 percent. Acceptance Rate: 21.0436
# Finished 59.8 percent. Acceptance Rate: 21.0301
# Finished 60 percent. Acceptance Rate: 21.03
# Finished 60.2 percent. Acceptance Rate: 21.0365
# Finished 60.4 percent. Acceptance Rate: 21.0497
# Finished 60.6 percent. Acceptance Rate: 21.0462
# Finished 60.8 percent. Acceptance Rate: 21.0625
# Finished 61 percent. Acceptance Rate: 21.0754
# Finished 61.2 percent. Acceptance Rate: 21.1111
# Finished 61.4 percent. Acceptance Rate: 21.1205
# Finished 61.6 percent. Acceptance Rate: 21.1396
# Finished 61.8 percent. Acceptance Rate: 21.123
# Finished 62 percent. Acceptance Rate: 21.1258
# Finished 62.2 percent. Acceptance Rate: 21.1254
# Finished 62.4 percent. Acceptance Rate: 21.1218
# Finished 62.6 percent. Acceptance Rate: 21.1214
# Finished 62.8 percent. Acceptance Rate: 21.1274
# Finished 63 percent. Acceptance Rate: 21.1048
# Finished 63.2 percent. Acceptance Rate: 21.0854
# Finished 63.4 percent. Acceptance Rate: 21.1041
# Finished 63.6 percent. Acceptance Rate: 21.0755
# Finished 63.8 percent. Acceptance Rate: 21.0815
# Finished 64 percent. Acceptance Rate: 21.0781
# Finished 64.2 percent. Acceptance Rate: 21.0467
# Finished 64.4 percent. Acceptance Rate: 21.0652
# Finished 64.6 percent. Acceptance Rate: 21.096
# Finished 64.8 percent. Acceptance Rate: 21.0895
# Finished 65 percent. Acceptance Rate: 21.0985
# Finished 65.2 percent. Acceptance Rate: 21.1135
# Finished 65.4 percent. Acceptance Rate: 21.156
# Finished 65.6 percent. Acceptance Rate: 21.1555
# Finished 65.8 percent. Acceptance Rate: 21.1429
# Finished 66 percent. Acceptance Rate: 21.1485
# Finished 66.2 percent. Acceptance Rate: 21.1511
# Finished 66.4 percent. Acceptance Rate: 21.1446
# Finished 66.6 percent. Acceptance Rate: 21.1441
# Finished 66.8 percent. Acceptance Rate: 21.1138
# Finished 67 percent. Acceptance Rate: 21.1194
# Finished 67.2 percent. Acceptance Rate: 21.122
# Finished 67.4 percent. Acceptance Rate: 21.1098
# Finished 67.6 percent. Acceptance Rate: 21.1036
# Finished 67.8 percent. Acceptance Rate: 21.0944
# Finished 68 percent. Acceptance Rate: 21.0647
# Finished 68.2 percent. Acceptance Rate: 21.088
# Finished 68.4 percent. Acceptance Rate: 21.0877
# Finished 68.6 percent. Acceptance Rate: 21.0816
# Finished 68.8 percent. Acceptance Rate: 21.0872
# Finished 69 percent. Acceptance Rate: 21.0667
# Finished 69.2 percent. Acceptance Rate: 21.0289
# Finished 69.4 percent. Acceptance Rate: 21.0202
# Finished 69.6 percent. Acceptance Rate: 21.0115
# Finished 69.8 percent. Acceptance Rate: 21.0287
# Finished 70 percent. Acceptance Rate: 21.0257
# Finished 70.2 percent. Acceptance Rate: 21.0399
# Finished 70.4 percent. Acceptance Rate: 21.0398
# Finished 70.6 percent. Acceptance Rate: 21.0283
# Finished 70.8 percent. Acceptance Rate: 21.0198
# Finished 71 percent. Acceptance Rate: 21.0141
# Finished 71.2 percent. Acceptance Rate: 21.0112
# Finished 71.4 percent. Acceptance Rate: 21.0308
# Finished 71.6 percent. Acceptance Rate: 21.0363
# Finished 71.8 percent. Acceptance Rate: 21.039
# Finished 72 percent. Acceptance Rate: 21.0306
# Finished 72.2 percent. Acceptance Rate: 21.0249
# Finished 72.4 percent. Acceptance Rate: 21.0249
# Finished 72.6 percent. Acceptance Rate: 21.0523
# Finished 72.8 percent. Acceptance Rate: 21.0687
# Finished 73 percent. Acceptance Rate: 21.0822
# Finished 73.2 percent. Acceptance Rate: 21.0683
# Finished 73.4 percent. Acceptance Rate: 21.0763
# Finished 73.6 percent. Acceptance Rate: 21.0707
# Finished 73.8 percent. Acceptance Rate: 21.0379
# Finished 74 percent. Acceptance Rate: 21.0189
# Finished 74.2 percent. Acceptance Rate: 20.9946
# Finished 74.4 percent. Acceptance Rate: 20.9946
# Finished 74.6 percent. Acceptance Rate: 20.9786
# Finished 74.8 percent. Acceptance Rate: 20.9973
# Finished 75 percent. Acceptance Rate: 20.9973
# Finished 75.2 percent. Acceptance Rate: 20.9894
# Finished 75.4 percent. Acceptance Rate: 21.0106
# Finished 75.6 percent. Acceptance Rate: 21
# Finished 75.8 percent. Acceptance Rate: 21.0079
# Finished 76 percent. Acceptance Rate: 21.0237
# Finished 76.2 percent. Acceptance Rate: 21.0289
# Finished 76.4 percent. Acceptance Rate: 21.0288
# Finished 76.6 percent. Acceptance Rate: 21.0339
# Finished 76.8 percent. Acceptance Rate: 21.0339
# Finished 77 percent. Acceptance Rate: 21.0182
# Finished 77.2 percent. Acceptance Rate: 21.0052
# Finished 77.4 percent. Acceptance Rate: 21.0078
# Finished 77.6 percent. Acceptance Rate: 20.9871
# Finished 77.8 percent. Acceptance Rate: 20.9871
# Finished 78 percent. Acceptance Rate: 20.9846
# Finished 78.2 percent. Acceptance Rate: 20.9898
# Finished 78.4 percent. Acceptance Rate: 20.9898
# Finished 78.6 percent. Acceptance Rate: 20.9746
# Finished 78.8 percent. Acceptance Rate: 20.9492
# Finished 79 percent. Acceptance Rate: 20.9316
# Finished 79.2 percent. Acceptance Rate: 20.9444
# Finished 79.4 percent. Acceptance Rate: 20.9345
# Finished 79.6 percent. Acceptance Rate: 20.9598
# Finished 79.8 percent. Acceptance Rate: 20.9724
# Finished 80 percent. Acceptance Rate: 20.98
# Finished 80.2 percent. Acceptance Rate: 20.9925
# Finished 80.4 percent. Acceptance Rate: 21.0149
# Finished 80.6 percent. Acceptance Rate: 21.0298
# Finished 80.8 percent. Acceptance Rate: 21.0099
# Finished 81 percent. Acceptance Rate: 20.9951
# Finished 81.2 percent. Acceptance Rate: 21.0049
# Finished 81.4 percent. Acceptance Rate: 20.9951
# Finished 81.6 percent. Acceptance Rate: 21
# Finished 81.8 percent. Acceptance Rate: 20.9853
# Finished 82 percent. Acceptance Rate: 20.9707
# Finished 82.2 percent. Acceptance Rate: 20.944
# Finished 82.4 percent. Acceptance Rate: 20.9636
# Finished 82.6 percent. Acceptance Rate: 20.9516
# Finished 82.8 percent. Acceptance Rate: 20.9638
# Finished 83 percent. Acceptance Rate: 20.9325
# Finished 83.2 percent. Acceptance Rate: 20.9375
# Finished 83.4 percent. Acceptance Rate: 20.9472
# Finished 83.6 percent. Acceptance Rate: 20.9474
# Finished 83.8 percent. Acceptance Rate: 20.9547
# Finished 84 percent. Acceptance Rate: 20.95
# Finished 84.2 percent. Acceptance Rate: 20.943
# Finished 84.4 percent. Acceptance Rate: 20.9194
# Finished 84.6 percent. Acceptance Rate: 20.8983
# Finished 84.8 percent. Acceptance Rate: 20.9245
# Finished 85 percent. Acceptance Rate: 20.9082
# Finished 85.2 percent. Acceptance Rate: 20.9061
# Finished 85.4 percent. Acceptance Rate: 20.9063
# Finished 85.6 percent. Acceptance Rate: 20.9159
# Finished 85.8 percent. Acceptance Rate: 20.8951
# Finished 86 percent. Acceptance Rate: 20.893
# Finished 86.2 percent. Acceptance Rate: 20.9072
# Finished 86.4 percent. Acceptance Rate: 20.8912
# Finished 86.6 percent. Acceptance Rate: 20.8915
# Finished 86.8 percent. Acceptance Rate: 20.871
# Finished 87 percent. Acceptance Rate: 20.8759
# Finished 87.2 percent. Acceptance Rate: 20.867
# Finished 87.4 percent. Acceptance Rate: 20.849
# Finished 87.6 percent. Acceptance Rate: 20.8493
# Finished 87.8 percent. Acceptance Rate: 20.8588
# Finished 88 percent. Acceptance Rate: 20.8545
# Finished 88.2 percent. Acceptance Rate: 20.8594
# Finished 88.4 percent. Acceptance Rate: 20.8439
# Finished 88.6 percent. Acceptance Rate: 20.8352
# Finished 88.8 percent. Acceptance Rate: 20.8491
# Finished 89 percent. Acceptance Rate: 20.8517
# Finished 89.2 percent. Acceptance Rate: 20.8251
# Finished 89.4 percent. Acceptance Rate: 20.8121
# Finished 89.6 percent. Acceptance Rate: 20.7902
# Finished 89.8 percent. Acceptance Rate: 20.784
# Finished 90 percent. Acceptance Rate: 20.78
# Finished 90.2 percent. Acceptance Rate: 20.796
# Finished 90.4 percent. Acceptance Rate: 20.8296
# Finished 90.6 percent. Acceptance Rate: 20.8256
# Finished 90.8 percent. Acceptance Rate: 20.8238
# Finished 91 percent. Acceptance Rate: 20.8549
# Finished 91.2 percent. Acceptance Rate: 20.8662
# Finished 91.4 percent. Acceptance Rate: 20.8731
# Finished 91.6 percent. Acceptance Rate: 20.869
# Finished 91.8 percent. Acceptance Rate: 20.8736
# Finished 92 percent. Acceptance Rate: 20.8717
# Finished 92.2 percent. Acceptance Rate: 20.8568
# Finished 92.4 percent. Acceptance Rate: 20.8225
# Finished 92.6 percent. Acceptance Rate: 20.8078
# Finished 92.8 percent. Acceptance Rate: 20.8103
# Finished 93 percent. Acceptance Rate: 20.8215
# Finished 93.2 percent. Acceptance Rate: 20.824
# Finished 93.4 percent. Acceptance Rate: 20.8223
# Finished 93.6 percent. Acceptance Rate: 20.7906
# Finished 93.8 percent. Acceptance Rate: 20.7804
# Finished 94 percent. Acceptance Rate: 20.7787
# Finished 94.2 percent. Acceptance Rate: 20.7749
# Finished 94.4 percent. Acceptance Rate: 20.7669
# Finished 94.6 percent. Acceptance Rate: 20.74
# Finished 94.8 percent. Acceptance Rate: 20.7574
# Finished 95 percent. Acceptance Rate: 20.7874
# Finished 95.2 percent. Acceptance Rate: 20.792
# Finished 95.4 percent. Acceptance Rate: 20.7778
# Finished 95.6 percent. Acceptance Rate: 20.7657
# Finished 95.8 percent. Acceptance Rate: 20.7662
# Finished 96 percent. Acceptance Rate: 20.7646
# Finished 96.2 percent. Acceptance Rate: 20.7505
# Finished 96.4 percent. Acceptance Rate: 20.7656
# Finished 96.6 percent. Acceptance Rate: 20.7453
# Finished 96.8 percent. Acceptance Rate: 20.7355
# Finished 97 percent. Acceptance Rate: 20.7216
# Finished 97.2 percent. Acceptance Rate: 20.7407
# Finished 97.4 percent. Acceptance Rate: 20.7351
# Finished 97.6 percent. Acceptance Rate: 20.7398
# Finished 97.8 percent. Acceptance Rate: 20.7546
# Finished 98 percent. Acceptance Rate: 20.7408
# Finished 98.2 percent. Acceptance Rate: 20.7576
# Finished 98.4 percent. Acceptance Rate: 20.7663
# Finished 98.6 percent. Acceptance Rate: 20.7728
# Finished 98.8 percent. Acceptance Rate: 20.7794
# Finished 99 percent. Acceptance Rate: 20.7939
# Finished 99.2 percent. Acceptance Rate: 20.8145
# Finished 99.4 percent. Acceptance Rate: 20.8129
# Finished 99.6 percent. Acceptance Rate: 20.7791
# Finished 99.8 percent. Acceptance Rate: 20.7796

# %%
def get_psd_vals(samples, confidence=0.05):
    """
    Get the confidence intervals for MCMC samples
    
    :param samples:
        The samples from the MCMC chain
    
    :param confidence:
        The significance/confidence level of the interval.
        This is two-sided, so on either side of the interval,
        there is 0.5*confidence of probability
    
    return list of tuples: [(smin ,smax), ...]
    """
    return [(np.percentile(col, 50), np.percentile(col, 50*confidence), np.percentile(col, 100-50*confidence)) for col in samples.T]

# %%
# Get the PSD confidence levels
ci = np.array(get_psd_vals(sampler.chain[10000:,:]))
psd_val = np.mean(ci[1:,1:], axis=1)
psd_err = ci[1:,2]-ci[1:,1]

# %%
plt.scatter(psr.freqs[::2], ci[1:,0], marker='x', c='b')
plt.errorbar(psr.freqs[::2], psd_val, yerr=psd_err, fmt=' ', c='blue')
plt.xscale('log')
plt.xlim(3e-9, 2e-7)
# Out:
# (3e-09, 2e-07)

# %%
triangle.corner(sampler.chain[10000:,:5])

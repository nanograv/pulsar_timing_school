# %%
import numpy as np
import scipy.linalg as sl
import scipy.special as ss
import libstempo as lt, libstempo.plot as ltp, libstempo.toasim as ltt
import matplotlib.pyplot as plt
import os, sys, glob
import simple_mcmc as smcmc
import triangle
# %matplotlib inline
# Out:
# Warning: cannot find astropy, units support will not be available.

# %% [markdown]
# # Day 2: do a simple noise analysis #
#
# We are going to do a simple noise analysis today. For a whole bunch of pulsars, you will find datafiles in the directory 'signals'. We will analyze one pulsar (say, J0030) today for noise. In order to do that, we have provided some auxiliary functions

# %% [markdown]
# ## Some constants ##
#
# These constants will come in handy

# %%
day = 86400.0                   # Seconds per day
year =  31557600.0              # Seconds per year (yr = 365.25 days, so Julian years)
EulerGamma = 0.5772156649015329 # Euler gamma constant
mjdT0 = 54000.0                 # MJD to which all toas are referenced (for precision)

# %% [markdown]
# ## Design matrix ##
# In case we do not use the tempo2 design matrix, we can generate one ourselves for quadratic spindown

# %%
def designqsd(t, order=2):
    """
    Calculate the design matrix for quadratic spindown

    :param t:
        array of toas
    """
    M = np.ones([len(t), order+1])
    for ii in range(1, order+1):
        M[:,ii] = t ** ii
    
    return M.copy()

# %% [markdown]
# ## Fourier basis ##
# Like the design matrix, we need a basis for the Fourier amplitudes as well.

# %%
def fourierdesignmatrix(t, nmodes, Ttot=None):
    """
    Calculate the matrix of Fourier modes A, given a set of timestamps

    These are sine/cosine basis vectors at evenly separated frequency bins

    Mode 0: sin(f_0)
    Mode 1: cos(f_0)
    Mode 2: sin(f_1)
    ... etc

    :param nmodes:
        The number of modes that will be included (= 2*nfreq)
    :param Ttot:
        Total duration experiment (in case not given by t)

    :return:
        (A, freqs), with A the 'fourier design matrix', and f the associa

    """
    N = t.size
    A = np.zeros([N, nmodes])
    T = t.max() - t.min()

    if(nmodes % 2 != 0):
      print "WARNING: Number of modes should be even!"

    if Ttot is None:
        deltaf = 1.0 / T
    else:
        deltaf = 1.0 / Ttot

    freqs1 = np.linspace(deltaf, (nmodes/2)*deltaf, nmodes/2)
    freqs = np.array([freqs1, freqs1]).T.flatten()

    # The cosine modes
    for i in range(0, nmodes, 2):
        omega = 2.0 * np.pi * freqs[i]
        A[:,i] = np.cos(omega * t)

    # The sine modes
    for i in range(1, nmodes, 2):
        omega = 2.0 * np.pi * freqs[i]
        A[:,i] = np.sin(omega * t)

    return (A, freqs)

# %% [markdown]
# ## Functions for power-law spectral analysis ##
# In order to do spectral analysis, we need the PSD, the covariance function (PSD cosine transform), and the covariance matrix.

# %%
def PL_psd(f, amp, alpha, sig_fL):
    """
    PSD for a power-law signal.

    :param f:
        Array of frequencies for which to return the PSD (1/sec)

    :param amp:
        Unitless amplitude of the power-law signal

    :param alpha:
        Spectral index

    :param sig_fL:
        Signal low-frequency cut-off. A physical bound
    
    Note that this function returns the power per
    frequency bin of (1/Tmax) size, so the units are in sec^2 / (1/Tmax)
    """
    Si = 3.0 - 2.0*alpha

    Tmax = 1.0 / np.min(f)

    freqpy = f * year

    mask = (freqpy >= sig_fL)

    psd = np.zeros(len(freqpy))
    psd[mask] = (amp**2 * year**3 / (12*np.pi*np.pi * Tmax)) * freqpy[mask] ** (-Si)
    
    return psd


# Calculate the covariance matrix for a red signal
# (for a GWB with unitless amplitude h_c(1yr^{-1}) = 1)
def PL_covfunc(tau, amp, alpha=-2.0/3.0, fL=1.0/(year*20)):
    """
    Compute the covariance function for a powerlaw
    Result is in units of (sec)^2.

    :param tau:
        the time lag

    :param amp:
        amplitude

    :param alpha:
        the GWB spectral index

    :param fL:
        the low-frequency cut-off
    """
    fL = fL * year
    x = 2 * np.pi * fL * np.abs(tau) / year
    cf = ss.gamma(-2+2*alpha) * np.cos(np.pi*alpha)
    power = cf * x**(2-2*alpha)
    ksum = ss.hyp1f2(alpha-1,0.5,alpha,-0.25*x**2)[0]/(2*alpha-2)
    corr = -(year**2 * fL**(-2+2*alpha)) / (12 * np.pi**2) * (power + ksum)
    
    return amp**2*corr


def PL_covmat(toas, amp, alpha=-2.0/3.0, fL=1.0/(year*20)):
    """
    Use the covariance function PL_covfunc to create the covariance matrix for
    'toas'. Result is in units of (sec)^2

    :param tau:
        the time lag

    :param amp:
        amplitude

    :param alpha:
        the GWB spectral index

    :param fL:
        the low-frequency cut-off
    """
    t1, t2 = np.meshgrid(toas, toas)
    tau = np.abs(t1-t2)

    return PL_covfunc(tau, amp, alpha, fL)

# %% [markdown]
# ## A simple pulsar class ##
#
# This class does not do much. It neatly stores data for you, and conveniently creates the Fourier basis for spectral analysis

# %%
class Pulsar(object):
    def __init__(self, toas, residuals, toaerrs, desmat=None, nfreqs=20,
            qsdorder=2, Tlow=None):
        """
        Initialise the pulsar from data

        :param toas:
            The barycentric times of arrival [MJD]

        :param residuals:
            The timing residuals [sec]

        :param toaerrs:
            The TOA uncertainties [sec]

        :param desmat:
            The design matrix (default None)

        :param nfreqs:
            The number of frequencies we'll use in the Fourier expansion

        :param qsdorder:
            If desmat=None, make a design matrix from scratch, with this order

        :param Tlow:
            1/lowest frequency used in expansion (default length of dataset)(
        """
        self.toas = (toas - mjdT0) * day       # MJD to seconds
        self.residuals = residuals
        self.toaerrs = toaerrs
        self.Mmat = desmat
        self.nobs = len(toas)
        self.nfreqs = nfreqs

        self.T = (np.max(self.toas) - np.min(self.toas))

        if self.Mmat is None:
            self.Mmat = designqsd(self.toas, order=qsdorder)

        # Create the basis of Fourier components
        if Tlow is None:
            Tlow = (np.max(self.toas) - np.min(self.toas))
        (self.Fmat, self.freqs) = fourierdesignmatrix(self.toas, 2*nfreqs, Ttot=Tlow)

# %% [markdown]
# # Exercise 1 #
# In this exercise, we test the provided functions above. We'll read in data, and construct the PSD-derived functions

# %% [markdown]
# # Exercise 1a #
# Read in a pulsar of your choice, and initialize the pulsar class

# %%
psrnum = 1 # J0030
psrlist = glob.glob('signals/J?????????.txt')
psrname = os.path.splitext(psrlist[psrnum])[0]
sigfile = psrname + '.txt'
desfile = psrname + '-des.txt'

# %%
dat = np.loadtxt(sigfile)
toas = dat[:,0]
residuals = dat[:,1]
toaerrs = dat[:,2]
desmat = np.loadtxt(desfile)
psr = Pulsar(toas, residuals, toaerrs, desmat=desmat)

# %% [markdown]
# # Exercise 1b #
# Plot the timing residuals, including the measurement uncertainties

# %%
plt.errorbar(toas, residuals, yerr=toaerrs, fmt='x', c='blue')
# Out:
# <Container object of 3 artists>

# %% [markdown]
# # Exercise 1c #
# For a red noise signal with $\alpha=-\frac{2}{3}$, and $A=10^{-14}$, plot the power spectral density and the covariance function.
#
# What is the effect of the low-frequency cut-off on either of these?

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)

# Power-law parameters
amp = 1.0e-14
alpha = -2.0/3.0
fL = 1.0 / (np.max(psr.toas) - np.min(psr.toas))

# Create the PSD
psd = PL_psd(psr.freqs, amp=1.0e-14, alpha=-2.0/3.0, sig_fL=fL)
ax[0].loglog(psr.freqs, psd)

# Create the covariance function
tau = psr.toas-np.min(psr.toas)
covf = PL_covfunc(tau, amp, alpha, fL=fL/4.0)
ax[1].plot(tau, covf)

# %% [markdown]
# ## Exercise 1d ##
# How could you use the psd of the previous exercise to generate mock timing residuals?

# %%
mockres = np.dot(psr.Fmat, np.sqrt(psd) * np.random.randn(len(psd)))
plt.plot(psr.toas, mockres)

# %% [markdown]
# # Exercise 2 #
# We will be writing log-likelihood functions here. First we will give two log-likelihood functions that can be used for _simple_ analyses, but they are not fast. You will be challenged to write a faster version. If you don't manage, use one of these slower versions for the MCMC exercise in exercise 3.

# %%
def mark1loglikelihood(psr, Aw, Ar, Si):
    """
    Log-likelihood for our pulsar. This one does not marginalize
    over the timing model, so it cannot be used if the data has been
    'fit'. Use when creating data with 'dofit=False':
    psr = Pulsar(dofit=False)
    
    Calculate covariance matrix in the time-domain with:
    
    ll = -0.5 * res^{T} C^{-1} res - 0.5 * log(det(C))
    
    :param psr:
        pulsar object, containing the data and stuff

    :param Aw:
        White noise amplitude, model parameter

    :param Ar:
        Red noise amplitude, model parameter

    :param Si:
        Spectral index of red noise, model parameter
    """
    
    # The function that builds the non-diagonal covariance matrix is Cred_sec
    #Cov = Aw**2 * np.eye(len(psr.toas)) + \
    #      Ar**2 * Cred_sec(psr.toas, alpha=0.5*(3-Si))
    Cov = Aw**2 * np.eye(len(psr.toas)) + \
        PL_covmat(psr.toas, Ar, alpha=0.5*(3-Si), fL=1.0/(year*20))
    
    cfC = sl.cho_factor(Cov)
    ldetC = 2 * np.sum(np.log(np.diag(cfC[0])))
    rCr = np.dot(psr.residuals, sl.cho_solve(cfC, psr.residuals))
    
    return -0.5 * rCr - 0.5 * ldetC - 0.5*len(psr.residuals)*np.log(2*np.pi)

def mark2loglikelihood(psr, Aw, Ar, Si):
    """
    Log-likelihood for our pulsar
    
    This likelihood does marginalize over the timing model. Calculate
    covariance matrix in the time-domain with:
    
    ll = 0.5 * res^{t} (C^{-1} - C^{-1} M (M^{T} C^{-1} M)^{-1} M^{T} C^{-1} ) res - \
         0.5 * log(det(C)) - 0.5 * log(det(M^{T} C^{-1} M))
         
    In relation to 'mark1loglikelihood', this likelihood has but a simple addition:
    res' = res - M xi
    where M is a (n x m) matrix, with m < n, and xi is a vector of length m. The xi
    are analytically marginalised over, yielding the above equation (up to constants)
    
    :param psr:
        pulsar object, containing the data and stuff

    :param Aw:
        White noise amplitude, model parameter

    :param Ar:
        Red noise amplitude, model parameter

    :param Si:
        Spectral index of red noise, model parameter
    """
    Mmat = psr.Mmat
    
    Cov = Aw**2 * np.eye(len(psr.toas)) + \
        PL_covmat(psr.toas, Ar, alpha=0.5*(3-Si), fL=1.0/(year*20))
    
    cfC = sl.cho_factor(Cov)
    Cinv = sl.cho_solve(cfC, np.eye(len(psr.toas)))
    ldetC = 2 * np.sum(np.log(np.diag(cfC[0])))

    MCM = np.dot(Mmat.T, np.dot(Cinv, Mmat))
    cfM = sl.cho_factor(MCM)
    ldetM = 2 * np.sum(np.log(np.diag(cfM[0])))
    
    wr = np.dot(Cinv, psr.residuals)
    rCr = np.dot(psr.residuals, wr)
    MCr = np.dot(Mmat.T, wr)
    
    return -0.5 * rCr + 0.5 * np.dot(MCr, sl.cho_solve(cfM, MCr)) - \
            0.5 * ldetC - 0.5 * ldetM -0.5*len(psr.residuals)*np.log(2*np.pi)

# %% [markdown]
# ## Exercise 2a ##
# Write the log-likelihood function using the hierachical model (with the Woodbury matrix identity) as shown in the presentation. How much faster is it?

# %%
def mark3loglikelihood(psr, Nvec, psd):
    """
    Log-likelihood for our pulsar (hierarchical/Woodbury)

    :param psr:
        pulsar object, containing the data and stuff

    :param Nvec:
        Vector of squared white noise amplitude (diagonal of covariance matrix)

    :param psd:
        Power-spectral density per frequency bin (of size 1/T)
    """
    Mmat, Fmat = psr.Mmat, psr.Fmat
    Tmat = np.append(Mmat, Fmat, axis=1)
    n, m, l = len(psr.toas), Mmat.shape[1], Fmat.shape[1]

    # Sigma matrix (inverse)
    TNT = np.dot(Tmat.T / Nvec, Tmat)
    phi_inv = np.zeros(m+l)
    phi_inv[m:] = 1.0/psd
    Sigma_inv = TNT + np.diag(phi_inv)

    # Invert Sigma_inv for use in the Woodbury identity
    #Sigma = sl.inv(Sigma_inv)       # Does not use Cholesky
    cf = sl.cho_factor(Sigma_inv)
    STNr = sl.cho_solve(cf, np.dot(Tmat.T / Nvec, psr.residuals))
    rNTSTNr = np.dot(psr.residuals, np.dot((Tmat.T / Nvec).T, STNr))
    rNr = np.sum(psr.residuals**2/Nvec)

    # The full Woodbury expansion
    rCr = rNr - rNTSTNr

    # Determinants
    logNdet = np.sum(np.log(Nvec))
    logPhidet = np.sum(np.log(psd))
    logSigmadet = 2.0*np.sum(np.log(np.diag(cf[0])))

    # Sylvester Matrix identity
    logCdet = logNdet + logPhidet + logSigmadet

    return -0.5*rCr-0.5*logCdet-0.5*n*np.log(2*np.pi)

def pl_loglikelihood(psr, Aw, Ar, Si):
    """
    Log-likelihood for our pulsar (hierarchical/Woodbury)

    :param psr:
        pulsar object, containing the data and stuff

    :param Aw:
        White noise amplitude [sec]
        
    :param Ar:
        Power-law red noise amplitude []

    :param Si:
        Power-law red noise spectral index []
    """
    Nvec = np.ones(len(psr.toas)) * Aw**2
    psd = PL_psd(psr.freqs, Ar, 0.5*(3-Si), sig_fL=1.0/(20.0*year))
    return mark3loglikelihood(psr, Nvec, psd)

def sp_loglikelihood(psr, Aw, psd):
    """
    Log-likelihood for our pulsar (hierarchical/Woodbury)

    :param psr:
        pulsar object, containing the data and stuff

    :param Aw:
        White noise amplitude [sec]
        
    :param psd:
        Vector PSD amplitudes [sec]
    """    
    if len(psd)*2 != psr.Fmat.shape[1]:
        raise ValueError("PSD vector not of appropriate length!")

    Nvec = np.ones(len(psr.toas)) * Aw**2
    return mark3loglikelihood(psr, Nvec, psd.repeat(2))

# %%
# %timeit mark1loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
# %timeit mark2loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
# %timeit pl_loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
# Out:
# 100 loops, best of 3: 4.44 ms per loop
# 100 loops, best of 3: 6.43 ms per loop
# 1000 loops, best of 3: 419 µs per loop

# %% [markdown]
# # Exercise 2b #
# Plot the log-likelihood as a function of power-law amplitude for the range 10**(-16, -13), with $\gamma=13/3$

# %%
# The log-likelihood for a particular value of A
print mark1loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
print mark2loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
print pl_loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
# Out:
# 2842.91946275
# 2613.81315359
# 2613.8339915

# %%
Ar = np.linspace(-16.0, -13.0, 100)
ll1 = np.zeros_like(Ar)
ll2 = np.zeros_like(Ar)
ll3 = np.zeros_like(Ar)

for ii, A in enumerate(Ar):
    amp = 10**(A)
    ll1[ii] = mark1loglikelihood(psr, 1.0e-7, amp, 4.33)
    ll2[ii] = mark2loglikelihood(psr, 1.0e-7, amp, 4.33)
    ll3[ii] = pl_loglikelihood(psr, 1.0e-7, amp, 4.33)

plt.plot(Ar, np.exp(ll1-np.max(ll1)), 'b')
plt.plot(Ar, np.exp(ll2-np.max(ll2)), 'g')
plt.plot(Ar, np.exp(ll3-np.max(ll3)), 'r--')

# %% [markdown]
# ## Exercise 2c ##
# Run a simple MCMC, using the sampler you wrote yesterday, to discover the injected value of:
#  * white noise
#  * power-law red noise amplitude
#  * power-law red noise spectral index

# %%
# Run a simple MCMC on the power-law
def loglik(x):
    return pl_loglikelihood(psr, 10**x[0], 10**x[1], x[2])

def logprior(x):
    rv = 0.0
    xmin = np.array([-10.0, -18.0, 0.0])
    xmax = np.array([-4.0, -12.0, 9.0])
    
    if np.any(x < xmin) or np.any(x > xmax):
        rv = -np.inf
        
    return rv

p0 = np.array([-7.0, -14.0, 4.33])
sigmas = np.array([0.1, 0.1, 0.1])
sampler = smcmc.SimpleMCMC(loglik, logprior, sigmas)

# %%
sampler.sample(p0, 50000)
# Out:
# Finished 0.2 percent. Acceptance Rate: 24
# Finished 92.4 percent. Acceptance Rate: 22.7965
# Finished 92.6 percent. Acceptance Rate: 22.8121
# Finished 92.8 percent. Acceptance Rate: 22.7953
# Finished 93 percent. Acceptance Rate: 22.7957
# Finished 93.2 percent. Acceptance Rate: 22.8047
# Finished 93.4 percent. Acceptance Rate: 22.7966
# Finished 93.6 percent. Acceptance Rate: 22.7906
# Finished 93.8 percent. Acceptance Rate: 22.7889
# Finished 94 percent. Acceptance Rate: 22.7915
# Finished 94.2 percent. Acceptance Rate: 22.7834
# Finished 94.4 percent. Acceptance Rate: 22.7797
# Finished 94.6 percent. Acceptance Rate: 22.7653
# Finished 94.8 percent. Acceptance Rate: 22.7574
# Finished 95 percent. Acceptance Rate: 22.7537
# Finished 95.2 percent. Acceptance Rate: 22.7521
# Finished 95.4 percent. Acceptance Rate: 22.7505
# Finished 95.6 percent. Acceptance Rate: 22.7448
# Finished 95.8 percent. Acceptance Rate: 22.7578
# Finished 96 percent. Acceptance Rate: 22.7521
# Finished 96.2 percent. Acceptance Rate: 22.7505
# Finished 96.4 percent. Acceptance Rate: 22.7365
# Finished 96.6 percent. Acceptance Rate: 22.7371
# Finished 96.8 percent. Acceptance Rate: 22.7355
# Finished 97 percent. Acceptance Rate: 22.7155
# Finished 97.2 percent. Acceptance Rate: 22.714
# Finished 97.4 percent. Acceptance Rate: 22.7064
# Finished 97.6 percent. Acceptance Rate: 22.6967
# Finished 97.8 percent. Acceptance Rate: 22.6953
# Finished 98 percent. Acceptance Rate: 22.7143
# Finished 98.2 percent. Acceptance Rate: 22.7128
# Finished 98.4 percent. Acceptance Rate: 22.7195
# Finished 98.6 percent. Acceptance Rate: 22.7099
# Finished 98.8 percent. Acceptance Rate: 22.7146
# Finished 99 percent. Acceptance Rate: 22.7111
# Finished 99.2 percent. Acceptance Rate: 22.7157
# Finished 99.4 percent. Acceptance Rate: 22.7062
# Finished 99.6 percent. Acceptance Rate: 22.6867
# Finished 99.8 percent. Acceptance Rate: 22.6874

# %%
triangle.corner(sampler.chain)

# %% [markdown]
# ## Exercise 2d ##
# Run a simple MCMC, using the sampler you wrote yesterday, to discover the injected value of:
#  * white noise
#  * PSD amplitudes

# %%
# Run a simple MCMC on the power-law
def loglik(x):
    return sp_loglikelihood(psr, 10**x[0], 10**x[1:])

def logprior(x):
    rv = 0.0
    xmin, xmax = np.ones_like(x), np.ones_like(x)
    
    xmin[0], xmax[0] = -10.0, -4.0
    xmin[1:] = -18.0
    xmax[1:] = -12.0
    
    if np.any(x < xmin) or np.any(x > xmax):
        rv = -np.inf
        
    return rv

psd0 = np.ones(psr.Fmat.shape[1]/2) * -14.0
p0 = np.append([-7.0], psd0)
sigmas = 0.1 * np.ones_like(p0)
sampler = smcmc.SimpleMCMC(loglik, logprior, sigmas)

# %%
sampler.sample(p0, 500000)
# Out:
# Finished 0.02 percent. Acceptance Rate: 28
# Finished 0.04 percent. Acceptance Rate: 30.5
# Finished 0.06 percent. Acceptance Rate: 28.3333
# Finished 0.08 percent. Acceptance Rate: 28
# Finished 0.1 percent. Acceptance Rate: 26.8
# Finished 0.12 percent. Acceptance Rate: 26.6667
# Finished 0.14 percent. Acceptance Rate: 25.5714
# Finished 0.16 percent. Acceptance Rate: 25.875
# Finished 0.18 percent. Acceptance Rate: 24.3333
# Finished 0.2 percent. Acceptance Rate: 23.8
# Finished 0.22 percent. Acceptance Rate: 23.0909
# Finished 0.24 percent. Acceptance Rate: 23.5
# Finished 0.26 percent. Acceptance Rate: 24
# Finished 0.28 percent. Acceptance Rate: 24.5714
# Finished 0.3 percent. Acceptance Rate: 24.4
# Finished 0.32 percent. Acceptance Rate: 24.625
# Finished 0.34 percent. Acceptance Rate: 23.7059
# Finished 0.36 percent. Acceptance Rate: 23.6667
# Finished 0.38 percent. Acceptance Rate: 23.0526
# Finished 0.4 percent. Acceptance Rate: 22.75
# Finished 0.42 percent. Acceptance Rate: 22.4286
# Finished 0.44 percent. Acceptance Rate: 22.1818
# Finished 0.46 percent. Acceptance Rate: 21.8261
# Finished 0.48 percent. Acceptance Rate: 21.375
# Finished 0.5 percent. Acceptance Rate: 21.12
# Finished 0.52 percent. Acceptance Rate: 20.8462
# Finished 0.54 percent. Acceptance Rate: 20.7778
# Finished 0.56 percent. Acceptance Rate: 20.5714
# Finished 0.58 percent. Acceptance Rate: 20.4828
# Finished 0.6 percent. Acceptance Rate: 20.1667
# Finished 0.62 percent. Acceptance Rate: 20.0645
# Finished 0.64 percent. Acceptance Rate: 20.2188
# Finished 0.66 percent. Acceptance Rate: 20.303
# Finished 0.68 percent. Acceptance Rate: 20.0588
# Finished 0.7 percent. Acceptance Rate: 19.9714
# Finished 0.72 percent. Acceptance Rate: 19.9167
# Finished 0.74 percent. Acceptance Rate: 19.9459
# Finished 0.76 percent. Acceptance Rate: 20.0263
# Finished 0.78 percent. Acceptance Rate: 20.1795
# Finished 0.8 percent. Acceptance Rate: 20.3
# Finished 0.82 percent. Acceptance Rate: 20.3902
# Finished 0.84 percent. Acceptance Rate: 20.4524
# Finished 0.86 percent. Acceptance Rate: 20.4419
# Finished 0.88 percent. Acceptance Rate: 20.2727
# Finished 0.9 percent. Acceptance Rate: 20.1778
# Finished 0.92 percent. Acceptance Rate: 20.087
# Finished 0.94 percent. Acceptance Rate: 20.1064
# Finished 0.96 percent. Acceptance Rate: 20.1458
# Finished 0.98 percent. Acceptance Rate: 20.1837
# Finished 1 percent. Acceptance Rate: 20.24
# Finished 1.02 percent. Acceptance Rate: 20.1569
# Finished 1.04 percent. Acceptance Rate: 20.25
# Finished 1.06 percent. Acceptance Rate: 20.3019
# Finished 1.08 percent. Acceptance Rate: 20.3148
# Finished 1.1 percent. Acceptance Rate: 20.2727
# Finished 1.12 percent. Acceptance Rate: 20.25
# Finished 1.14 percent. Acceptance Rate: 20.4211
# Finished 1.16 percent. Acceptance Rate: 20.3621
# Finished 1.18 percent. Acceptance Rate: 20.2881
# Finished 1.2 percent. Acceptance Rate: 20.3333
# Finished 1.22 percent. Acceptance Rate: 20.3115
# Finished 1.24 percent. Acceptance Rate: 20.4032
# Finished 1.26 percent. Acceptance Rate: 20.4127
# Finished 1.28 percent. Acceptance Rate: 20.375
# Finished 1.3 percent. Acceptance Rate: 20.3385
# Finished 1.32 percent. Acceptance Rate: 20.2576
# Finished 1.34 percent. Acceptance Rate: 20.4328
# Finished 1.36 percent. Acceptance Rate: 20.5147
# Finished 1.38 percent. Acceptance Rate: 20.5797
# Finished 1.4 percent. Acceptance Rate: 20.4857
# Finished 1.42 percent. Acceptance Rate: 20.4789
# Finished 1.44 percent. Acceptance Rate: 20.4306
# Finished 1.46 percent. Acceptance Rate: 20.4658
# Finished 1.48 percent. Acceptance Rate: 20.3919
# Finished 1.5 percent. Acceptance Rate: 20.44
# Finished 1.52 percent. Acceptance Rate: 20.4474
# Finished 1.54 percent. Acceptance Rate: 20.4156
# Finished 1.56 percent. Acceptance Rate: 20.3846
# Finished 1.58 percent. Acceptance Rate: 20.3165
# Finished 1.6 percent. Acceptance Rate: 20.35
# Finished 1.62 percent. Acceptance Rate: 20.3333
# Finished 1.64 percent. Acceptance Rate: 20.3293
# Finished 1.66 percent. Acceptance Rate: 20.4458
# Finished 1.68 percent. Acceptance Rate: 20.4643
# Finished 1.7 percent. Acceptance Rate: 20.4118
# Finished 1.72 percent. Acceptance Rate: 20.3953
# Finished 1.74 percent. Acceptance Rate: 20.3103
# Finished 1.76 percent. Acceptance Rate: 20.2273
# Finished 1.78 percent. Acceptance Rate: 20.1461
# Finished 1.8 percent. Acceptance Rate: 20.1889
# Finished 1.82 percent. Acceptance Rate: 20.1648
# Finished 1.84 percent. Acceptance Rate: 20.087
# Finished 1.86 percent. Acceptance Rate: 20.0215
# Finished 1.88 percent. Acceptance Rate: 20.0213
# Finished 1.9 percent. Acceptance Rate: 20.1053
# Finished 1.92 percent. Acceptance Rate: 20.1146
# Finished 1.94 percent. Acceptance Rate: 20.1753
# Finished 1.96 percent. Acceptance Rate: 20.1633
# Finished 1.98 percent. Acceptance Rate: 20.1515
# Finished 2 percent. Acceptance Rate: 20.13
# Finished 2.02 percent. Acceptance Rate: 20.1188
# Finished 2.04 percent. Acceptance Rate: 20.1176
# Finished 2.06 percent. Acceptance Rate: 20.1068
# Finished 2.08 percent. Acceptance Rate: 20.1731
# Finished 2.1 percent. Acceptance Rate: 20.1714
# Finished 2.12 percent. Acceptance Rate: 20.2453
# Finished 2.14 percent. Acceptance Rate: 20.271
# Finished 2.16 percent. Acceptance Rate: 20.25
# Finished 2.18 percent. Acceptance Rate: 20.3394
# Finished 2.2 percent. Acceptance Rate: 20.3273
# Finished 2.22 percent. Acceptance Rate: 20.3153
# Finished 2.24 percent. Acceptance Rate: 20.3482
# Finished 2.26 percent. Acceptance Rate: 20.3451
# Finished 2.28 percent. Acceptance Rate: 20.3333
# Finished 2.3 percent. Acceptance Rate: 20.3043
# Finished 2.32 percent. Acceptance Rate: 20.3707
# Finished 2.34 percent. Acceptance Rate: 20.3248
# Finished 2.36 percent. Acceptance Rate: 20.2542
# Finished 4.64 percent. Acceptance Rate: 20.3276
# Finished 4.66 percent. Acceptance Rate: 20.3648
# Finished 4.68 percent. Acceptance Rate: 20.3248
# Finished 4.7 percent. Acceptance Rate: 20.3149
# Finished 4.72 percent. Acceptance Rate: 20.2881
# Finished 4.74 percent. Acceptance Rate: 20.2827
# Finished 4.76 percent. Acceptance Rate: 20.2521
# Finished 4.78 percent. Acceptance Rate: 20.2301
# Finished 4.8 percent. Acceptance Rate: 20.2375
# Finished 4.82 percent. Acceptance Rate: 20.2614
# Finished 4.84 percent. Acceptance Rate: 20.2314
# Finished 4.86 percent. Acceptance Rate: 20.214
# Finished 4.88 percent. Acceptance Rate: 20.1762
# Finished 4.9 percent. Acceptance Rate: 20.1592
# Finished 4.92 percent. Acceptance Rate: 20.1667
# Finished 4.94 percent. Acceptance Rate: 20.1984
# Finished 4.96 percent. Acceptance Rate: 20.2097
# Finished 4.98 percent. Acceptance Rate: 20.1807
# Finished 5 percent. Acceptance Rate: 20.18
# Finished 5.02 percent. Acceptance Rate: 20.2032
# Finished 5.04 percent. Acceptance Rate: 20.25
# Finished 5.06 percent. Acceptance Rate: 20.2806
# Finished 5.08 percent. Acceptance Rate: 20.2756
# Finished 5.1 percent. Acceptance Rate: 20.251
# Finished 5.12 percent. Acceptance Rate: 20.2266
# Finished 5.14 percent. Acceptance Rate: 20.2568
# Finished 5.16 percent. Acceptance Rate: 20.2868
# Finished 5.18 percent. Acceptance Rate: 20.278
# Finished 5.2 percent. Acceptance Rate: 20.2462
# Finished 5.22 percent. Acceptance Rate: 20.2184
# Finished 5.24 percent. Acceptance Rate: 20.2176
# Finished 5.26 percent. Acceptance Rate: 20.2357
# Finished 5.28 percent. Acceptance Rate: 20.2727
# Finished 5.3 percent. Acceptance Rate: 20.2679
# Finished 5.32 percent. Acceptance Rate: 20.2895
# Finished 5.34 percent. Acceptance Rate: 20.3296
# Finished 5.36 percent. Acceptance Rate: 20.3134
# Finished 5.38 percent. Acceptance Rate: 20.3048
# Finished 5.4 percent. Acceptance Rate: 20.2963
# Finished 5.42 percent. Acceptance Rate: 20.2841
# Finished 5.44 percent. Acceptance Rate: 20.3051
# Finished 5.46 percent. Acceptance Rate: 20.348
# Finished 5.48 percent. Acceptance Rate: 20.3978
# Finished 5.5 percent. Acceptance Rate: 20.4182
# Finished 5.52 percent. Acceptance Rate: 20.4094
# Finished 5.54 percent. Acceptance Rate: 20.4116
# Finished 5.56 percent. Acceptance Rate: 20.4317
# Finished 5.58 percent. Acceptance Rate: 20.4373
# Finished 5.6 percent. Acceptance Rate: 20.4393
# Finished 5.62 percent. Acceptance Rate: 20.4342
# Finished 5.64 percent. Acceptance Rate: 20.4326
# Finished 5.66 percent. Acceptance Rate: 20.4311
# Finished 5.68 percent. Acceptance Rate: 20.4577
# Finished 5.7 percent. Acceptance Rate: 20.4316
# Finished 5.72 percent. Acceptance Rate: 20.4301
# Finished 5.74 percent. Acceptance Rate: 20.4425
# Finished 5.76 percent. Acceptance Rate: 20.4549
# Finished 5.78 percent. Acceptance Rate: 20.4671
# Finished 5.8 percent. Acceptance Rate: 20.4655
# Finished 5.82 percent. Acceptance Rate: 20.512
# Finished 5.84 percent. Acceptance Rate: 20.4897
# Finished 5.86 percent. Acceptance Rate: 20.4778
# Finished 5.88 percent. Acceptance Rate: 20.4592
# Finished 5.9 percent. Acceptance Rate: 20.4712
# Finished 5.92 percent. Acceptance Rate: 20.4831
# Finished 5.94 percent. Acceptance Rate: 20.4781
# Finished 5.96 percent. Acceptance Rate: 20.4799
# Finished 5.98 percent. Acceptance Rate: 20.4883
# Finished 6 percent. Acceptance Rate: 20.5
# Finished 6.02 percent. Acceptance Rate: 20.5017
# Finished 6.04 percent. Acceptance Rate: 20.5099
# Finished 6.06 percent. Acceptance Rate: 20.5347
# Finished 6.08 percent. Acceptance Rate: 20.5559
# Finished 6.1 percent. Acceptance Rate: 20.5836
# Finished 6.12 percent. Acceptance Rate: 20.6242
# Finished 6.14 percent. Acceptance Rate: 20.6547
# Finished 6.16 percent. Acceptance Rate: 20.6526
# Finished 6.18 percent. Acceptance Rate: 20.6634
# Finished 6.2 percent. Acceptance Rate: 20.671
# Finished 6.22 percent. Acceptance Rate: 20.672
# Finished 6.24 percent. Acceptance Rate: 20.7212
# Finished 6.26 percent. Acceptance Rate: 20.6965
# Finished 6.28 percent. Acceptance Rate: 20.6369
# Finished 6.3 percent. Acceptance Rate: 20.6095
# Finished 6.32 percent. Acceptance Rate: 20.6266
# Finished 6.34 percent. Acceptance Rate: 20.6151
# Finished 6.36 percent. Acceptance Rate: 20.6101
# Finished 6.38 percent. Acceptance Rate: 20.5705
# Finished 6.4 percent. Acceptance Rate: 20.5656
# Finished 6.42 percent. Acceptance Rate: 20.5514
# Finished 6.44 percent. Acceptance Rate: 20.5435
# Finished 6.46 percent. Acceptance Rate: 20.5356
# Finished 6.48 percent. Acceptance Rate: 20.534
# Finished 6.5 percent. Acceptance Rate: 20.52
# Finished 6.52 percent. Acceptance Rate: 20.5307
# Finished 6.54 percent. Acceptance Rate: 20.5382
# Finished 6.56 percent. Acceptance Rate: 20.5488
# Finished 6.58 percent. Acceptance Rate: 20.5593
# Finished 6.6 percent. Acceptance Rate: 20.5242
# Finished 6.62 percent. Acceptance Rate: 20.5045
# Finished 6.64 percent. Acceptance Rate: 20.512
# Finished 6.66 percent. Acceptance Rate: 20.5435
# Finished 6.68 percent. Acceptance Rate: 20.5509
# Finished 6.7 percent. Acceptance Rate: 20.5582
# Finished 6.72 percent. Acceptance Rate: 20.5714
# Finished 6.74 percent. Acceptance Rate: 20.5727
# Finished 6.76 percent. Acceptance Rate: 20.6095
# Finished 6.78 percent. Acceptance Rate: 20.6077
# Finished 6.8 percent. Acceptance Rate: 20.5824
# Finished 6.82 percent. Acceptance Rate: 20.5748
# Finished 6.84 percent. Acceptance Rate: 20.5526
# Finished 6.86 percent. Acceptance Rate: 20.5714
# Finished 6.88 percent. Acceptance Rate: 20.5785
# Finished 6.9 percent. Acceptance Rate: 20.5681
# Finished 6.92 percent. Acceptance Rate: 20.5954
# Finished 6.94 percent. Acceptance Rate: 20.5793
# Finished 6.96 percent. Acceptance Rate: 20.5431
# Finished 6.98 percent. Acceptance Rate: 20.5215
# Finished 7 percent. Acceptance Rate: 20.4914
# Finished 7.02 percent. Acceptance Rate: 20.4701
# Finished 7.04 percent. Acceptance Rate: 20.4517
# Finished 7.06 percent. Acceptance Rate: 20.4618
# Finished 7.08 percent. Acceptance Rate: 20.4718
# Finished 7.1 percent. Acceptance Rate: 20.4648
# Finished 7.12 percent. Acceptance Rate: 20.4719
# Finished 7.14 percent. Acceptance Rate: 20.4734
# Finished 7.16 percent. Acceptance Rate: 20.5
# Finished 7.18 percent. Acceptance Rate: 20.5014
# Finished 7.2 percent. Acceptance Rate: 20.5194
# Finished 7.22 percent. Acceptance Rate: 20.5429
# Finished 7.24 percent. Acceptance Rate: 20.5249
# Finished 7.26 percent. Acceptance Rate: 20.5152
# Finished 7.28 percent. Acceptance Rate: 20.5055
# Finished 7.3 percent. Acceptance Rate: 20.4959
# Finished 7.32 percent. Acceptance Rate: 20.4918
# Finished 7.34 percent. Acceptance Rate: 20.5204
# Finished 7.36 percent. Acceptance Rate: 20.519
# Finished 7.38 percent. Acceptance Rate: 20.5149
# Finished 7.4 percent. Acceptance Rate: 20.5351
# Finished 7.42 percent. Acceptance Rate: 20.5121
# Finished 7.44 percent. Acceptance Rate: 20.4785
# Finished 7.46 percent. Acceptance Rate: 20.4531
# Finished 7.48 percent. Acceptance Rate: 20.4465
# Finished 7.5 percent. Acceptance Rate: 20.4347
# Finished 7.52 percent. Acceptance Rate: 20.4335
# Finished 7.54 percent. Acceptance Rate: 20.4403
# Finished 7.56 percent. Acceptance Rate: 20.455
# Finished 7.58 percent. Acceptance Rate: 20.4617
# Finished 7.6 percent. Acceptance Rate: 20.4553
# Finished 7.62 percent. Acceptance Rate: 20.4619
# Finished 7.64 percent. Acceptance Rate: 20.466
# Finished 7.66 percent. Acceptance Rate: 20.4674
# Finished 7.68 percent. Acceptance Rate: 20.4609
# Finished 7.7 percent. Acceptance Rate: 20.4831
# Finished 7.72 percent. Acceptance Rate: 20.4819
# Finished 7.74 percent. Acceptance Rate: 20.4806
# Finished 7.76 percent. Acceptance Rate: 20.4639
# Finished 7.78 percent. Acceptance Rate: 20.4319
# Finished 7.8 percent. Acceptance Rate: 20.4359
# Finished 7.82 percent. Acceptance Rate: 20.4194
# Finished 7.84 percent. Acceptance Rate: 20.426
# Finished 7.86 percent. Acceptance Rate: 20.4351
# Finished 7.88 percent. Acceptance Rate: 20.4416
# Finished 7.9 percent. Acceptance Rate: 20.4709
# Finished 7.92 percent. Acceptance Rate: 20.4773
# Finished 7.94 percent. Acceptance Rate: 20.4761
# Finished 7.96 percent. Acceptance Rate: 20.4849
# Finished 7.98 percent. Acceptance Rate: 20.4912
# Finished 8 percent. Acceptance Rate: 20.52
# Finished 8.02 percent. Acceptance Rate: 20.5187
# Finished 8.04 percent. Acceptance Rate: 20.5224
# Finished 8.06 percent. Acceptance Rate: 20.5037
# Finished 8.08 percent. Acceptance Rate: 20.4876
# Finished 8.1 percent. Acceptance Rate: 20.4593
# Finished 8.12 percent. Acceptance Rate: 20.4409
# Finished 8.14 percent. Acceptance Rate: 20.43
# Finished 8.16 percent. Acceptance Rate: 20.4338
# Finished 8.18 percent. Acceptance Rate: 20.4156
# Finished 8.2 percent. Acceptance Rate: 20.4122
# Finished 8.22 percent. Acceptance Rate: 20.4088
# Finished 8.24 percent. Acceptance Rate: 20.3981
# Finished 8.26 percent. Acceptance Rate: 20.385
# Finished 8.28 percent. Acceptance Rate: 20.3865
# Finished 8.3 percent. Acceptance Rate: 20.3807
# Finished 8.32 percent. Acceptance Rate: 20.375
# Finished 8.34 percent. Acceptance Rate: 20.3525
# Finished 8.36 percent. Acceptance Rate: 20.3206
# Finished 8.38 percent. Acceptance Rate: 20.3126
# Finished 8.4 percent. Acceptance Rate: 20.3167
# Finished 8.42 percent. Acceptance Rate: 20.3207
# Finished 8.44 percent. Acceptance Rate: 20.3246
# Finished 8.46 percent. Acceptance Rate: 20.3239
# Finished 8.48 percent. Acceptance Rate: 20.3373
# Finished 8.5 percent. Acceptance Rate: 20.3553
# Finished 8.52 percent. Acceptance Rate: 20.3592
# Finished 8.54 percent. Acceptance Rate: 20.3888
# Finished 8.56 percent. Acceptance Rate: 20.3855
# Finished 8.58 percent. Acceptance Rate: 20.3776
# Finished 8.6 percent. Acceptance Rate: 20.3488
# Finished 8.62 percent. Acceptance Rate: 20.3387
# Finished 8.64 percent. Acceptance Rate: 20.3426
# Finished 8.66 percent. Acceptance Rate: 20.3487
# Finished 8.68 percent. Acceptance Rate: 20.3548
# Finished 8.7 percent. Acceptance Rate: 20.3793
# Finished 8.72 percent. Acceptance Rate: 20.3693
# Finished 8.74 percent. Acceptance Rate: 20.3753
# Finished 8.76 percent. Acceptance Rate: 20.3744
# Finished 8.78 percent. Acceptance Rate: 20.3781
# Finished 8.8 percent. Acceptance Rate: 20.3682
# Finished 8.82 percent. Acceptance Rate: 20.3605
# Finished 8.84 percent. Acceptance Rate: 20.3597
# Finished 8.86 percent. Acceptance Rate: 20.3679
# Finished 8.88 percent. Acceptance Rate: 20.3536
# Finished 8.9 percent. Acceptance Rate: 20.3551
# Finished 8.92 percent. Acceptance Rate: 20.3475
# Finished 8.94 percent. Acceptance Rate: 20.3512
# Finished 8.96 percent. Acceptance Rate: 20.3616
# Finished 8.98 percent. Acceptance Rate: 20.3742
# Finished 9 percent. Acceptance Rate: 20.3711
# Finished 9.02 percent. Acceptance Rate: 20.3681
# Finished 9.04 percent. Acceptance Rate: 20.3562
# Finished 9.06 percent. Acceptance Rate: 20.34
# Finished 9.08 percent. Acceptance Rate: 20.3238
# Finished 9.1 percent. Acceptance Rate: 20.3033
# Finished 9.12 percent. Acceptance Rate: 20.2917
# Finished 9.14 percent. Acceptance Rate: 20.2845
# Finished 9.16 percent. Acceptance Rate: 20.2882
# Finished 9.18 percent. Acceptance Rate: 20.2876
# Finished 9.2 percent. Acceptance Rate: 20.287
# Finished 9.22 percent. Acceptance Rate: 20.2842
# Finished 9.24 percent. Acceptance Rate: 20.2792
# Finished 9.26 percent. Acceptance Rate: 20.2765
# Finished 9.28 percent. Acceptance Rate: 20.278
# Finished 9.3 percent. Acceptance Rate: 20.2839
# Finished 9.32 percent. Acceptance Rate: 20.2897
# Finished 9.34 percent. Acceptance Rate: 20.3041
# Finished 9.36 percent. Acceptance Rate: 20.3098
# Finished 9.38 percent. Acceptance Rate: 20.3006
# Finished 9.4 percent. Acceptance Rate: 20.3234
# Finished 9.42 percent. Acceptance Rate: 20.3397
# Finished 9.44 percent. Acceptance Rate: 20.3263
# Finished 9.46 percent. Acceptance Rate: 20.3362
# Finished 9.48 percent. Acceptance Rate: 20.327
# Finished 9.5 percent. Acceptance Rate: 20.3347
# Finished 9.52 percent. Acceptance Rate: 20.3403
# Finished 9.54 percent. Acceptance Rate: 20.3438
# Finished 9.56 percent. Acceptance Rate: 20.3494
# Finished 9.58 percent. Acceptance Rate: 20.3424
# Finished 9.6 percent. Acceptance Rate: 20.3417
# Finished 9.62 percent. Acceptance Rate: 20.3389
# Finished 9.64 percent. Acceptance Rate: 20.3444
# Finished 9.66 percent. Acceptance Rate: 20.3644
# Finished 9.68 percent. Acceptance Rate: 20.3822
# Finished 9.7 percent. Acceptance Rate: 20.3918
# Finished 9.72 percent. Acceptance Rate: 20.3951
# Finished 9.74 percent. Acceptance Rate: 20.4107
# Finished 9.76 percent. Acceptance Rate: 20.4119
# Finished 9.78 percent. Acceptance Rate: 20.4029
# Finished 9.8 percent. Acceptance Rate: 20.4163
# Finished 9.82 percent. Acceptance Rate: 20.4134
# Finished 9.84 percent. Acceptance Rate: 20.4045
# Finished 9.86 percent. Acceptance Rate: 20.3935
# Finished 9.88 percent. Acceptance Rate: 20.4008
# Finished 9.9 percent. Acceptance Rate: 20.396
# Finished 9.92 percent. Acceptance Rate: 20.373
# Finished 9.94 percent. Acceptance Rate: 20.3602
# Finished 9.96 percent. Acceptance Rate: 20.3554
# Finished 9.98 percent. Acceptance Rate: 20.3387
# Finished 10 percent. Acceptance Rate: 20.338
# Finished 10.02 percent. Acceptance Rate: 20.3273
# Finished 10.04 percent. Acceptance Rate: 20.3207
# Finished 10.06 percent. Acceptance Rate: 20.3221
# Finished 10.08 percent. Acceptance Rate: 20.3194
# Finished 10.1 percent. Acceptance Rate: 20.3366
# Finished 10.12 percent. Acceptance Rate: 20.3261
# Finished 10.14 percent. Acceptance Rate: 20.3176
# Finished 10.16 percent. Acceptance Rate: 20.315
# Finished 10.18 percent. Acceptance Rate: 20.3301
# Finished 10.2 percent. Acceptance Rate: 20.3373
# Finished 10.22 percent. Acceptance Rate: 20.3386
# Finished 10.24 percent. Acceptance Rate: 20.3359
# Finished 10.26 percent. Acceptance Rate: 20.3392
# Finished 10.28 percent. Acceptance Rate: 20.3405
# Finished 15.98 percent. Acceptance Rate: 20.2966
# Finished 16 percent. Acceptance Rate: 20.3
# Finished 16.02 percent. Acceptance Rate: 20.3109
# Finished 16.04 percent. Acceptance Rate: 20.318
# Finished 16.06 percent. Acceptance Rate: 20.3188
# Finished 16.08 percent. Acceptance Rate: 20.3221
# Finished 16.1 percent. Acceptance Rate: 20.3379
# Finished 16.12 percent. Acceptance Rate: 20.3424
# Finished 16.14 percent. Acceptance Rate: 20.3457
# Finished 16.16 percent. Acceptance Rate: 20.3453
# Finished 16.18 percent. Acceptance Rate: 20.3399
# Finished 16.2 percent. Acceptance Rate: 20.3407
# Finished 16.22 percent. Acceptance Rate: 20.3539
# Finished 16.24 percent. Acceptance Rate: 20.3584
# Finished 16.26 percent. Acceptance Rate: 20.3653
# Finished 16.28 percent. Acceptance Rate: 20.3735
# Finished 16.3 percent. Acceptance Rate: 20.3656
# Finished 16.32 percent. Acceptance Rate: 20.3517
# Finished 16.34 percent. Acceptance Rate: 20.3366
# Finished 16.36 percent. Acceptance Rate: 20.3447
# Finished 16.38 percent. Acceptance Rate: 20.3529
# Finished 16.4 percent. Acceptance Rate: 20.3524
# Finished 16.42 percent. Acceptance Rate: 20.3398
# Finished 16.44 percent. Acceptance Rate: 20.3382
# Finished 16.46 percent. Acceptance Rate: 20.3341
# Finished 16.48 percent. Acceptance Rate: 20.3447
# Finished 16.5 percent. Acceptance Rate: 20.3527
# Finished 16.52 percent. Acceptance Rate: 20.3596
# Finished 16.54 percent. Acceptance Rate: 20.3458
# Finished 16.56 percent. Acceptance Rate: 20.3357
# Finished 16.58 percent. Acceptance Rate: 20.3293
# Finished 16.6 percent. Acceptance Rate: 20.3265
# Finished 16.62 percent. Acceptance Rate: 20.3273
# Finished 16.64 percent. Acceptance Rate: 20.3245
# Finished 16.66 percent. Acceptance Rate: 20.3133
# Finished 16.68 percent. Acceptance Rate: 20.3129
# Finished 16.7 percent. Acceptance Rate: 20.3018
# Finished 16.72 percent. Acceptance Rate: 20.2931
# Finished 16.74 percent. Acceptance Rate: 20.2915
# Finished 16.76 percent. Acceptance Rate: 20.3007
# Finished 16.78 percent. Acceptance Rate: 20.298
# Finished 16.8 percent. Acceptance Rate: 20.2857
# Finished 16.82 percent. Acceptance Rate: 20.283
# Finished 16.84 percent. Acceptance Rate: 20.2743
# Finished 16.86 percent. Acceptance Rate: 20.2705
# Finished 16.88 percent. Acceptance Rate: 20.2725
# Finished 16.9 percent. Acceptance Rate: 20.2698
# Finished 16.92 percent. Acceptance Rate: 20.266
# Finished 16.94 percent. Acceptance Rate: 20.2586
# Finished 16.96 percent. Acceptance Rate: 20.2583
# Finished 16.98 percent. Acceptance Rate: 20.2462
# Finished 17 percent. Acceptance Rate: 20.2471
# Finished 17.02 percent. Acceptance Rate: 20.2421
# Finished 17.04 percent. Acceptance Rate: 20.2394
# Finished 17.06 percent. Acceptance Rate: 20.2368
# Finished 17.08 percent. Acceptance Rate: 20.2354
# Finished 17.1 percent. Acceptance Rate: 20.2316
# Finished 99.62 percent. Acceptance Rate: 19.9289
# Finished 99.64 percent. Acceptance Rate: 19.9283
# Finished 99.66 percent. Acceptance Rate: 19.9286
# Finished 99.68 percent. Acceptance Rate: 19.9292
# Finished 99.7 percent. Acceptance Rate: 19.9314
# Finished 99.72 percent. Acceptance Rate: 19.932
# Finished 99.74 percent. Acceptance Rate: 19.9302
# Finished 99.76 percent. Acceptance Rate: 19.931
# Finished 99.78 percent. Acceptance Rate: 19.9294
# Finished 99.8 percent. Acceptance Rate: 19.9277
# Finished 99.82 percent. Acceptance Rate: 19.9267
# Finished 99.84 percent. Acceptance Rate: 19.9247
# Finished 99.86 percent. Acceptance Rate: 19.9229
# Finished 99.88 percent. Acceptance Rate: 19.9237
# Finished 99.9 percent. Acceptance Rate: 19.9233
# Finished 99.92 percent. Acceptance Rate: 19.9239
# Finished 99.94 percent. Acceptance Rate: 19.9232
# Finished 99.96 percent. Acceptance Rate: 19.9222
# Finished 99.98 percent. Acceptance Rate: 19.9228

# %%
sampler.chain.shape
# Out:
# (500000, 21)

# %%
triangle.corner(sampler.chain[10000:,:5])

# %%
"""
Given a collection of samples, return the 2-sigma confidence intervals
samples: an array of samples
sigmalevel: either 1, 2, or 3. Which sigma limit must be given
onesided: Give one-sided limits (useful for setting upper or lower limits)

"""
def confinterval(samples, sigmalevel=2, onesided=False, weights=None):
  # The probabilities for different sigmas
  sigma = [0.68268949, 0.95449974, 0.99730024]

  bins = 200
  xmin = min(samples)
  xmax = max(samples)

  # If we don't have any weighting (MCMC chain), use the statsmodels package
  if weights is None and sm != None:
    # Create the ecdf function
    ecdf = sm.distributions.ECDF(samples)

    # Create the binning
    x = np.linspace(xmin, xmax, bins)
    y = ecdf(x)
  else:
    # MultiNest chain with weights or no statsmodel.api package
    # hist, xedges = np.histogram(samples[:], bins=bins, range=(xmin,xmax), weights=weights, density=True)
    hist, xedges = np.histogram(samples[:], bins=bins, range=(xmin,xmax), weights=weights)
    x = np.delete(xedges, -1) + 0.5*(xedges[1] - xedges[0])     # This was originally 1.5*, but turns out this is a bug plotting of 'stepstyle' in matplotlib
    y = np.cumsum(hist) / np.sum(hist)

  # Find the intervals
  if(onesided):
    bound = 1 - sigma[sigmalevel-1]
  else:
    bound = 0.5*(1-sigma[sigmalevel-1])

  x2min = x[0]
  for i in range(len(y)):
    if y[i] >= bound:
      x2min = x[i]
      break

  if(onesided):
    bound = sigma[sigmalevel-1]
  else:
    bound = 1 - 0.5 * (1 - sigma[sigmalevel-1])

  x2max = x[-1]
  for i in reversed(range(len(y))):
    if y[i] <= bound:
      x2max = x[i]
      break

  return x2min, x2max

# %%
import scipy.stats as sst
import statsmodels.api as sm

# %%
s = sampler.chain[10000:,1]

print confinterval(s)
print sst.bayes_mvs(s, alpha=0.95)
# Out:
# (-17.909558021300413, -13.779935059420827)
# ((-16.34476992117575, (-16.348024247869052, -16.341515594482448)), (1.3508968684373293, (1.3455476880479884, 1.3562460488266701)), (1.1622808905068212, (1.1599797340337898, 1.1645820469798525)))

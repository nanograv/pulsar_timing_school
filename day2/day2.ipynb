# %%
import numpy as np
import scipy.linalg as sl
import scipy.special as ss
import libstempo as lt, libstempo.plot as ltp, libstempo.toasim as ltt
import matplotlib.pyplot as plt
import os, sys, glob
import simple_mcmc as smcmc
import triangle
# %matplotlib inline
# Out:
# Warning: cannot find astropy, units support will not be available.

# %% [markdown]
# # Day 2: do a simple noise analysis #
#
# We are going to do a simple noise analysis today. For a whole bunch of pulsars, you will find datafiles in the directory 'signals'. We will analyze one pulsar (say, J0030) today for noise. In order to do that, we have provided some auxiliary functions

# %% [markdown]
# ## Some constants ##
#
# These constants will come in handy

# %%
day = 86400.0                   # Seconds per day
year =  31557600.0              # Seconds per year (yr = 365.25 days, so Julian years)
EulerGamma = 0.5772156649015329 # Euler gamma constant
mjdT0 = 54000.0                 # MJD to which all toas are referenced (for precision)

# %% [markdown]
# ## Design matrix ##
# In case we do not use the tempo2 design matrix, we can generate one ourselves for quadratic spindown

# %%
def designqsd(t, order=2):
    """
    Calculate the design matrix for quadratic spindown

    :param t:
        array of toas
    """
    M = np.ones([len(t), order+1])
    for ii in range(1, order+1):
        M[:,ii] = t ** ii
    
    return M.copy()

# %% [markdown]
# ## Fourier basis ##
# Like the design matrix, we need a basis for the Fourier amplitudes as well.

# %%
def fourierdesignmatrix(t, nmodes, Ttot=None):
    """
    Calculate the matrix of Fourier modes A, given a set of timestamps

    These are sine/cosine basis vectors at evenly separated frequency bins

    Mode 0: sin(f_0)
    Mode 1: cos(f_0)
    Mode 2: sin(f_1)
    ... etc

    :param nmodes:
        The number of modes that will be included (= 2*nfreq)
    :param Ttot:
        Total duration experiment (in case not given by t)

    :return:
        (A, freqs), with A the 'fourier design matrix', and f the associa

    """
    N = t.size
    A = np.zeros([N, nmodes])
    T = t.max() - t.min()

    if(nmodes % 2 != 0):
      print "WARNING: Number of modes should be even!"

    if Ttot is None:
        deltaf = 1.0 / T
    else:
        deltaf = 1.0 / Ttot

    freqs1 = np.linspace(deltaf, (nmodes/2)*deltaf, nmodes/2)
    freqs = np.array([freqs1, freqs1]).T.flatten()

    # The cosine modes
    for i in range(0, nmodes, 2):
        omega = 2.0 * np.pi * freqs[i]
        A[:,i] = np.cos(omega * t)

    # The sine modes
    for i in range(1, nmodes, 2):
        omega = 2.0 * np.pi * freqs[i]
        A[:,i] = np.sin(omega * t)

    return (A, freqs)

# %% [markdown]
# ## Functions for power-law spectral analysis ##
# In order to do spectral analysis, we need the PSD, the covariance function (PSD cosine transform), and the covariance matrix.

# %%
def PL_psd(f, amp, alpha, sig_fL):
    """
    PSD for a power-law signal.

    :param f:
        Array of frequencies for which to return the PSD (1/sec)

    :param amp:
        Unitless amplitude of the power-law signal

    :param alpha:
        Spectral index

    :param sig_fL:
        Signal low-frequency cut-off. A physical bound
    
    Note that this function returns the power per
    frequency bin of (1/Tmax) size, so the units are in sec^2 / (1/Tmax)
    """
    Si = 3.0 - 2.0*alpha

    Tmax = 1.0 / np.min(f)

    freqpy = f * year

    mask = (freqpy >= sig_fL)

    psd = np.zeros(len(freqpy))
    psd[mask] = (amp**2 * year**3 / (12*np.pi*np.pi * Tmax)) * freqpy[mask] ** (-Si)
    
    return psd


# Calculate the covariance matrix for a red signal
# (for a GWB with unitless amplitude h_c(1yr^{-1}) = 1)
def PL_covfunc(tau, amp, alpha=-2.0/3.0, fL=1.0/(year*20)):
    """
    Compute the covariance function for a powerlaw
    Result is in units of (sec)^2.

    :param tau:
        the time lag

    :param amp:
        amplitude

    :param alpha:
        the GWB spectral index

    :param fL:
        the low-frequency cut-off
    """
    fL = fL * year
    x = 2 * np.pi * fL * np.abs(tau) / year
    cf = ss.gamma(-2+2*alpha) * np.cos(np.pi*alpha)
    power = cf * x**(2-2*alpha)
    ksum = ss.hyp1f2(alpha-1,0.5,alpha,-0.25*x**2)[0]/(2*alpha-2)
    corr = -(year**2 * fL**(-2+2*alpha)) / (12 * np.pi**2) * (power + ksum)
    
    return amp**2*corr


def PL_covmat(toas, amp, alpha=-2.0/3.0, fL=1.0/(year*20)):
    """
    Use the covariance function PL_covfunc to create the covariance matrix for
    'toas'. Result is in units of (sec)^2

    :param tau:
        the time lag

    :param amp:
        amplitude

    :param alpha:
        the GWB spectral index

    :param fL:
        the low-frequency cut-off
    """
    t1, t2 = np.meshgrid(toas, toas)
    tau = np.abs(t1-t2)

    return PL_covfunc(tau, amp, alpha, fL)

# %% [markdown]
# ## A simple pulsar class ##
#
# This class does not do much. It neatly stores data for you, and conveniently creates the Fourier basis for spectral analysis

# %%
class Pulsar(object):
    def __init__(self, toas, residuals, toaerrs, desmat=None, nfreqs=20,
            qsdorder=2, Tlow=None):
        """
        Initialise the pulsar from data

        :param toas:
            The barycentric times of arrival [MJD]

        :param residuals:
            The timing residuals [sec]

        :param toaerrs:
            The TOA uncertainties [sec]

        :param desmat:
            The design matrix (default None)

        :param nfreqs:
            The number of frequencies we'll use in the Fourier expansion

        :param qsdorder:
            If desmat=None, make a design matrix from scratch, with this order

        :param Tlow:
            1/lowest frequency used in expansion (default length of dataset)(
        """
        self.toas = (toas - mjdT0) * day       # MJD to seconds
        self.residuals = residuals
        self.toaerrs = toaerrs
        self.Mmat = desmat
        self.nobs = len(toas)
        self.nfreqs = nfreqs

        self.T = (np.max(self.toas) - np.min(self.toas))

        if self.Mmat is None:
            self.Mmat = designqsd(self.toas, order=qsdorder)

        # Create the basis of Fourier components
        if Tlow is None:
            Tlow = (np.max(self.toas) - np.min(self.toas))
        (self.Fmat, self.freqs) = fourierdesignmatrix(self.toas, 2*nfreqs, Ttot=Tlow)

# %% [markdown]
# # Exercise 1 #
# In this exercise, we test the provided functions above. We'll read in data, and construct the PSD-derived functions

# %% [markdown]
# # Exercise 1a #
# Read in a pulsar of your choice, and initialize the pulsar class

# %%
psrnum = 0 # J0030
psrlist = glob.glob('signals/J?????????.txt')
psrname = os.path.splitext(psrlist[psrnum])[0]
sigfile = psrname + '.txt'
desfile = psrname + '-des.txt'

# %%
dat = np.loadtxt(sigfile)
toas = dat[:,0]
residuals = dat[:,1]
toaerrs = dat[:,2]
desmat = np.loadtxt(desfile)
psr = Pulsar(toas, residuals, toaerrs, desmat=desmat, nfreqs=10)

# %% [markdown]
# # Exercise 1b #
# Plot the timing residuals, including the measurement uncertainties

# %%
plt.errorbar(toas, residuals, yerr=toaerrs, fmt='x', c='blue')
# Out:
# <Container object of 3 artists>

# %% [markdown]
# # Exercise 1c #
# For a red noise signal with $\alpha=-\frac{2}{3}$, and $A=10^{-14}$, plot the power spectral density and the covariance function.
#
# What is the effect of the low-frequency cut-off on either of these?

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)

# Power-law parameters
amp = 1.0e-14
alpha = -2.0/3.0
fL = 1.0 / (np.max(psr.toas) - np.min(psr.toas))

# Create the PSD
psd = PL_psd(psr.freqs, amp=1.0e-14, alpha=-2.0/3.0, sig_fL=fL)
ax[0].loglog(psr.freqs, psd)

# Create the covariance function
tau = psr.toas-np.min(psr.toas)
covf = PL_covfunc(tau, amp, alpha, fL=fL/4.0)
ax[1].plot(tau, covf)

# %% [markdown]
# ## Exercise 1d ##
# How could you use the psd of the previous exercise to generate mock timing residuals?

# %%
mockres = np.dot(psr.Fmat, np.sqrt(psd) * np.random.randn(len(psd)))
plt.plot(psr.toas, mockres)

# %% [markdown]
# # Exercise 2 #
# We will be writing log-likelihood functions here. First we will give two log-likelihood functions that can be used for _simple_ analyses, but they are not fast. You will be challenged to write a faster version. If you don't manage, use one of these slower versions for the MCMC exercise in exercise 3.

# %%
def mark1loglikelihood(psr, Aw, Ar, Si):
    """
    Log-likelihood for our pulsar. This one does not marginalize
    over the timing model, so it cannot be used if the data has been
    'fit'. Use when creating data with 'dofit=False':
    psr = Pulsar(dofit=False)
    
    Calculate covariance matrix in the time-domain with:
    
    ll = -0.5 * res^{T} C^{-1} res - 0.5 * log(det(C))
    
    :param psr:
        pulsar object, containing the data and stuff

    :param Aw:
        White noise amplitude, model parameter

    :param Ar:
        Red noise amplitude, model parameter

    :param Si:
        Spectral index of red noise, model parameter
    """
    
    # The function that builds the non-diagonal covariance matrix is Cred_sec
    #Cov = Aw**2 * np.eye(len(psr.toas)) + \
    #      Ar**2 * Cred_sec(psr.toas, alpha=0.5*(3-Si))
    Cov = Aw**2 * np.eye(len(psr.toas)) + \
        PL_covmat(psr.toas, Ar, alpha=0.5*(3-Si), fL=1.0/(year*20))
    
    cfC = sl.cho_factor(Cov)
    ldetC = 2 * np.sum(np.log(np.diag(cfC[0])))
    rCr = np.dot(psr.residuals, sl.cho_solve(cfC, psr.residuals))
    
    return -0.5 * rCr - 0.5 * ldetC - 0.5*len(psr.residuals)*np.log(2*np.pi)

def mark2loglikelihood(psr, Aw, Ar, Si):
    """
    Log-likelihood for our pulsar
    
    This likelihood does marginalize over the timing model. Calculate
    covariance matrix in the time-domain with:
    
    ll = 0.5 * res^{t} (C^{-1} - C^{-1} M (M^{T} C^{-1} M)^{-1} M^{T} C^{-1} ) res - \
         0.5 * log(det(C)) - 0.5 * log(det(M^{T} C^{-1} M))
         
    In relation to 'mark1loglikelihood', this likelihood has but a simple addition:
    res' = res - M xi
    where M is a (n x m) matrix, with m < n, and xi is a vector of length m. The xi
    are analytically marginalised over, yielding the above equation (up to constants)
    
    :param psr:
        pulsar object, containing the data and stuff

    :param Aw:
        White noise amplitude, model parameter

    :param Ar:
        Red noise amplitude, model parameter

    :param Si:
        Spectral index of red noise, model parameter
    """
    Mmat = psr.Mmat
    
    Cov = Aw**2 * np.eye(len(psr.toas)) + \
        PL_covmat(psr.toas, Ar, alpha=0.5*(3-Si), fL=1.0/(year*20))
    
    cfC = sl.cho_factor(Cov)
    Cinv = sl.cho_solve(cfC, np.eye(len(psr.toas)))
    ldetC = 2 * np.sum(np.log(np.diag(cfC[0])))

    MCM = np.dot(Mmat.T, np.dot(Cinv, Mmat))
    cfM = sl.cho_factor(MCM)
    ldetM = 2 * np.sum(np.log(np.diag(cfM[0])))
    
    wr = np.dot(Cinv, psr.residuals)
    rCr = np.dot(psr.residuals, wr)
    MCr = np.dot(Mmat.T, wr)
    
    return -0.5 * rCr + 0.5 * np.dot(MCr, sl.cho_solve(cfM, MCr)) - \
            0.5 * ldetC - 0.5 * ldetM -0.5*len(psr.residuals)*np.log(2*np.pi)

# %% [markdown]
# ## Exercise 2a ##
# Write the log-likelihood function using the hierachical model (with the Woodbury matrix identity) as shown in the presentation. How much faster is it?

# %%
def mark3loglikelihood(psr, Nvec, psd):
    """
    Log-likelihood for our pulsar (hierarchical/Woodbury)

    :param psr:
        pulsar object, containing the data and stuff

    :param Nvec:
        Vector of squared white noise amplitude (diagonal of covariance matrix)

    :param psd:
        Power-spectral density per frequency bin (of size 1/T)
    """
    Mmat, Fmat = psr.Mmat, psr.Fmat
    Tmat = np.append(Mmat, Fmat, axis=1)
    n, m, l = len(psr.toas), Mmat.shape[1], Fmat.shape[1]

    # Sigma matrix (inverse)
    TNT = np.dot(Tmat.T / Nvec, Tmat)
    phi_inv = np.zeros(m+l)
    phi_inv[m:] = 1.0/psd
    Sigma_inv = TNT + np.diag(phi_inv)

    # Invert Sigma_inv for use in the Woodbury identity
    #Sigma = sl.inv(Sigma_inv)       # Does not use Cholesky
    cf = sl.cho_factor(Sigma_inv)
    STNr = sl.cho_solve(cf, np.dot(Tmat.T / Nvec, psr.residuals))
    rNTSTNr = np.dot(psr.residuals, np.dot((Tmat.T / Nvec).T, STNr))
    rNr = np.sum(psr.residuals**2/Nvec)

    # The full Woodbury expansion
    rCr = rNr - rNTSTNr

    # Determinants
    logNdet = np.sum(np.log(Nvec))
    logPhidet = np.sum(np.log(psd))
    logSigmadet = 2.0*np.sum(np.log(np.diag(cf[0])))

    # Sylvester Matrix identity
    logCdet = logNdet + logPhidet + logSigmadet

    return -0.5*rCr-0.5*logCdet-0.5*n*np.log(2*np.pi)

def pl_loglikelihood(psr, Aw, Ar, Si):
    """
    Log-likelihood for our pulsar (hierarchical/Woodbury)

    :param psr:
        pulsar object, containing the data and stuff

    :param Aw:
        White noise amplitude [sec]
        
    :param Ar:
        Power-law red noise amplitude []

    :param Si:
        Power-law red noise spectral index []
    """
    Nvec = np.ones(len(psr.toas)) * Aw**2
    psd = PL_psd(psr.freqs, Ar, 0.5*(3-Si), sig_fL=1.0/(20.0*year))
    return mark3loglikelihood(psr, Nvec, psd)

def sp_loglikelihood(psr, Aw, psd):
    """
    Log-likelihood for our pulsar (hierarchical/Woodbury)

    :param psr:
        pulsar object, containing the data and stuff

    :param Aw:
        White noise amplitude [sec]
        
    :param psd:
        Vector PSD amplitudes [sec]
    """    
    if len(psd)*2 != psr.Fmat.shape[1]:
        raise ValueError("PSD vector not of appropriate length!")

    Nvec = np.ones(len(psr.toas)) * Aw**2
    return mark3loglikelihood(psr, Nvec, psd.repeat(2))

# %%
# %timeit mark1loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
# %timeit mark2loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
# %timeit pl_loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
# Out:
# 100 loops, best of 3: 4.65 ms per loop
# 100 loops, best of 3: 6.39 ms per loop
# 1000 loops, best of 3: 284 µs per loop

# %% [markdown]
# # Exercise 2b #
# Plot the log-likelihood as a function of power-law amplitude for the range 10**(-16, -13), with $\gamma=13/3$

# %%
# The log-likelihood for a particular value of A
print mark1loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
print mark2loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
print pl_loglikelihood(psr, 1.0e-7, 1.0e-15, 4.33)
# Out:
# 2901.95293242
# 2758.93873165
# 2758.97762831

# %%
Ar = np.linspace(-16.0, -13.0, 100)
ll1 = np.zeros_like(Ar)
ll2 = np.zeros_like(Ar)
ll3 = np.zeros_like(Ar)

for ii, A in enumerate(Ar):
    amp = 10**(A)
    ll1[ii] = mark1loglikelihood(psr, 1.0e-7, amp, 4.33)
    ll2[ii] = mark2loglikelihood(psr, 1.0e-7, amp, 4.33)
    ll3[ii] = pl_loglikelihood(psr, 1.0e-7, amp, 4.33)

plt.plot(Ar, np.exp(ll1-np.max(ll1)), 'b')
plt.plot(Ar, np.exp(ll2-np.max(ll2)), 'g')
plt.plot(Ar, np.exp(ll3-np.max(ll3)), 'r--')

# %% [markdown]
# ## Exercise 2c ##
# Run a simple MCMC, using the sampler you wrote yesterday, to discover the injected value of:
#  * white noise
#  * power-law red noise amplitude
#  * power-law red noise spectral index

# %%
# Run a simple MCMC on the power-law
def loglik(x):
    return pl_loglikelihood(psr, 10**x[0], 10**x[1], x[2])

def logprior(x):
    rv = 0.0
    xmin = np.array([-10.0, -18.0, 0.0])
    xmax = np.array([-4.0, -12.0, 9.0])
    
    if np.any(x < xmin) or np.any(x > xmax):
        rv = -np.inf
        
    return rv

p0 = np.array([-7.0, -14.0, 4.33])
sigmas = np.array([0.1, 0.1, 0.1])
sampler = smcmc.SimpleMCMC(loglik, logprior, sigmas)

# %%
sampler.sample(p0, 50000)
# Out:
# Finished 0.2 percent. Acceptance Rate: 29
# Finished 0.4 percent. Acceptance Rate: 27.5
# Finished 0.6 percent. Acceptance Rate: 25
# Finished 0.8 percent. Acceptance Rate: 24.75
# Finished 1 percent. Acceptance Rate: 24.4
# Finished 1.2 percent. Acceptance Rate: 25
# Finished 1.4 percent. Acceptance Rate: 25
# Finished 1.6 percent. Acceptance Rate: 24.75
# Finished 1.8 percent. Acceptance Rate: 24.6667
# Finished 2 percent. Acceptance Rate: 24
# Finished 2.2 percent. Acceptance Rate: 23.8182
# Finished 2.4 percent. Acceptance Rate: 23.25
# Finished 2.6 percent. Acceptance Rate: 23.3846
# Finished 2.8 percent. Acceptance Rate: 23.3571
# Finished 3 percent. Acceptance Rate: 23.3333
# Finished 3.2 percent. Acceptance Rate: 23.125
# Finished 3.4 percent. Acceptance Rate: 23
# Finished 3.6 percent. Acceptance Rate: 23
# Finished 3.8 percent. Acceptance Rate: 22.8421
# Finished 4 percent. Acceptance Rate: 22.55
# Finished 4.2 percent. Acceptance Rate: 22.9048
# Finished 4.4 percent. Acceptance Rate: 22.5
# Finished 4.6 percent. Acceptance Rate: 22.7826
# Finished 4.8 percent. Acceptance Rate: 22.75
# Finished 5 percent. Acceptance Rate: 23.12
# Finished 5.2 percent. Acceptance Rate: 23.1538
# Finished 5.4 percent. Acceptance Rate: 23.2222
# Finished 5.6 percent. Acceptance Rate: 23.25
# Finished 5.8 percent. Acceptance Rate: 23.3448
# Finished 6 percent. Acceptance Rate: 23.4
# Finished 6.2 percent. Acceptance Rate: 23.4516
# Finished 6.4 percent. Acceptance Rate: 23.75
# Finished 6.6 percent. Acceptance Rate: 23.7273
# Finished 6.8 percent. Acceptance Rate: 23.5588
# Finished 7 percent. Acceptance Rate: 23.4571
# Finished 7.2 percent. Acceptance Rate: 23.5
# Finished 7.4 percent. Acceptance Rate: 23.5676
# Finished 7.6 percent. Acceptance Rate: 23.6316
# Finished 7.8 percent. Acceptance Rate: 23.6667
# Finished 8 percent. Acceptance Rate: 23.9
# Finished 8.2 percent. Acceptance Rate: 24.1463
# Finished 8.4 percent. Acceptance Rate: 23.9762
# Finished 8.6 percent. Acceptance Rate: 23.8605
# Finished 8.8 percent. Acceptance Rate: 24.0682
# Finished 9 percent. Acceptance Rate: 24
# Finished 9.2 percent. Acceptance Rate: 24.0217
# Finished 9.4 percent. Acceptance Rate: 23.9574
# Finished 9.6 percent. Acceptance Rate: 23.8125
# Finished 9.8 percent. Acceptance Rate: 23.8776
# Finished 10 percent. Acceptance Rate: 23.92
# Finished 10.2 percent. Acceptance Rate: 23.902
# Finished 10.4 percent. Acceptance Rate: 24.0962
# Finished 10.6 percent. Acceptance Rate: 24.1321
# Finished 10.8 percent. Acceptance Rate: 24.0556
# Finished 11 percent. Acceptance Rate: 24
# Finished 11.2 percent. Acceptance Rate: 23.9286
# Finished 11.4 percent. Acceptance Rate: 23.9649
# Finished 11.6 percent. Acceptance Rate: 24.0345
# Finished 11.8 percent. Acceptance Rate: 23.9492
# Finished 12 percent. Acceptance Rate: 23.8667
# Finished 12.2 percent. Acceptance Rate: 23.9836
# Finished 12.4 percent. Acceptance Rate: 23.9194
# Finished 12.6 percent. Acceptance Rate: 24
# Finished 12.8 percent. Acceptance Rate: 24.0781
# Finished 13 percent. Acceptance Rate: 24.0615
# Finished 13.2 percent. Acceptance Rate: 24.0758
# Finished 13.4 percent. Acceptance Rate: 24.1642
# Finished 13.6 percent. Acceptance Rate: 24.2206
# Finished 13.8 percent. Acceptance Rate: 24.2319
# Finished 14 percent. Acceptance Rate: 24.3286
# Finished 14.2 percent. Acceptance Rate: 24.3944
# Finished 14.4 percent. Acceptance Rate: 24.2917
# Finished 14.6 percent. Acceptance Rate: 24.4247
# Finished 14.8 percent. Acceptance Rate: 24.4459
# Finished 15 percent. Acceptance Rate: 24.4133
# Finished 15.2 percent. Acceptance Rate: 24.3947
# Finished 15.4 percent. Acceptance Rate: 24.4156
# Finished 15.6 percent. Acceptance Rate: 24.5256
# Finished 15.8 percent. Acceptance Rate: 24.5823
# Finished 16 percent. Acceptance Rate: 24.625
# Finished 16.2 percent. Acceptance Rate: 24.679
# Finished 16.4 percent. Acceptance Rate: 24.6463
# Finished 16.6 percent. Acceptance Rate: 24.6988
# Finished 16.8 percent. Acceptance Rate: 24.7024
# Finished 17 percent. Acceptance Rate: 24.7176
# Finished 17.2 percent. Acceptance Rate: 24.6744
# Finished 17.4 percent. Acceptance Rate: 24.6437
# Finished 17.6 percent. Acceptance Rate: 24.6364
# Finished 17.8 percent. Acceptance Rate: 24.573
# Finished 18 percent. Acceptance Rate: 24.5889
# Finished 18.2 percent. Acceptance Rate: 24.6374
# Finished 18.4 percent. Acceptance Rate: 24.7174
# Finished 18.6 percent. Acceptance Rate: 24.6452
# Finished 18.8 percent. Acceptance Rate: 24.6915
# Finished 19 percent. Acceptance Rate: 24.6632
# Finished 19.2 percent. Acceptance Rate: 24.6562
# Finished 19.4 percent. Acceptance Rate: 24.8041
# Finished 19.6 percent. Acceptance Rate: 24.7551
# Finished 19.8 percent. Acceptance Rate: 24.798
# Finished 20 percent. Acceptance Rate: 24.8
# Finished 20.2 percent. Acceptance Rate: 24.7723
# Finished 20.4 percent. Acceptance Rate: 24.7255
# Finished 20.6 percent. Acceptance Rate: 24.7282
# Finished 20.8 percent. Acceptance Rate: 24.6731
# Finished 21 percent. Acceptance Rate: 24.6762
# Finished 21.2 percent. Acceptance Rate: 24.6604
# Finished 21.4 percent. Acceptance Rate: 24.7196
# Finished 21.6 percent. Acceptance Rate: 24.7407
# Finished 21.8 percent. Acceptance Rate: 24.6881
# Finished 22 percent. Acceptance Rate: 24.6182
# Finished 22.2 percent. Acceptance Rate: 24.6216
# Finished 22.4 percent. Acceptance Rate: 24.5893
# Finished 22.6 percent. Acceptance Rate: 24.6195
# Finished 22.8 percent. Acceptance Rate: 24.5789
# Finished 23 percent. Acceptance Rate: 24.5652
# Finished 23.2 percent. Acceptance Rate: 24.6293
# Finished 23.4 percent. Acceptance Rate: 24.6581
# Finished 23.6 percent. Acceptance Rate: 24.6271
# Finished 23.8 percent. Acceptance Rate: 24.6303
# Finished 24 percent. Acceptance Rate: 24.625
# Finished 24.2 percent. Acceptance Rate: 24.6116
# Finished 24.4 percent. Acceptance Rate: 24.5902
# Finished 24.6 percent. Acceptance Rate: 24.6016
# Finished 24.8 percent. Acceptance Rate: 24.6452
# Finished 25 percent. Acceptance Rate: 24.68
# Finished 25.2 percent. Acceptance Rate: 24.6746
# Finished 25.4 percent. Acceptance Rate: 24.6457
# Finished 25.6 percent. Acceptance Rate: 24.625
# Finished 25.8 percent. Acceptance Rate: 24.6899
# Finished 26 percent. Acceptance Rate: 24.6923
# Finished 26.2 percent. Acceptance Rate: 24.7328
# Finished 26.4 percent. Acceptance Rate: 24.6818
# Finished 26.6 percent. Acceptance Rate: 24.6466
# Finished 26.8 percent. Acceptance Rate: 24.6119
# Finished 27 percent. Acceptance Rate: 24.5704
# Finished 27.2 percent. Acceptance Rate: 24.5221
# Finished 27.4 percent. Acceptance Rate: 24.4672
# Finished 27.6 percent. Acceptance Rate: 24.4348
# Finished 27.8 percent. Acceptance Rate: 24.3957
# Finished 28 percent. Acceptance Rate: 24.4
# Finished 28.2 percent. Acceptance Rate: 24.3262
# Finished 28.4 percent. Acceptance Rate: 24.2254
# Finished 28.6 percent. Acceptance Rate: 24.2028
# Finished 28.8 percent. Acceptance Rate: 24.1944
# Finished 29 percent. Acceptance Rate: 24.2414
# Finished 29.2 percent. Acceptance Rate: 24.2466
# Finished 29.4 percent. Acceptance Rate: 24.2449
# Finished 29.6 percent. Acceptance Rate: 24.2365
# Finished 29.8 percent. Acceptance Rate: 24.2617
# Finished 30 percent. Acceptance Rate: 24.24
# Finished 30.2 percent. Acceptance Rate: 24.2649
# Finished 30.4 percent. Acceptance Rate: 24.2237
# Finished 30.6 percent. Acceptance Rate: 24.2092
# Finished 30.8 percent. Acceptance Rate: 24.2143
# Finished 31 percent. Acceptance Rate: 24.2194
# Finished 31.2 percent. Acceptance Rate: 24.1987
# Finished 31.4 percent. Acceptance Rate: 24.1975
# Finished 31.6 percent. Acceptance Rate: 24.1772
# Finished 31.8 percent. Acceptance Rate: 24.2516
# Finished 32 percent. Acceptance Rate: 24.2937
# Finished 32.2 percent. Acceptance Rate: 24.2795
# Finished 32.4 percent. Acceptance Rate: 24.284
# Finished 32.6 percent. Acceptance Rate: 24.2638
# Finished 32.8 percent. Acceptance Rate: 24.2927
# Finished 33 percent. Acceptance Rate: 24.2727
# Finished 33.2 percent. Acceptance Rate: 24.2831
# Finished 33.4 percent. Acceptance Rate: 24.2874
# Finished 33.6 percent. Acceptance Rate: 24.2857
# Finished 33.8 percent. Acceptance Rate: 24.2722
# Finished 34 percent. Acceptance Rate: 24.3176
# Finished 34.2 percent. Acceptance Rate: 24.3684
# Finished 34.4 percent. Acceptance Rate: 24.343
# Finished 34.6 percent. Acceptance Rate: 24.3815
# Finished 34.8 percent. Acceptance Rate: 24.431
# Finished 35 percent. Acceptance Rate: 24.4114
# Finished 35.2 percent. Acceptance Rate: 24.3977
# Finished 35.4 percent. Acceptance Rate: 24.3898
# Finished 35.6 percent. Acceptance Rate: 24.3933
# Finished 35.8 percent. Acceptance Rate: 24.3575
# Finished 36 percent. Acceptance Rate: 24.3389
# Finished 36.2 percent. Acceptance Rate: 24.3702
# Finished 36.4 percent. Acceptance Rate: 24.3516
# Finished 36.6 percent. Acceptance Rate: 24.377
# Finished 36.8 percent. Acceptance Rate: 24.3533
# Finished 37 percent. Acceptance Rate: 24.3189
# Finished 37.2 percent. Acceptance Rate: 24.3065
# Finished 37.4 percent. Acceptance Rate: 24.2941
# Finished 37.6 percent. Acceptance Rate: 24.2606
# Finished 37.8 percent. Acceptance Rate: 24.3016
# Finished 38 percent. Acceptance Rate: 24.2789
# Finished 38.2 percent. Acceptance Rate: 24.2513
# Finished 38.4 percent. Acceptance Rate: 24.2604
# Finished 38.6 percent. Acceptance Rate: 24.2539
# Finished 38.8 percent. Acceptance Rate: 24.2113
# Finished 39 percent. Acceptance Rate: 24.2
# Finished 39.2 percent. Acceptance Rate: 24.2194
# Finished 39.4 percent. Acceptance Rate: 24.2234
# Finished 39.6 percent. Acceptance Rate: 24.1919
# Finished 39.8 percent. Acceptance Rate: 24.191
# Finished 40 percent. Acceptance Rate: 24.195
# Finished 40.2 percent. Acceptance Rate: 24.1841
# Finished 40.4 percent. Acceptance Rate: 24.1337
# Finished 40.6 percent. Acceptance Rate: 24.1576
# Finished 40.8 percent. Acceptance Rate: 24.1814
# Finished 41 percent. Acceptance Rate: 24.1854
# Finished 41.2 percent. Acceptance Rate: 24.2087
# Finished 41.4 percent. Acceptance Rate: 24.1932
# Finished 41.6 percent. Acceptance Rate: 24.1683
# Finished 41.8 percent. Acceptance Rate: 24.177
# Finished 42 percent. Acceptance Rate: 24.1714
# Finished 42.2 percent. Acceptance Rate: 24.1754
# Finished 42.4 percent. Acceptance Rate: 24.1651
# Finished 42.6 percent. Acceptance Rate: 24.1549
# Finished 42.8 percent. Acceptance Rate: 24.1402
# Finished 43 percent. Acceptance Rate: 24.1302
# Finished 43.2 percent. Acceptance Rate: 24.1574
# Finished 43.4 percent. Acceptance Rate: 24.1935
# Finished 43.6 percent. Acceptance Rate: 24.1972
# Finished 43.8 percent. Acceptance Rate: 24.1872
# Finished 44 percent. Acceptance Rate: 24.15
# Finished 44.2 percent. Acceptance Rate: 24.1448
# Finished 44.4 percent. Acceptance Rate: 24.1622
# Finished 44.6 percent. Acceptance Rate: 24.1614
# Finished 44.8 percent. Acceptance Rate: 24.1741
# Finished 45 percent. Acceptance Rate: 24.16
# Finished 45.2 percent. Acceptance Rate: 24.1726
# Finished 45.4 percent. Acceptance Rate: 24.1674
# Finished 45.6 percent. Acceptance Rate: 24.1711
# Finished 45.8 percent. Acceptance Rate: 24.1921
# Finished 46 percent. Acceptance Rate: 24.187
# Finished 46.2 percent. Acceptance Rate: 24.1991
# Finished 46.4 percent. Acceptance Rate: 24.2112
# Finished 46.6 percent. Acceptance Rate: 24.2232
# Finished 46.8 percent. Acceptance Rate: 24.2308
# Finished 47 percent. Acceptance Rate: 24.217
# Finished 47.2 percent. Acceptance Rate: 24.2119
# Finished 47.4 percent. Acceptance Rate: 24.1983
# Finished 47.6 percent. Acceptance Rate: 24.1723
# Finished 47.8 percent. Acceptance Rate: 24.1715
# Finished 48 percent. Acceptance Rate: 24.1667
# Finished 48.2 percent. Acceptance Rate: 24.1618
# Finished 48.4 percent. Acceptance Rate: 24.1694
# Finished 48.6 percent. Acceptance Rate: 24.1523
# Finished 48.8 percent. Acceptance Rate: 24.1107
# Finished 49 percent. Acceptance Rate: 24.1102
# Finished 49.2 percent. Acceptance Rate: 24.1057
# Finished 49.4 percent. Acceptance Rate: 24.1012
# Finished 49.6 percent. Acceptance Rate: 24.0847
# Finished 49.8 percent. Acceptance Rate: 24.1285
# Finished 50 percent. Acceptance Rate: 24.12
# Finished 50.2 percent. Acceptance Rate: 24.1434
# Finished 50.4 percent. Acceptance Rate: 24.1508
# Finished 50.6 percent. Acceptance Rate: 24.1858
# Finished 50.8 percent. Acceptance Rate: 24.2126
# Finished 51 percent. Acceptance Rate: 24.2078
# Finished 51.2 percent. Acceptance Rate: 24.2031
# Finished 51.4 percent. Acceptance Rate: 24.1829
# Finished 51.6 percent. Acceptance Rate: 24.2016
# Finished 51.8 percent. Acceptance Rate: 24.2124
# Finished 52 percent. Acceptance Rate: 24.2231
# Finished 52.2 percent. Acceptance Rate: 24.2146
# Finished 52.4 percent. Acceptance Rate: 24.229
# Finished 52.6 percent. Acceptance Rate: 24.2586
# Finished 52.8 percent. Acceptance Rate: 24.2841
# Finished 53 percent. Acceptance Rate: 24.283
# Finished 53.2 percent. Acceptance Rate: 24.2632
# Finished 53.4 percent. Acceptance Rate: 24.2285
# Finished 53.6 percent. Acceptance Rate: 24.2164
# Finished 53.8 percent. Acceptance Rate: 24.2045
# Finished 54 percent. Acceptance Rate: 24.2074
# Finished 54.2 percent. Acceptance Rate: 24.2288
# Finished 54.4 percent. Acceptance Rate: 24.2132
# Finished 54.6 percent. Acceptance Rate: 24.2418
# Finished 54.8 percent. Acceptance Rate: 24.2518
# Finished 55 percent. Acceptance Rate: 24.2764
# Finished 55.2 percent. Acceptance Rate: 24.2536
# Finished 55.4 percent. Acceptance Rate: 24.2347
# Finished 55.6 percent. Acceptance Rate: 24.2158
# Finished 55.8 percent. Acceptance Rate: 24.2079
# Finished 56 percent. Acceptance Rate: 24.1893
# Finished 56.2 percent. Acceptance Rate: 24.1744
# Finished 56.4 percent. Acceptance Rate: 24.195
# Finished 56.6 percent. Acceptance Rate: 24.1979
# Finished 56.8 percent. Acceptance Rate: 24.1866
# Finished 57 percent. Acceptance Rate: 24.1614
# Finished 57.2 percent. Acceptance Rate: 24.1713
# Finished 57.4 percent. Acceptance Rate: 24.1568
# Finished 57.6 percent. Acceptance Rate: 24.1597
# Finished 57.8 percent. Acceptance Rate: 24.1626
# Finished 58 percent. Acceptance Rate: 24.1621
# Finished 58.2 percent. Acceptance Rate: 24.1478
# Finished 58.4 percent. Acceptance Rate: 24.1849
# Finished 58.6 percent. Acceptance Rate: 24.198
# Finished 58.8 percent. Acceptance Rate: 24.2007
# Finished 59 percent. Acceptance Rate: 24.2068
# Finished 59.2 percent. Acceptance Rate: 24.2331
# Finished 59.4 percent. Acceptance Rate: 24.2492
# Finished 59.6 percent. Acceptance Rate: 24.2685
# Finished 59.8 percent. Acceptance Rate: 24.2575
# Finished 60 percent. Acceptance Rate: 24.2667
# Finished 60.2 percent. Acceptance Rate: 24.2658
# Finished 60.4 percent. Acceptance Rate: 24.2914
# Finished 60.6 percent. Acceptance Rate: 24.2772
# Finished 60.8 percent. Acceptance Rate: 24.2632
# Finished 61 percent. Acceptance Rate: 24.259
# Finished 61.2 percent. Acceptance Rate: 24.2484
# Finished 61.4 percent. Acceptance Rate: 24.2476
# Finished 61.6 percent. Acceptance Rate: 24.2468
# Finished 61.8 percent. Acceptance Rate: 24.2654
# Finished 62 percent. Acceptance Rate: 24.2742
# Finished 62.2 percent. Acceptance Rate: 24.3119
# Finished 62.4 percent. Acceptance Rate: 24.3045
# Finished 62.6 percent. Acceptance Rate: 24.2748
# Finished 62.8 percent. Acceptance Rate: 24.2643
# Finished 63 percent. Acceptance Rate: 24.2508
# Finished 63.2 percent. Acceptance Rate: 24.2563
# Finished 63.4 percent. Acceptance Rate: 24.2618
# Finished 63.6 percent. Acceptance Rate: 24.2547
# Finished 63.8 percent. Acceptance Rate: 24.232
# Finished 64 percent. Acceptance Rate: 24.2312
# Finished 64.2 percent. Acceptance Rate: 24.2118
# Finished 64.4 percent. Acceptance Rate: 24.1925
# Finished 64.6 percent. Acceptance Rate: 24.2105
# Finished 64.8 percent. Acceptance Rate: 24.1975
# Finished 65 percent. Acceptance Rate: 24.1815
# Finished 65.2 percent. Acceptance Rate: 24.1503
# Finished 65.4 percent. Acceptance Rate: 24.159
# Finished 65.6 percent. Acceptance Rate: 24.1677
# Finished 65.8 percent. Acceptance Rate: 24.1702
# Finished 66 percent. Acceptance Rate: 24.1545
# Finished 66.2 percent. Acceptance Rate: 24.1722
# Finished 66.4 percent. Acceptance Rate: 24.1777
# Finished 66.6 percent. Acceptance Rate: 24.1712
# Finished 66.8 percent. Acceptance Rate: 24.1707
# Finished 67 percent. Acceptance Rate: 24.1881
# Finished 67.2 percent. Acceptance Rate: 24.2024
# Finished 67.4 percent. Acceptance Rate: 24.1869
# Finished 67.6 percent. Acceptance Rate: 24.1805
# Finished 67.8 percent. Acceptance Rate: 24.1917
# Finished 68 percent. Acceptance Rate: 24.2206
# Finished 68.2 percent. Acceptance Rate: 24.2023
# Finished 68.4 percent. Acceptance Rate: 24.2076
# Finished 68.6 percent. Acceptance Rate: 24.2041
# Finished 68.8 percent. Acceptance Rate: 24.2209
# Finished 69 percent. Acceptance Rate: 24.2174
# Finished 69.2 percent. Acceptance Rate: 24.2197
# Finished 69.4 percent. Acceptance Rate: 24.2017
# Finished 69.6 percent. Acceptance Rate: 24.1983
# Finished 69.8 percent. Acceptance Rate: 24.1948
# Finished 70 percent. Acceptance Rate: 24.1714
# Finished 70.2 percent. Acceptance Rate: 24.1652
# Finished 70.4 percent. Acceptance Rate: 24.1847
# Finished 70.6 percent. Acceptance Rate: 24.1955
# Finished 70.8 percent. Acceptance Rate: 24.1864
# Finished 71 percent. Acceptance Rate: 24.1915
# Finished 71.2 percent. Acceptance Rate: 24.1966
# Finished 71.4 percent. Acceptance Rate: 24.2241
# Finished 71.6 percent. Acceptance Rate: 24.2151
# Finished 71.8 percent. Acceptance Rate: 24.2396
# Finished 72 percent. Acceptance Rate: 24.2472
# Finished 72.2 percent. Acceptance Rate: 24.2161
# Finished 72.4 percent. Acceptance Rate: 24.2044
# Finished 72.6 percent. Acceptance Rate: 24.2342
# Finished 72.8 percent. Acceptance Rate: 24.228
# Finished 73 percent. Acceptance Rate: 24.211
# Finished 73.2 percent. Acceptance Rate: 24.1967
# Finished 73.4 percent. Acceptance Rate: 24.2044
# Finished 73.6 percent. Acceptance Rate: 24.2283
# Finished 73.8 percent. Acceptance Rate: 24.2493
# Finished 74 percent. Acceptance Rate: 24.2486
# Finished 74.2 percent. Acceptance Rate: 24.2561
# Finished 74.4 percent. Acceptance Rate: 24.2715
# Finished 74.6 percent. Acceptance Rate: 24.2869
# Finished 74.8 percent. Acceptance Rate: 24.2701
# Finished 75 percent. Acceptance Rate: 24.264
# Finished 75.2 percent. Acceptance Rate: 24.2739
# Finished 75.4 percent. Acceptance Rate: 24.2812
# Finished 75.6 percent. Acceptance Rate: 24.2857
# Finished 75.8 percent. Acceptance Rate: 24.2744
# Finished 76 percent. Acceptance Rate: 24.2658
# Finished 76.2 percent. Acceptance Rate: 24.2651
# Finished 76.4 percent. Acceptance Rate: 24.2539
# Finished 76.6 percent. Acceptance Rate: 24.2298
# Finished 76.8 percent. Acceptance Rate: 24.224
# Finished 77 percent. Acceptance Rate: 24.2338
# Finished 77.2 percent. Acceptance Rate: 24.2306
# Finished 77.4 percent. Acceptance Rate: 24.2041
# Finished 77.6 percent. Acceptance Rate: 24.2036
# Finished 77.8 percent. Acceptance Rate: 24.1851
# Finished 78 percent. Acceptance Rate: 24.1821
# Finished 78.2 percent. Acceptance Rate: 24.1944
# Finished 78.4 percent. Acceptance Rate: 24.1913
# Finished 78.6 percent. Acceptance Rate: 24.2112
# Finished 78.8 percent. Acceptance Rate: 24.2081
# Finished 79 percent. Acceptance Rate: 24.2127
# Finished 79.2 percent. Acceptance Rate: 24.2146
# Finished 79.4 percent. Acceptance Rate: 24.2065
# Finished 79.6 percent. Acceptance Rate: 24.196
# Finished 79.8 percent. Acceptance Rate: 24.198
# Finished 80 percent. Acceptance Rate: 24.2025
# Finished 80.2 percent. Acceptance Rate: 24.207
# Finished 80.4 percent. Acceptance Rate: 24.2065
# Finished 80.6 percent. Acceptance Rate: 24.2084
# Finished 80.8 percent. Acceptance Rate: 24.2228
# Finished 81 percent. Acceptance Rate: 24.242
# Finished 81.2 percent. Acceptance Rate: 24.2414
# Finished 81.4 percent. Acceptance Rate: 24.2408
# Finished 81.6 percent. Acceptance Rate: 24.2475
# Finished 81.8 percent. Acceptance Rate: 24.2445
# Finished 82 percent. Acceptance Rate: 24.2366
# Finished 82.2 percent. Acceptance Rate: 24.236
# Finished 82.4 percent. Acceptance Rate: 24.2403
# Finished 82.6 percent. Acceptance Rate: 24.2276
# Finished 82.8 percent. Acceptance Rate: 24.2126
# Finished 83 percent. Acceptance Rate: 24.2361
# Finished 83.2 percent. Acceptance Rate: 24.2428
# Finished 83.4 percent. Acceptance Rate: 24.2518
# Finished 83.6 percent. Acceptance Rate: 24.256
# Finished 83.8 percent. Acceptance Rate: 24.2625
# Finished 84 percent. Acceptance Rate: 24.281
# Finished 84.2 percent. Acceptance Rate: 24.2898
# Finished 84.4 percent. Acceptance Rate: 24.282
# Finished 84.6 percent. Acceptance Rate: 24.2742
# Finished 84.8 percent. Acceptance Rate: 24.2642
# Finished 85 percent. Acceptance Rate: 24.2753
# Finished 85.2 percent. Acceptance Rate: 24.277
# Finished 85.4 percent. Acceptance Rate: 24.2646
# Finished 85.6 percent. Acceptance Rate: 24.2734
# Finished 85.8 percent. Acceptance Rate: 24.2727
# Finished 86 percent. Acceptance Rate: 24.2767
# Finished 86.2 percent. Acceptance Rate: 24.297
# Finished 86.4 percent. Acceptance Rate: 24.3171
# Finished 86.6 percent. Acceptance Rate: 24.3095
# Finished 86.8 percent. Acceptance Rate: 24.2903
# Finished 87 percent. Acceptance Rate: 24.2828
# Finished 87.2 percent. Acceptance Rate: 24.2752
# Finished 87.4 percent. Acceptance Rate: 24.2838
# Finished 87.6 percent. Acceptance Rate: 24.2785
# Finished 87.8 percent. Acceptance Rate: 24.2938
# Finished 88 percent. Acceptance Rate: 24.2841
# Finished 88.2 percent. Acceptance Rate: 24.2993
# Finished 88.4 percent. Acceptance Rate: 24.2941
# Finished 88.6 percent. Acceptance Rate: 24.2912
# Finished 88.8 percent. Acceptance Rate: 24.2703
# Finished 89 percent. Acceptance Rate: 24.2742
# Finished 89.2 percent. Acceptance Rate: 24.2668
# Finished 89.4 percent. Acceptance Rate: 24.2506
# Finished 89.6 percent. Acceptance Rate: 24.2478
# Finished 89.8 percent. Acceptance Rate: 24.2405
# Finished 90 percent. Acceptance Rate: 24.2333
# Finished 90.2 percent. Acceptance Rate: 24.235
# Finished 90.4 percent. Acceptance Rate: 24.2345
# Finished 90.6 percent. Acceptance Rate: 24.2384
# Finished 90.8 percent. Acceptance Rate: 24.2445
# Finished 91 percent. Acceptance Rate: 24.2527
# Finished 91.2 percent. Acceptance Rate: 24.2478
# Finished 91.4 percent. Acceptance Rate: 24.2648
# Finished 91.6 percent. Acceptance Rate: 24.2664
# Finished 91.8 percent. Acceptance Rate: 24.2723
# Finished 92 percent. Acceptance Rate: 24.2826
# Finished 92.2 percent. Acceptance Rate: 24.2755
# Finished 92.4 percent. Acceptance Rate: 24.2706
# Finished 92.6 percent. Acceptance Rate: 24.2549
# Finished 92.8 percent. Acceptance Rate: 24.2457
# Finished 93 percent. Acceptance Rate: 24.2495
# Finished 93.2 percent. Acceptance Rate: 24.2425
# Finished 93.4 percent. Acceptance Rate: 24.2484
# Finished 93.6 percent. Acceptance Rate: 24.2393
# Finished 93.8 percent. Acceptance Rate: 24.2516
# Finished 94 percent. Acceptance Rate: 24.2574
# Finished 94.2 percent. Acceptance Rate: 24.2505
# Finished 94.4 percent. Acceptance Rate: 24.2627
# Finished 94.6 percent. Acceptance Rate: 24.2664
# Finished 94.8 percent. Acceptance Rate: 24.27
# Finished 95 percent. Acceptance Rate: 24.2632
# Finished 95.2 percent. Acceptance Rate: 24.2563
# Finished 95.4 percent. Acceptance Rate: 24.2495
# Finished 95.6 percent. Acceptance Rate: 24.2448
# Finished 95.8 percent. Acceptance Rate: 24.2463
# Finished 96 percent. Acceptance Rate: 24.2292
# Finished 96.2 percent. Acceptance Rate: 24.2391
# Finished 96.4 percent. Acceptance Rate: 24.2344
# Finished 96.6 percent. Acceptance Rate: 24.2547
# Finished 96.8 percent. Acceptance Rate: 24.2603
# Finished 97 percent. Acceptance Rate: 24.2701
# Finished 97.2 percent. Acceptance Rate: 24.2798
# Finished 97.4 percent. Acceptance Rate: 24.2936
# Finished 97.6 percent. Acceptance Rate: 24.2992
# Finished 97.8 percent. Acceptance Rate: 24.3211
# Finished 98 percent. Acceptance Rate: 24.3388
# Finished 98.2 percent. Acceptance Rate: 24.3381
# Finished 98.4 percent. Acceptance Rate: 24.3455
# Finished 98.6 percent. Acceptance Rate: 24.3489
# Finished 98.8 percent. Acceptance Rate: 24.3441
# Finished 99 percent. Acceptance Rate: 24.3394
# Finished 99.2 percent. Acceptance Rate: 24.3407
# Finished 99.4 percent. Acceptance Rate: 24.3481
# Finished 99.6 percent. Acceptance Rate: 24.3373
# Finished 99.8 percent. Acceptance Rate: 24.3226

# %%
triangle.corner(sampler.chain)

# %% [markdown]
# ## Exercise 2d ##
# Run a simple MCMC, using the sampler you wrote yesterday, to discover the injected value of:
#  * white noise
#  * PSD amplitudes
#
# Make a plot of the power spectrum (use np.percentile)

# %%
# Run a simple MCMC on the power-law
def loglik(x):
    return sp_loglikelihood(psr, 10**x[0], 10**x[1:])

def logprior(x):
    rv = 0.0
    xmin, xmax = np.ones_like(x), np.ones_like(x)
    
    xmin[0], xmax[0] = -10.0, -4.0
    xmin[1:] = -18.0
    xmax[1:] = -12.0
    
    if np.any(x < xmin) or np.any(x > xmax):
        rv = -np.inf
        
    return rv

psd0 = np.ones(psr.Fmat.shape[1]/2) * -14.0
p0 = np.append([-7.0], psd0)
sigmas = 0.1 * np.ones_like(p0)
sampler = smcmc.SimpleMCMC(loglik, logprior, sigmas)

# %%
sampler.sample(p0, 50000)
# Out:
# Finished 0.2 percent. Acceptance Rate: 33
# Finished 0.4 percent. Acceptance Rate: 33.5
# Finished 0.6 percent. Acceptance Rate: 33
# Finished 0.8 percent. Acceptance Rate: 31.75
# Finished 1 percent. Acceptance Rate: 30.6
# Finished 1.2 percent. Acceptance Rate: 30.1667
# Finished 1.4 percent. Acceptance Rate: 28.8571
# Finished 1.6 percent. Acceptance Rate: 28.25
# Finished 1.8 percent. Acceptance Rate: 27.6667
# Finished 2 percent. Acceptance Rate: 27
# Finished 2.2 percent. Acceptance Rate: 26.9091
# Finished 2.4 percent. Acceptance Rate: 26.0833
# Finished 2.6 percent. Acceptance Rate: 26
# Finished 2.8 percent. Acceptance Rate: 25.5714
# Finished 3 percent. Acceptance Rate: 25.5333
# Finished 3.2 percent. Acceptance Rate: 25.5
# Finished 3.4 percent. Acceptance Rate: 25.7059
# Finished 3.6 percent. Acceptance Rate: 25.5556
# Finished 3.8 percent. Acceptance Rate: 25.5263
# Finished 4 percent. Acceptance Rate: 25.4
# Finished 4.2 percent. Acceptance Rate: 25.4286
# Finished 4.4 percent. Acceptance Rate: 24.9545
# Finished 4.6 percent. Acceptance Rate: 24.913
# Finished 4.8 percent. Acceptance Rate: 24.4167
# Finished 5 percent. Acceptance Rate: 24.8
# Finished 5.2 percent. Acceptance Rate: 25.1923
# Finished 5.4 percent. Acceptance Rate: 25.2963
# Finished 5.6 percent. Acceptance Rate: 25.3929
# Finished 5.8 percent. Acceptance Rate: 25.1379
# Finished 6 percent. Acceptance Rate: 24.8667
# Finished 6.2 percent. Acceptance Rate: 24.871
# Finished 6.4 percent. Acceptance Rate: 24.6875
# Finished 6.6 percent. Acceptance Rate: 24.6061
# Finished 6.8 percent. Acceptance Rate: 24.5882
# Finished 7 percent. Acceptance Rate: 24.5143
# Finished 7.2 percent. Acceptance Rate: 24.6667
# Finished 7.4 percent. Acceptance Rate: 24.7838
# Finished 7.6 percent. Acceptance Rate: 24.9211
# Finished 7.8 percent. Acceptance Rate: 25.0256
# Finished 8 percent. Acceptance Rate: 25.25
# Finished 8.2 percent. Acceptance Rate: 25.2195
# Finished 8.4 percent. Acceptance Rate: 25.3571
# Finished 8.6 percent. Acceptance Rate: 25.2326
# Finished 8.8 percent. Acceptance Rate: 25.0682
# Finished 9 percent. Acceptance Rate: 24.6
# Finished 9.2 percent. Acceptance Rate: 24.4348
# Finished 9.4 percent. Acceptance Rate: 24.7234
# Finished 9.6 percent. Acceptance Rate: 24.7917
# Finished 9.8 percent. Acceptance Rate: 24.8776
# Finished 10 percent. Acceptance Rate: 24.98
# Finished 10.2 percent. Acceptance Rate: 24.8627
# Finished 10.4 percent. Acceptance Rate: 24.9038
# Finished 10.6 percent. Acceptance Rate: 24.6981
# Finished 10.8 percent. Acceptance Rate: 24.7037
# Finished 11 percent. Acceptance Rate: 24.6182
# Finished 11.2 percent. Acceptance Rate: 24.6786
# Finished 11.4 percent. Acceptance Rate: 24.6491
# Finished 11.6 percent. Acceptance Rate: 24.5345
# Finished 11.8 percent. Acceptance Rate: 24.4915
# Finished 12 percent. Acceptance Rate: 24.5667
# Finished 12.2 percent. Acceptance Rate: 24.5902
# Finished 12.4 percent. Acceptance Rate: 24.5806
# Finished 12.6 percent. Acceptance Rate: 24.7143
# Finished 12.8 percent. Acceptance Rate: 24.75
# Finished 13 percent. Acceptance Rate: 24.6154
# Finished 13.2 percent. Acceptance Rate: 24.5758
# Finished 13.4 percent. Acceptance Rate: 24.6119
# Finished 13.6 percent. Acceptance Rate: 24.6176
# Finished 13.8 percent. Acceptance Rate: 24.5507
# Finished 14 percent. Acceptance Rate: 24.5286
# Finished 14.2 percent. Acceptance Rate: 24.4507
# Finished 14.4 percent. Acceptance Rate: 24.4444
# Finished 14.6 percent. Acceptance Rate: 24.411
# Finished 14.8 percent. Acceptance Rate: 24.4865
# Finished 15 percent. Acceptance Rate: 24.5733
# Finished 15.2 percent. Acceptance Rate: 24.5789
# Finished 15.4 percent. Acceptance Rate: 24.5844
# Finished 15.6 percent. Acceptance Rate: 24.5769
# Finished 15.8 percent. Acceptance Rate: 24.5823
# Finished 16 percent. Acceptance Rate: 24.5625
# Finished 16.2 percent. Acceptance Rate: 24.5802
# Finished 16.4 percent. Acceptance Rate: 24.5244
# Finished 16.6 percent. Acceptance Rate: 24.6506
# Finished 16.8 percent. Acceptance Rate: 24.7143
# Finished 17 percent. Acceptance Rate: 24.7294
# Finished 17.2 percent. Acceptance Rate: 24.7791
# Finished 17.4 percent. Acceptance Rate: 24.8851
# Finished 17.6 percent. Acceptance Rate: 24.8295
# Finished 17.8 percent. Acceptance Rate: 24.809
# Finished 18 percent. Acceptance Rate: 24.8889
# Finished 18.2 percent. Acceptance Rate: 24.9451
# Finished 18.4 percent. Acceptance Rate: 24.9783
# Finished 18.6 percent. Acceptance Rate: 24.9355
# Finished 18.8 percent. Acceptance Rate: 24.9362
# Finished 19 percent. Acceptance Rate: 24.9895
# Finished 19.2 percent. Acceptance Rate: 25.0729
# Finished 19.4 percent. Acceptance Rate: 25.1237
# Finished 19.6 percent. Acceptance Rate: 25.1633
# Finished 19.8 percent. Acceptance Rate: 25.1717
# Finished 20 percent. Acceptance Rate: 25.21
# Finished 20.2 percent. Acceptance Rate: 25.198
# Finished 20.4 percent. Acceptance Rate: 25.1863
# Finished 20.6 percent. Acceptance Rate: 25.1456
# Finished 20.8 percent. Acceptance Rate: 25.125
# Finished 21 percent. Acceptance Rate: 25.1429
# Finished 21.2 percent. Acceptance Rate: 25.0849
# Finished 21.4 percent. Acceptance Rate: 25.0467
# Finished 21.6 percent. Acceptance Rate: 24.9815
# Finished 21.8 percent. Acceptance Rate: 25.0092
# Finished 22 percent. Acceptance Rate: 25.0091
# Finished 22.2 percent. Acceptance Rate: 24.982
# Finished 22.4 percent. Acceptance Rate: 24.9643
# Finished 22.6 percent. Acceptance Rate: 24.9381
# Finished 22.8 percent. Acceptance Rate: 24.9298
# Finished 23 percent. Acceptance Rate: 24.887
# Finished 23.2 percent. Acceptance Rate: 24.8534
# Finished 23.4 percent. Acceptance Rate: 24.8547
# Finished 23.6 percent. Acceptance Rate: 24.9153
# Finished 23.8 percent. Acceptance Rate: 24.9328
# Finished 24 percent. Acceptance Rate: 24.95
# Finished 24.2 percent. Acceptance Rate: 24.9587
# Finished 24.4 percent. Acceptance Rate: 24.9672
# Finished 24.6 percent. Acceptance Rate: 24.8862
# Finished 24.8 percent. Acceptance Rate: 24.9194
# Finished 25 percent. Acceptance Rate: 24.904
# Finished 25.2 percent. Acceptance Rate: 24.8968
# Finished 25.4 percent. Acceptance Rate: 24.9134
# Finished 25.6 percent. Acceptance Rate: 24.9609
# Finished 25.8 percent. Acceptance Rate: 24.938
# Finished 26 percent. Acceptance Rate: 24.8231
# Finished 26.2 percent. Acceptance Rate: 24.8473
# Finished 26.4 percent. Acceptance Rate: 24.7879
# Finished 26.6 percent. Acceptance Rate: 24.6992
# Finished 26.8 percent. Acceptance Rate: 24.6716
# Finished 27 percent. Acceptance Rate: 24.6444
# Finished 27.2 percent. Acceptance Rate: 24.6029
# Finished 27.4 percent. Acceptance Rate: 24.5693
# Finished 27.6 percent. Acceptance Rate: 24.5652
# Finished 27.8 percent. Acceptance Rate: 24.5755
# Finished 28 percent. Acceptance Rate: 24.5643
# Finished 28.2 percent. Acceptance Rate: 24.5177
# Finished 28.4 percent. Acceptance Rate: 24.5352
# Finished 28.6 percent. Acceptance Rate: 24.5734
# Finished 28.8 percent. Acceptance Rate: 24.625
# Finished 29 percent. Acceptance Rate: 24.6069
# Finished 29.2 percent. Acceptance Rate: 24.5753
# Finished 29.4 percent. Acceptance Rate: 24.6395
# Finished 29.6 percent. Acceptance Rate: 24.6892
# Finished 29.8 percent. Acceptance Rate: 24.6913
# Finished 30 percent. Acceptance Rate: 24.68
# Finished 30.2 percent. Acceptance Rate: 24.6291
# Finished 30.4 percent. Acceptance Rate: 24.6579
# Finished 30.6 percent. Acceptance Rate: 24.6275
# Finished 30.8 percent. Acceptance Rate: 24.6364
# Finished 31 percent. Acceptance Rate: 24.6387
# Finished 31.2 percent. Acceptance Rate: 24.609
# Finished 31.4 percent. Acceptance Rate: 24.5541
# Finished 31.6 percent. Acceptance Rate: 24.5316
# Finished 31.8 percent. Acceptance Rate: 24.5283
# Finished 32 percent. Acceptance Rate: 24.5125
# Finished 32.2 percent. Acceptance Rate: 24.5342
# Finished 32.4 percent. Acceptance Rate: 24.5
# Finished 32.6 percent. Acceptance Rate: 24.4969
# Finished 32.8 percent. Acceptance Rate: 24.5183
# Finished 33 percent. Acceptance Rate: 24.5212
# Finished 33.2 percent. Acceptance Rate: 24.5422
# Finished 33.4 percent. Acceptance Rate: 24.497
# Finished 33.6 percent. Acceptance Rate: 24.4702
# Finished 33.8 percent. Acceptance Rate: 24.4793
# Finished 34 percent. Acceptance Rate: 24.4765
# Finished 34.2 percent. Acceptance Rate: 24.538
# Finished 34.4 percent. Acceptance Rate: 24.5872
# Finished 34.6 percent. Acceptance Rate: 24.578
# Finished 34.8 percent. Acceptance Rate: 24.5632
# Finished 35 percent. Acceptance Rate: 24.56
# Finished 35.2 percent. Acceptance Rate: 24.5284
# Finished 35.4 percent. Acceptance Rate: 24.5424
# Finished 35.6 percent. Acceptance Rate: 24.5281
# Finished 35.8 percent. Acceptance Rate: 24.5475
# Finished 36 percent. Acceptance Rate: 24.5444
# Finished 36.2 percent. Acceptance Rate: 24.5525
# Finished 36.4 percent. Acceptance Rate: 24.5275
# Finished 36.6 percent. Acceptance Rate: 24.5847
# Finished 36.8 percent. Acceptance Rate: 24.6141
# Finished 37 percent. Acceptance Rate: 24.5676
# Finished 37.2 percent. Acceptance Rate: 24.5484
# Finished 37.4 percent. Acceptance Rate: 24.5561
# Finished 37.6 percent. Acceptance Rate: 24.5266
# Finished 37.8 percent. Acceptance Rate: 24.5079
# Finished 38 percent. Acceptance Rate: 24.4842
# Finished 38.2 percent. Acceptance Rate: 24.4921
# Finished 38.4 percent. Acceptance Rate: 24.4948
# Finished 38.6 percent. Acceptance Rate: 24.4819
# Finished 38.8 percent. Acceptance Rate: 24.4175
# Finished 39 percent. Acceptance Rate: 24.4308
# Finished 39.2 percent. Acceptance Rate: 24.398
# Finished 39.4 percent. Acceptance Rate: 24.3959
# Finished 39.6 percent. Acceptance Rate: 24.3838
# Finished 39.8 percent. Acceptance Rate: 24.3719
# Finished 40 percent. Acceptance Rate: 24.36
# Finished 40.2 percent. Acceptance Rate: 24.3881
# Finished 40.4 percent. Acceptance Rate: 24.396
# Finished 40.6 percent. Acceptance Rate: 24.3842
# Finished 40.8 percent. Acceptance Rate: 24.3873
# Finished 41 percent. Acceptance Rate: 24.3317
# Finished 41.2 percent. Acceptance Rate: 24.2427
# Finished 41.4 percent. Acceptance Rate: 24.2367
# Finished 41.6 percent. Acceptance Rate: 24.2356
# Finished 41.8 percent. Acceptance Rate: 24.2392
# Finished 42 percent. Acceptance Rate: 24.2238
# Finished 42.2 percent. Acceptance Rate: 24.2038
# Finished 42.4 percent. Acceptance Rate: 24.1981
# Finished 42.6 percent. Acceptance Rate: 24.1831
# Finished 42.8 percent. Acceptance Rate: 24.1636
# Finished 43 percent. Acceptance Rate: 24.1488
# Finished 43.2 percent. Acceptance Rate: 24.1713
# Finished 43.4 percent. Acceptance Rate: 24.1613
# Finished 43.6 percent. Acceptance Rate: 24.1881
# Finished 43.8 percent. Acceptance Rate: 24.1507
# Finished 44 percent. Acceptance Rate: 24.1545
# Finished 44.2 percent. Acceptance Rate: 24.1584
# Finished 44.4 percent. Acceptance Rate: 24.1396
# Finished 44.6 percent. Acceptance Rate: 24.1345
# Finished 44.8 percent. Acceptance Rate: 24.125
# Finished 45 percent. Acceptance Rate: 24.1378
# Finished 45.2 percent. Acceptance Rate: 24.1416
# Finished 45.4 percent. Acceptance Rate: 24.1322
# Finished 45.6 percent. Acceptance Rate: 24.1535
# Finished 45.8 percent. Acceptance Rate: 24.1266
# Finished 46 percent. Acceptance Rate: 24.1348
# Finished 46.2 percent. Acceptance Rate: 24.1429
# Finished 46.4 percent. Acceptance Rate: 24.1336
# Finished 46.6 percent. Acceptance Rate: 24.133
# Finished 46.8 percent. Acceptance Rate: 24.0983
# Finished 47 percent. Acceptance Rate: 24.0766
# Finished 47.2 percent. Acceptance Rate: 24.0932
# Finished 47.4 percent. Acceptance Rate: 24.0844
# Finished 47.6 percent. Acceptance Rate: 24.0882
# Finished 47.8 percent. Acceptance Rate: 24.0837
# Finished 48 percent. Acceptance Rate: 24.1125
# Finished 48.2 percent. Acceptance Rate: 24.1328
# Finished 48.4 percent. Acceptance Rate: 24.1074
# Finished 48.6 percent. Acceptance Rate: 24.1193
# Finished 48.8 percent. Acceptance Rate: 24.1516
# Finished 49 percent. Acceptance Rate: 24.1551
# Finished 49.2 percent. Acceptance Rate: 24.1341
# Finished 49.4 percent. Acceptance Rate: 24.1215
# Finished 49.6 percent. Acceptance Rate: 24.1169
# Finished 49.8 percent. Acceptance Rate: 24.1606
# Finished 50 percent. Acceptance Rate: 24.192
# Finished 50.2 percent. Acceptance Rate: 24.1873
# Finished 50.4 percent. Acceptance Rate: 24.1944
# Finished 50.6 percent. Acceptance Rate: 24.1818
# Finished 50.8 percent. Acceptance Rate: 24.1772
# Finished 51 percent. Acceptance Rate: 24.1843
# Finished 51.2 percent. Acceptance Rate: 24.1719
# Finished 51.4 percent. Acceptance Rate: 24.1712
# Finished 51.6 percent. Acceptance Rate: 24.1744
# Finished 51.8 percent. Acceptance Rate: 24.1892
# Finished 52 percent. Acceptance Rate: 24.2038
# Finished 52.2 percent. Acceptance Rate: 24.2222
# Finished 52.4 percent. Acceptance Rate: 24.2405
# Finished 52.6 percent. Acceptance Rate: 24.251
# Finished 52.8 percent. Acceptance Rate: 24.2386
# Finished 53 percent. Acceptance Rate: 24.2226
# Finished 53.2 percent. Acceptance Rate: 24.2368
# Finished 53.4 percent. Acceptance Rate: 24.236
# Finished 53.6 percent. Acceptance Rate: 24.2463
# Finished 53.8 percent. Acceptance Rate: 24.2788
# Finished 54 percent. Acceptance Rate: 24.2815
# Finished 54.2 percent. Acceptance Rate: 24.2841
# Finished 54.4 percent. Acceptance Rate: 24.2463
# Finished 54.6 percent. Acceptance Rate: 24.2198
# Finished 54.8 percent. Acceptance Rate: 24.2263
# Finished 55 percent. Acceptance Rate: 24.2218
# Finished 55.2 percent. Acceptance Rate: 24.2246
# Finished 55.4 percent. Acceptance Rate: 24.2347
# Finished 55.6 percent. Acceptance Rate: 24.2158
# Finished 55.8 percent. Acceptance Rate: 24.2115
# Finished 56 percent. Acceptance Rate: 24.2143
# Finished 56.2 percent. Acceptance Rate: 24.21
# Finished 56.4 percent. Acceptance Rate: 24.2092
# Finished 56.6 percent. Acceptance Rate: 24.2297
# Finished 56.8 percent. Acceptance Rate: 24.2359
# Finished 57 percent. Acceptance Rate: 24.2211
# Finished 57.2 percent. Acceptance Rate: 24.2063
# Finished 57.4 percent. Acceptance Rate: 24.1777
# Finished 57.6 percent. Acceptance Rate: 24.1597
# Finished 57.8 percent. Acceptance Rate: 24.1246
# Finished 58 percent. Acceptance Rate: 24.1069
# Finished 58.2 percent. Acceptance Rate: 24.0859
# Finished 58.4 percent. Acceptance Rate: 24.0685
# Finished 58.6 percent. Acceptance Rate: 24.1058
# Finished 58.8 percent. Acceptance Rate: 24.0986
# Finished 59 percent. Acceptance Rate: 24.0847
# Finished 59.2 percent. Acceptance Rate: 24.0574
# Finished 59.4 percent. Acceptance Rate: 24.0505
# Finished 59.6 percent. Acceptance Rate: 24.0805
# Finished 59.8 percent. Acceptance Rate: 24.0569
# Finished 60 percent. Acceptance Rate: 24.0533
# Finished 60.2 percent. Acceptance Rate: 24.0698
# Finished 60.4 percent. Acceptance Rate: 24.043
# Finished 60.6 percent. Acceptance Rate: 24.0528
# Finished 60.8 percent. Acceptance Rate: 24.0625
# Finished 61 percent. Acceptance Rate: 24.0689
# Finished 61.2 percent. Acceptance Rate: 24.085
# Finished 61.4 percent. Acceptance Rate: 24.0782
# Finished 61.6 percent. Acceptance Rate: 24.0909
# Finished 61.8 percent. Acceptance Rate: 24.1036
# Finished 62 percent. Acceptance Rate: 24.1097
# Finished 62.2 percent. Acceptance Rate: 24.0804
# Finished 62.4 percent. Acceptance Rate: 24.0673
# Finished 62.6 percent. Acceptance Rate: 24.0607
# Finished 62.8 percent. Acceptance Rate: 24.0605
# Finished 63 percent. Acceptance Rate: 24.0794
# Finished 63.2 percent. Acceptance Rate: 24.0886
# Finished 63.4 percent. Acceptance Rate: 24.0883
# Finished 63.6 percent. Acceptance Rate: 24.0723
# Finished 63.8 percent. Acceptance Rate: 24.0784
# Finished 64 percent. Acceptance Rate: 24.0875
# Finished 64.2 percent. Acceptance Rate: 24.081
# Finished 64.4 percent. Acceptance Rate: 24.0714
# Finished 64.6 percent. Acceptance Rate: 24.1022
# Finished 64.8 percent. Acceptance Rate: 24.0833
# Finished 65 percent. Acceptance Rate: 24.0708
# Finished 65.2 percent. Acceptance Rate: 24.0429
# Finished 65.4 percent. Acceptance Rate: 24.0275
# Finished 65.6 percent. Acceptance Rate: 24.0152
# Finished 65.8 percent. Acceptance Rate: 24.0122
# Finished 66 percent. Acceptance Rate: 24.0394
# Finished 66.2 percent. Acceptance Rate: 24.0211
# Finished 66.4 percent. Acceptance Rate: 24.0542
# Finished 66.6 percent. Acceptance Rate: 24.0601
# Finished 66.8 percent. Acceptance Rate: 24.0689
# Finished 67 percent. Acceptance Rate: 24.0478
# Finished 67.2 percent. Acceptance Rate: 24.0238
# Finished 67.4 percent. Acceptance Rate: 24.0178
# Finished 67.6 percent. Acceptance Rate: 23.997
# Finished 67.8 percent. Acceptance Rate: 23.9941
# Finished 68 percent. Acceptance Rate: 23.9647
# Finished 68.2 percent. Acceptance Rate: 23.956
# Finished 68.4 percent. Acceptance Rate: 23.9708
# Finished 68.6 percent. Acceptance Rate: 23.9738
# Finished 68.8 percent. Acceptance Rate: 23.9593
# Finished 69 percent. Acceptance Rate: 23.9942
# Finished 69.2 percent. Acceptance Rate: 24.0087
# Finished 69.4 percent. Acceptance Rate: 23.9914
# Finished 69.6 percent. Acceptance Rate: 23.9741
# Finished 69.8 percent. Acceptance Rate: 23.9713
# Finished 70 percent. Acceptance Rate: 23.96
# Finished 70.2 percent. Acceptance Rate: 23.9202
# Finished 70.4 percent. Acceptance Rate: 23.9261
# Finished 70.6 percent. Acceptance Rate: 23.9377
# Finished 70.8 percent. Acceptance Rate: 23.9605
# Finished 71 percent. Acceptance Rate: 23.9803
# Finished 71.2 percent. Acceptance Rate: 23.9972
# Finished 71.4 percent. Acceptance Rate: 24.0084
# Finished 71.6 percent. Acceptance Rate: 23.9749
# Finished 71.8 percent. Acceptance Rate: 23.9749
# Finished 72 percent. Acceptance Rate: 23.9667
# Finished 72.2 percent. Acceptance Rate: 23.9695
# Finished 72.4 percent. Acceptance Rate: 23.9696
# Finished 72.6 percent. Acceptance Rate: 23.9614
# Finished 72.8 percent. Acceptance Rate: 23.9313
# Finished 73 percent. Acceptance Rate: 23.9096
# Finished 73.2 percent. Acceptance Rate: 23.9016
# Finished 73.4 percent. Acceptance Rate: 23.9155
# Finished 73.6 percent. Acceptance Rate: 23.913
# Finished 73.8 percent. Acceptance Rate: 23.897
# Finished 74 percent. Acceptance Rate: 23.9081
# Finished 74.2 percent. Acceptance Rate: 23.8895
# Finished 74.4 percent. Acceptance Rate: 23.8602
# Finished 74.6 percent. Acceptance Rate: 23.866
# Finished 74.8 percent. Acceptance Rate: 23.8904
# Finished 75 percent. Acceptance Rate: 23.912
# Finished 75.2 percent. Acceptance Rate: 23.9176
# Finished 75.4 percent. Acceptance Rate: 23.9363
# Finished 75.6 percent. Acceptance Rate: 23.9339
# Finished 75.8 percent. Acceptance Rate: 23.934
# Finished 76 percent. Acceptance Rate: 23.9316
# Finished 76.2 percent. Acceptance Rate: 23.937
# Finished 76.4 percent. Acceptance Rate: 23.9555
# Finished 76.6 percent. Acceptance Rate: 23.9295
# Finished 76.8 percent. Acceptance Rate: 23.9141
# Finished 77 percent. Acceptance Rate: 23.8987
# Finished 77.2 percent. Acceptance Rate: 23.9093
# Finished 77.4 percent. Acceptance Rate: 23.9225
# Finished 77.6 percent. Acceptance Rate: 23.9253
# Finished 77.8 percent. Acceptance Rate: 23.9229
# Finished 78 percent. Acceptance Rate: 23.9462
# Finished 78.2 percent. Acceptance Rate: 23.9463
# Finished 78.4 percent. Acceptance Rate: 23.9464
# Finished 78.6 percent. Acceptance Rate: 23.9338
# Finished 78.8 percent. Acceptance Rate: 23.9112
# Finished 79 percent. Acceptance Rate: 23.8911
# Finished 79.2 percent. Acceptance Rate: 23.8939
# Finished 79.4 percent. Acceptance Rate: 23.9018
# Finished 79.6 percent. Acceptance Rate: 23.902
# Finished 79.8 percent. Acceptance Rate: 23.9148
# Finished 80 percent. Acceptance Rate: 23.92
# Finished 80.2 percent. Acceptance Rate: 23.9302
# Finished 80.4 percent. Acceptance Rate: 23.9428
# Finished 80.6 percent. Acceptance Rate: 23.9429
# Finished 80.8 percent. Acceptance Rate: 23.9381
# Finished 81 percent. Acceptance Rate: 23.9481
# Finished 81.2 percent. Acceptance Rate: 23.931
# Finished 81.4 percent. Acceptance Rate: 23.9361
# Finished 81.6 percent. Acceptance Rate: 23.9289
# Finished 81.8 percent. Acceptance Rate: 23.9535
# Finished 82 percent. Acceptance Rate: 23.961
# Finished 82.2 percent. Acceptance Rate: 23.9635
# Finished 82.4 percent. Acceptance Rate: 23.9563
# Finished 82.6 percent. Acceptance Rate: 23.9613
# Finished 82.8 percent. Acceptance Rate: 23.9638
# Finished 83 percent. Acceptance Rate: 23.9518
# Finished 83.2 percent. Acceptance Rate: 23.9351
# Finished 83.4 percent. Acceptance Rate: 23.9041
# Finished 83.6 percent. Acceptance Rate: 23.8947
# Finished 83.8 percent. Acceptance Rate: 23.9021
# Finished 84 percent. Acceptance Rate: 23.8976
# Finished 84.2 percent. Acceptance Rate: 23.9192
# Finished 84.4 percent. Acceptance Rate: 23.9289
# Finished 84.6 percent. Acceptance Rate: 23.9456
# Finished 84.8 percent. Acceptance Rate: 23.9458
# Finished 85 percent. Acceptance Rate: 23.9576
# Finished 85.2 percent. Acceptance Rate: 23.9624
# Finished 85.4 percent. Acceptance Rate: 23.9625
# Finished 85.6 percent. Acceptance Rate: 23.9673
# Finished 85.8 percent. Acceptance Rate: 23.9674
# Finished 86 percent. Acceptance Rate: 23.9791
# Finished 86.2 percent. Acceptance Rate: 23.9814
# Finished 86.4 percent. Acceptance Rate: 23.9653
# Finished 86.6 percent. Acceptance Rate: 23.9538
# Finished 86.8 percent. Acceptance Rate: 23.9654
# Finished 87 percent. Acceptance Rate: 23.9632
# Finished 87.2 percent. Acceptance Rate: 23.9702
# Finished 87.4 percent. Acceptance Rate: 23.9771
# Finished 87.6 percent. Acceptance Rate: 23.9749
# Finished 87.8 percent. Acceptance Rate: 23.9749
# Finished 88 percent. Acceptance Rate: 23.9614
# Finished 88.2 percent. Acceptance Rate: 23.966
# Finished 88.4 percent. Acceptance Rate: 23.9638
# Finished 88.6 percent. Acceptance Rate: 23.9729
# Finished 88.8 percent. Acceptance Rate: 23.9775
# Finished 89 percent. Acceptance Rate: 23.9708
# Finished 89.2 percent. Acceptance Rate: 23.9776
# Finished 89.4 percent. Acceptance Rate: 23.962
# Finished 89.6 percent. Acceptance Rate: 23.9643
# Finished 89.8 percent. Acceptance Rate: 23.951
# Finished 90 percent. Acceptance Rate: 23.9956
# Finished 90.2 percent. Acceptance Rate: 24.0044
# Finished 90.4 percent. Acceptance Rate: 24.0243
# Finished 90.6 percent. Acceptance Rate: 24.0243
# Finished 90.8 percent. Acceptance Rate: 24.0396
# Finished 91 percent. Acceptance Rate: 24.0549
# Finished 91.2 percent. Acceptance Rate: 24.0636
# Finished 91.4 percent. Acceptance Rate: 24.0788
# Finished 91.6 percent. Acceptance Rate: 24.0895
# Finished 91.8 percent. Acceptance Rate: 24.0871
# Finished 92 percent. Acceptance Rate: 24.0522
# Finished 92.2 percent. Acceptance Rate: 24.0477
# Finished 92.4 percent. Acceptance Rate: 24.0433
# Finished 92.6 percent. Acceptance Rate: 24.0518
# Finished 92.8 percent. Acceptance Rate: 24.0517
# Finished 93 percent. Acceptance Rate: 24.0602
# Finished 93.2 percent. Acceptance Rate: 24.0794
# Finished 93.4 percent. Acceptance Rate: 24.1006
# Finished 93.6 percent. Acceptance Rate: 24.1068
# Finished 93.8 percent. Acceptance Rate: 24.1173
# Finished 94 percent. Acceptance Rate: 24.1255
# Finished 94.2 percent. Acceptance Rate: 24.1359
# Finished 94.4 percent. Acceptance Rate: 24.1356
# Finished 94.6 percent. Acceptance Rate: 24.1332
# Finished 94.8 percent. Acceptance Rate: 24.1203
# Finished 95 percent. Acceptance Rate: 24.1032
# Finished 95.2 percent. Acceptance Rate: 24.1113
# Finished 95.4 percent. Acceptance Rate: 24.1006
# Finished 95.6 percent. Acceptance Rate: 24.1234
# Finished 95.8 percent. Acceptance Rate: 24.1232
# Finished 96 percent. Acceptance Rate: 24.1
# Finished 96.2 percent. Acceptance Rate: 24.0811
# Finished 96.4 percent. Acceptance Rate: 24.0643
# Finished 96.6 percent. Acceptance Rate: 24.0559
# Finished 96.8 percent. Acceptance Rate: 24.0496
# Finished 97 percent. Acceptance Rate: 24.0309
# Finished 97.2 percent. Acceptance Rate: 24.0103
# Finished 97.4 percent. Acceptance Rate: 23.9938
# Finished 97.6 percent. Acceptance Rate: 24
# Finished 97.8 percent. Acceptance Rate: 23.9918
# Finished 98 percent. Acceptance Rate: 23.9959
# Finished 98.2 percent. Acceptance Rate: 24.002
# Finished 98.4 percent. Acceptance Rate: 24.0061
# Finished 98.6 percent. Acceptance Rate: 24.0183
# Finished 98.8 percent. Acceptance Rate: 24.002
# Finished 99 percent. Acceptance Rate: 24.004
# Finished 99.2 percent. Acceptance Rate: 23.9919
# Finished 99.4 percent. Acceptance Rate: 23.9839
# Finished 99.6 percent. Acceptance Rate: 23.9598
# Finished 99.8 percent. Acceptance Rate: 23.9379

# %%
def get_psd_vals(samples, confidence=0.05):
    """
    Get the confidence intervals for MCMC samples
    
    :param samples:
        The samples from the MCMC chain
    
    :param confidence:
        The significance/confidence level of the interval.
        This is two-sided, so on either side of the interval,
        there is 0.5*confidence of probability
    
    return list of tuples: [(smin ,smax), ...]
    """
    return [(np.percentile(col, 50), np.percentile(col, 50*confidence), np.percentile(col, 100-50*confidence)) for col in samples.T]

# %%
# Get the PSD confidence levels
ci = np.array(get_psd_vals(sampler.chain[10000:,:]))
psd_val = np.mean(ci[1:,1:], axis=1)
psd_err = ci[1:,2]-ci[1:,1]

# %%
plt.scatter(psr.freqs[::2], ci[1:,0], marker='x', c='b')
plt.errorbar(psr.freqs[::2], psd_val, yerr=psd_err, fmt=' ', c='blue')
plt.xscale('log')
plt.xlim(3e-9, 2e-7)
# Out:
# (3e-09, 2e-07)

# %%
triangle.corner(sampler.chain[10000:,:5])
